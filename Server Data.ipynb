# %% [markdown]
# ### Setup Spark enviroment

# %%
import os
import sys
spark_path = os.environ['SPARK_HOME']
sys.path.append(spark_path + "/bin")
sys.path.append(spark_path + "/python")
sys.path.append(spark_path + "/python/pyspark/")
sys.path.append(spark_path + "/python/lib")
sys.path.append(spark_path + "/python/lib/pyspark.zip")
sys.path.append(spark_path + "/python/lib/py4j-0.10.9-src.zip")

import findspark
findspark.init()
import pyspark

# %%
number_cores = 4
memory_gb = 4
conf = (pyspark.SparkConf().setMaster('local[{}]'.format(number_cores)).set('spark.driver.memory', '{}g'.format(memory_gb)))
sc = pyspark.SparkContext(conf=conf)

# %% [markdown]
# ### Load Data

# %%
#Load Data
textFile = sc.textFile("C://Users//samue//Downloads//BigData//auth_log//*")

# %%
textFile.count()
# Out:
# 271071

# %% [markdown]
# ### Make Sure I Have the Data

# %%
textFile.take(100)
# Out:
# ['Dec 13 00:06:16 submitty sshd[19509]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#  'Dec 13 00:06:17 submitty sshd[19509]: Failed password for root from 218.92.0.184 port 3753 ssh2',
#  'Dec 13 00:06:21 submitty sshd[19509]: Failed password for root from 218.92.0.184 port 3753 ssh2',
#  'Dec 13 00:07:01 submitty CRON[19523]: pam_unix(cron:session): session opened for user submitty_daemon by (uid=0)',
#  'Dec 13 00:07:02 submitty CRON[19523]: pam_unix(cron:session): session closed for user submitty_daemon',
#  'Dec 13 00:08:01 submitty CRON[19536]: pam_unix(cron:session): session opened for user submitty_daemon by (uid=0)',
#  'Dec 13 00:08:01 submitty CRON[19536]: pam_unix(cron:session): session closed for user submitty_daemon',
#  'Dec 13 00:08:29 submitty sshd[19552]: Invalid user shalini from 27.128.173.81 port 49454',
#  'Dec 13 00:08:29 submitty sshd[19552]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:08:29 submitty sshd[19552]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=27.128.173.81',
#  'Dec 13 00:08:32 submitty sshd[19552]: Failed password for invalid user shalini from 27.128.173.81 port 49454 ssh2',
#  'Dec 13 00:08:40 submitty sshd[19560]: Invalid user user5 from 134.175.17.32 port 44532',
#  'Dec 13 00:08:40 submitty sshd[19560]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:08:40 submitty sshd[19560]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=134.175.17.32',
#  'Dec 13 00:08:41 submitty sshd[19562]: Invalid user lms from 201.90.101.165 port 44854',
#  'Dec 13 00:08:41 submitty sshd[19562]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:08:41 submitty sshd[19562]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=201.90.101.165',
#  'Dec 13 00:08:43 submitty sshd[19560]: Failed password for invalid user user5 from 134.175.17.32 port 44532 ssh2',
#  'Dec 13 00:08:43 submitty sshd[19560]: Received disconnect from 134.175.17.32 port 44532:11: Bye Bye [preauth]',
#  'Dec 13 00:08:43 submitty sshd[19560]: Disconnected from invalid user user5 134.175.17.32 port 44532 [preauth]',
#  'Dec 13 00:08:43 submitty sshd[19562]: Failed password for invalid user lms from 201.90.101.165 port 44854 ssh2',
#  'Dec 13 00:08:44 submitty sshd[19562]: Received disconnect from 201.90.101.165 port 44854:11: Bye Bye [preauth]',
#  'Dec 13 00:08:44 submitty sshd[19562]: Disconnected from invalid user lms 201.90.101.165 port 44854 [preauth]',
#  'Dec 13 00:09:01 submitty CRON[19580]: pam_unix(cron:session): session opened for user root by (uid=0)',
#  'Dec 13 00:09:01 submitty CRON[19581]: pam_unix(cron:session): session opened for user submitty_daemon by (uid=0)',
#  'Dec 13 00:09:01 submitty CRON[19580]: pam_unix(cron:session): session closed for user root',
#  'Dec 13 00:09:01 submitty CRON[19581]: pam_unix(cron:session): session closed for user submitty_daemon',
#  'Dec 13 00:10:01 submitty CRON[19702]: pam_unix(cron:session): session opened for user submitty_daemon by (uid=0)',
#  'Dec 13 00:10:01 submitty CRON[19702]: pam_unix(cron:session): session closed for user submitty_daemon',
#  'Dec 13 00:10:35 submitty sshd[19716]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.247  user=root',
#  'Dec 13 00:10:36 submitty sshd[19716]: Failed password for root from 218.92.0.247 port 16026 ssh2',
#  'Dec 13 00:10:40 submitty sshd[19716]: Failed password for root from 218.92.0.247 port 16026 ssh2',
#  'Dec 13 00:11:01 submitty CRON[19734]: pam_unix(cron:session): session opened for user submitty_daemon by (uid=0)',
#  'Dec 13 00:11:02 submitty CRON[19734]: pam_unix(cron:session): session closed for user submitty_daemon',
#  'Dec 13 00:11:06 submitty sshd[19744]: Invalid user ttf from 119.45.22.71 port 60804',
#  'Dec 13 00:11:06 submitty sshd[19744]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:11:06 submitty sshd[19744]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=119.45.22.71',
#  'Dec 13 00:11:07 submitty sshd[19744]: Failed password for invalid user ttf from 119.45.22.71 port 60804 ssh2',
#  'Dec 13 00:11:08 submitty sshd[19744]: Received disconnect from 119.45.22.71 port 60804:11: Bye Bye [preauth]',
#  'Dec 13 00:11:08 submitty sshd[19744]: Disconnected from invalid user ttf 119.45.22.71 port 60804 [preauth]',
#  'Dec 13 00:11:21 submitty sshd[19752]: Invalid user finn from 58.17.200.197 port 49650',
#  'Dec 13 00:11:21 submitty sshd[19752]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:11:21 submitty sshd[19752]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=58.17.200.197',
#  'Dec 13 00:11:23 submitty sshd[19752]: Failed password for invalid user finn from 58.17.200.197 port 49650 ssh2',
#  'Dec 13 00:11:23 submitty sshd[19752]: Received disconnect from 58.17.200.197 port 49650:11: Bye Bye [preauth]',
#  'Dec 13 00:11:23 submitty sshd[19752]: Disconnected from invalid user finn 58.17.200.197 port 49650 [preauth]',
#  'Dec 13 00:11:43 submitty sshd[19777]: warning: /etc/hosts.allow, line 13: host name/name mismatch: static.vnpt.vn != dnsfirewall.wcupa.edu',
#  'Dec 13 00:11:44 submitty sshd[19777]: Invalid user merle from 14.161.45.187 port 56273',
#  'Dec 13 00:11:44 submitty sshd[19777]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:11:44 submitty sshd[19777]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=14.161.45.187',
#  'Dec 13 00:11:46 submitty sshd[19777]: Failed password for invalid user merle from 14.161.45.187 port 56273 ssh2',
#  'Dec 13 00:11:46 submitty sshd[19777]: Received disconnect from 14.161.45.187 port 56273:11: Bye Bye [preauth]',
#  'Dec 13 00:11:46 submitty sshd[19777]: Disconnected from invalid user merle 14.161.45.187 port 56273 [preauth]',
#  'Dec 13 00:11:53 submitty sshd[19789]: Invalid user domain from 49.70.64.41 port 34474',
#  'Dec 13 00:11:53 submitty sshd[19789]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:11:53 submitty sshd[19789]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=49.70.64.41',
#  'Dec 13 00:11:54 submitty sshd[19796]: Invalid user ame from 129.211.138.177 port 53742',
#  'Dec 13 00:11:54 submitty sshd[19796]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:11:54 submitty sshd[19796]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=129.211.138.177',
#  'Dec 13 00:11:55 submitty sshd[19789]: Failed password for invalid user domain from 49.70.64.41 port 34474 ssh2',
#  'Dec 13 00:11:55 submitty sshd[19789]: Received disconnect from 49.70.64.41 port 34474:11: Bye Bye [preauth]',
#  'Dec 13 00:11:55 submitty sshd[19789]: Disconnected from invalid user domain 49.70.64.41 port 34474 [preauth]',
#  'Dec 13 00:11:56 submitty sshd[19796]: Failed password for invalid user ame from 129.211.138.177 port 53742 ssh2',
#  'Dec 13 00:11:56 submitty sshd[19796]: Received disconnect from 129.211.138.177 port 53742:11: Bye Bye [preauth]',
#  'Dec 13 00:11:56 submitty sshd[19796]: Disconnected from invalid user ame 129.211.138.177 port 53742 [preauth]',
#  "Dec 13 00:11:58 submitty sshd[19809]: warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#  'Dec 13 00:12:00 submitty sshd[19809]: Invalid user mysql from 185.156.74.65 port 2243',
#  'Dec 13 00:12:00 submitty sshd[19809]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:12:00 submitty sshd[19809]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#  'Dec 13 00:12:01 submitty CRON[19811]: pam_unix(cron:session): session opened for user submitty_daemon by (uid=0)',
#  'Dec 13 00:12:01 submitty CRON[19811]: pam_unix(cron:session): session closed for user submitty_daemon',
#  'Dec 13 00:12:02 submitty sshd[19809]: Failed password for invalid user mysql from 185.156.74.65 port 2243 ssh2',
#  'Dec 13 00:12:02 submitty sshd[19809]: Connection closed by invalid user mysql 185.156.74.65 port 2243 [preauth]',
#  'Dec 13 00:12:41 submitty sshd[19833]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.93.207.88  user=root',
#  'Dec 13 00:12:43 submitty sshd[19833]: Failed password for root from 218.93.207.88 port 46251 ssh2',
#  'Dec 13 00:12:45 submitty sshd[19833]: Failed password for root from 218.93.207.88 port 46251 ssh2',
#  'Dec 13 00:12:54 submitty sshd[19848]: Invalid user klx from 103.152.101.19 port 60110',
#  'Dec 13 00:12:54 submitty sshd[19848]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:12:54 submitty sshd[19848]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=103.152.101.19',
#  'Dec 13 00:12:56 submitty sshd[19848]: Failed password for invalid user klx from 103.152.101.19 port 60110 ssh2',
#  'Dec 13 00:12:56 submitty sshd[19850]: Invalid user lionya from 61.181.80.253 port 60023',
#  'Dec 13 00:12:56 submitty sshd[19850]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:12:56 submitty sshd[19850]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=61.181.80.253',
#  'Dec 13 00:12:56 submitty sshd[19848]: Received disconnect from 103.152.101.19 port 60110:11: Bye Bye [preauth]',
#  'Dec 13 00:12:56 submitty sshd[19848]: Disconnected from invalid user klx 103.152.101.19 port 60110 [preauth]',
#  'Dec 13 00:12:58 submitty sshd[19850]: Failed password for invalid user lionya from 61.181.80.253 port 60023 ssh2',
#  'Dec 13 00:12:58 submitty sshd[19850]: Received disconnect from 61.181.80.253 port 60023:11: Bye Bye [preauth]',
#  'Dec 13 00:12:58 submitty sshd[19850]: Disconnected from invalid user lionya 61.181.80.253 port 60023 [preauth]',
#  'Dec 13 00:13:01 submitty CRON[19867]: pam_unix(cron:session): session opened for user submitty_daemon by (uid=0)',
#  'Dec 13 00:13:01 submitty CRON[19867]: pam_unix(cron:session): session closed for user submitty_daemon',
#  'Dec 13 00:14:01 submitty CRON[19885]: pam_unix(cron:session): session opened for user submitty_daemon by (uid=0)',
#  'Dec 13 00:14:01 submitty CRON[19885]: pam_unix(cron:session): session closed for user submitty_daemon',
#  'Dec 13 00:14:34 submitty sshd[19898]: Invalid user yarosh from 42.200.109.74 port 40276',
#  'Dec 13 00:14:34 submitty sshd[19898]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:14:34 submitty sshd[19898]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=42.200.109.74',
#  'Dec 13 00:14:36 submitty sshd[19898]: Failed password for invalid user yarosh from 42.200.109.74 port 40276 ssh2',
#  'Dec 13 00:14:51 submitty sshd[19915]: Received disconnect from 61.177.172.107 port 3678:11:  [preauth]',
#  'Dec 13 00:14:51 submitty sshd[19915]: Disconnected from 61.177.172.107 port 3678 [preauth]',
#  'Dec 13 00:14:55 submitty sshd[19917]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.221  user=root',
#  'Dec 13 00:14:58 submitty sshd[19917]: Failed password for root from 221.181.185.221 port 27415 ssh2']

# %% [markdown]
# ### All of the fails seem to have command sshd so I filtered it to have just those commands

# %%
fails = textFile.filter(lambda line: line.find("sshd") > 0)
fails.take(100)
# Out:
# ['Dec 13 00:06:16 submitty sshd[19509]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#  'Dec 13 00:06:17 submitty sshd[19509]: Failed password for root from 218.92.0.184 port 3753 ssh2',
#  'Dec 13 00:06:21 submitty sshd[19509]: Failed password for root from 218.92.0.184 port 3753 ssh2',
#  'Dec 13 00:08:29 submitty sshd[19552]: Invalid user shalini from 27.128.173.81 port 49454',
#  'Dec 13 00:08:29 submitty sshd[19552]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:08:29 submitty sshd[19552]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=27.128.173.81',
#  'Dec 13 00:08:32 submitty sshd[19552]: Failed password for invalid user shalini from 27.128.173.81 port 49454 ssh2',
#  'Dec 13 00:08:40 submitty sshd[19560]: Invalid user user5 from 134.175.17.32 port 44532',
#  'Dec 13 00:08:40 submitty sshd[19560]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:08:40 submitty sshd[19560]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=134.175.17.32',
#  'Dec 13 00:08:41 submitty sshd[19562]: Invalid user lms from 201.90.101.165 port 44854',
#  'Dec 13 00:08:41 submitty sshd[19562]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:08:41 submitty sshd[19562]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=201.90.101.165',
#  'Dec 13 00:08:43 submitty sshd[19560]: Failed password for invalid user user5 from 134.175.17.32 port 44532 ssh2',
#  'Dec 13 00:08:43 submitty sshd[19560]: Received disconnect from 134.175.17.32 port 44532:11: Bye Bye [preauth]',
#  'Dec 13 00:08:43 submitty sshd[19560]: Disconnected from invalid user user5 134.175.17.32 port 44532 [preauth]',
#  'Dec 13 00:08:43 submitty sshd[19562]: Failed password for invalid user lms from 201.90.101.165 port 44854 ssh2',
#  'Dec 13 00:08:44 submitty sshd[19562]: Received disconnect from 201.90.101.165 port 44854:11: Bye Bye [preauth]',
#  'Dec 13 00:08:44 submitty sshd[19562]: Disconnected from invalid user lms 201.90.101.165 port 44854 [preauth]',
#  'Dec 13 00:10:35 submitty sshd[19716]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.247  user=root',
#  'Dec 13 00:10:36 submitty sshd[19716]: Failed password for root from 218.92.0.247 port 16026 ssh2',
#  'Dec 13 00:10:40 submitty sshd[19716]: Failed password for root from 218.92.0.247 port 16026 ssh2',
#  'Dec 13 00:11:06 submitty sshd[19744]: Invalid user ttf from 119.45.22.71 port 60804',
#  'Dec 13 00:11:06 submitty sshd[19744]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:11:06 submitty sshd[19744]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=119.45.22.71',
#  'Dec 13 00:11:07 submitty sshd[19744]: Failed password for invalid user ttf from 119.45.22.71 port 60804 ssh2',
#  'Dec 13 00:11:08 submitty sshd[19744]: Received disconnect from 119.45.22.71 port 60804:11: Bye Bye [preauth]',
#  'Dec 13 00:11:08 submitty sshd[19744]: Disconnected from invalid user ttf 119.45.22.71 port 60804 [preauth]',
#  'Dec 13 00:11:21 submitty sshd[19752]: Invalid user finn from 58.17.200.197 port 49650',
#  'Dec 13 00:11:21 submitty sshd[19752]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:11:21 submitty sshd[19752]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=58.17.200.197',
#  'Dec 13 00:11:23 submitty sshd[19752]: Failed password for invalid user finn from 58.17.200.197 port 49650 ssh2',
#  'Dec 13 00:11:23 submitty sshd[19752]: Received disconnect from 58.17.200.197 port 49650:11: Bye Bye [preauth]',
#  'Dec 13 00:11:23 submitty sshd[19752]: Disconnected from invalid user finn 58.17.200.197 port 49650 [preauth]',
#  'Dec 13 00:11:43 submitty sshd[19777]: warning: /etc/hosts.allow, line 13: host name/name mismatch: static.vnpt.vn != dnsfirewall.wcupa.edu',
#  'Dec 13 00:11:44 submitty sshd[19777]: Invalid user merle from 14.161.45.187 port 56273',
#  'Dec 13 00:11:44 submitty sshd[19777]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:11:44 submitty sshd[19777]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=14.161.45.187',
#  'Dec 13 00:11:46 submitty sshd[19777]: Failed password for invalid user merle from 14.161.45.187 port 56273 ssh2',
#  'Dec 13 00:11:46 submitty sshd[19777]: Received disconnect from 14.161.45.187 port 56273:11: Bye Bye [preauth]',
#  'Dec 13 00:11:46 submitty sshd[19777]: Disconnected from invalid user merle 14.161.45.187 port 56273 [preauth]',
#  'Dec 13 00:11:53 submitty sshd[19789]: Invalid user domain from 49.70.64.41 port 34474',
#  'Dec 13 00:11:53 submitty sshd[19789]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:11:53 submitty sshd[19789]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=49.70.64.41',
#  'Dec 13 00:11:54 submitty sshd[19796]: Invalid user ame from 129.211.138.177 port 53742',
#  'Dec 13 00:11:54 submitty sshd[19796]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:11:54 submitty sshd[19796]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=129.211.138.177',
#  'Dec 13 00:11:55 submitty sshd[19789]: Failed password for invalid user domain from 49.70.64.41 port 34474 ssh2',
#  'Dec 13 00:11:55 submitty sshd[19789]: Received disconnect from 49.70.64.41 port 34474:11: Bye Bye [preauth]',
#  'Dec 13 00:11:55 submitty sshd[19789]: Disconnected from invalid user domain 49.70.64.41 port 34474 [preauth]',
#  'Dec 13 00:11:56 submitty sshd[19796]: Failed password for invalid user ame from 129.211.138.177 port 53742 ssh2',
#  'Dec 13 00:11:56 submitty sshd[19796]: Received disconnect from 129.211.138.177 port 53742:11: Bye Bye [preauth]',
#  'Dec 13 00:11:56 submitty sshd[19796]: Disconnected from invalid user ame 129.211.138.177 port 53742 [preauth]',
#  "Dec 13 00:11:58 submitty sshd[19809]: warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#  'Dec 13 00:12:00 submitty sshd[19809]: Invalid user mysql from 185.156.74.65 port 2243',
#  'Dec 13 00:12:00 submitty sshd[19809]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:12:00 submitty sshd[19809]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#  'Dec 13 00:12:02 submitty sshd[19809]: Failed password for invalid user mysql from 185.156.74.65 port 2243 ssh2',
#  'Dec 13 00:12:02 submitty sshd[19809]: Connection closed by invalid user mysql 185.156.74.65 port 2243 [preauth]',
#  'Dec 13 00:12:41 submitty sshd[19833]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.93.207.88  user=root',
#  'Dec 13 00:12:43 submitty sshd[19833]: Failed password for root from 218.93.207.88 port 46251 ssh2',
#  'Dec 13 00:12:45 submitty sshd[19833]: Failed password for root from 218.93.207.88 port 46251 ssh2',
#  'Dec 13 00:12:54 submitty sshd[19848]: Invalid user klx from 103.152.101.19 port 60110',
#  'Dec 13 00:12:54 submitty sshd[19848]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:12:54 submitty sshd[19848]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=103.152.101.19',
#  'Dec 13 00:12:56 submitty sshd[19848]: Failed password for invalid user klx from 103.152.101.19 port 60110 ssh2',
#  'Dec 13 00:12:56 submitty sshd[19850]: Invalid user lionya from 61.181.80.253 port 60023',
#  'Dec 13 00:12:56 submitty sshd[19850]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:12:56 submitty sshd[19850]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=61.181.80.253',
#  'Dec 13 00:12:56 submitty sshd[19848]: Received disconnect from 103.152.101.19 port 60110:11: Bye Bye [preauth]',
#  'Dec 13 00:12:56 submitty sshd[19848]: Disconnected from invalid user klx 103.152.101.19 port 60110 [preauth]',
#  'Dec 13 00:12:58 submitty sshd[19850]: Failed password for invalid user lionya from 61.181.80.253 port 60023 ssh2',
#  'Dec 13 00:12:58 submitty sshd[19850]: Received disconnect from 61.181.80.253 port 60023:11: Bye Bye [preauth]',
#  'Dec 13 00:12:58 submitty sshd[19850]: Disconnected from invalid user lionya 61.181.80.253 port 60023 [preauth]',
#  'Dec 13 00:14:34 submitty sshd[19898]: Invalid user yarosh from 42.200.109.74 port 40276',
#  'Dec 13 00:14:34 submitty sshd[19898]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:14:34 submitty sshd[19898]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=42.200.109.74',
#  'Dec 13 00:14:36 submitty sshd[19898]: Failed password for invalid user yarosh from 42.200.109.74 port 40276 ssh2',
#  'Dec 13 00:14:51 submitty sshd[19915]: Received disconnect from 61.177.172.107 port 3678:11:  [preauth]',
#  'Dec 13 00:14:51 submitty sshd[19915]: Disconnected from 61.177.172.107 port 3678 [preauth]',
#  'Dec 13 00:14:55 submitty sshd[19917]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.221  user=root',
#  'Dec 13 00:14:58 submitty sshd[19917]: Failed password for root from 221.181.185.221 port 27415 ssh2',
#  'Dec 13 00:15:00 submitty sshd[19917]: Failed password for root from 221.181.185.221 port 27415 ssh2',
#  'Dec 13 00:15:03 submitty sshd[19917]: Failed password for root from 221.181.185.221 port 27415 ssh2',
#  'Dec 13 00:16:22 submitty sshd[19965]: Invalid user arkserver2 from 152.136.173.58 port 40782',
#  'Dec 13 00:16:22 submitty sshd[19965]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:16:22 submitty sshd[19965]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=152.136.173.58',
#  'Dec 13 00:16:24 submitty sshd[19965]: Failed password for invalid user arkserver2 from 152.136.173.58 port 40782 ssh2',
#  'Dec 13 00:16:24 submitty sshd[19965]: Received disconnect from 152.136.173.58 port 40782:11: Bye Bye [preauth]',
#  'Dec 13 00:16:24 submitty sshd[19965]: Disconnected from invalid user arkserver2 152.136.173.58 port 40782 [preauth]',
#  'Dec 13 00:17:15 submitty sshd[19998]: Invalid user named from 140.143.24.26 port 44024',
#  'Dec 13 00:17:15 submitty sshd[19998]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:17:15 submitty sshd[19998]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=140.143.24.26',
#  'Dec 13 00:17:17 submitty sshd[19998]: Failed password for invalid user named from 140.143.24.26 port 44024 ssh2',
#  'Dec 13 00:17:18 submitty sshd[19998]: Received disconnect from 140.143.24.26 port 44024:11: Bye Bye [preauth]',
#  'Dec 13 00:17:18 submitty sshd[19998]: Disconnected from invalid user named 140.143.24.26 port 44024 [preauth]',
#  'Dec 13 00:17:44 submitty sshd[20016]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.198  user=root',
#  'Dec 13 00:17:46 submitty sshd[20016]: Failed password for root from 218.92.0.198 port 18959 ssh2',
#  'Dec 13 00:17:51 submitty sshd[20016]: message repeated 2 times: [ Failed password for root from 218.92.0.198 port 18959 ssh2]',
#  'Dec 13 00:18:20 submitty sshd[20035]: Invalid user hkim from 124.160.96.249 port 35030']

# %% [markdown]
# ### Filter out the root fails

# %%
rootFails = fails.filter(lambda line: line.find("root") > 0)
rootFails.take(5)
# Out:
# ['Dec 13 00:06:16 submitty sshd[19509]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#  'Dec 13 00:06:17 submitty sshd[19509]: Failed password for root from 218.92.0.184 port 3753 ssh2',
#  'Dec 13 00:06:21 submitty sshd[19509]: Failed password for root from 218.92.0.184 port 3753 ssh2',
#  'Dec 13 00:10:35 submitty sshd[19716]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.247  user=root',
#  'Dec 13 00:10:36 submitty sshd[19716]: Failed password for root from 218.92.0.247 port 16026 ssh2']

# %% [markdown]
# ### Method to break down error message

# %%
import re
def breakdown_failed(entry):
    extracts = re.search(r'(?P<date>\w+\s+\d+) (?P<time>\d+:\d+:\d+) \S+ \S+\[(?P<proc>\d+)\]: ?(?P<msg>[\S ]+)', entry)
    return extracts.groups() if extracts else entry

# %% [markdown]
# ### Test ip address findings

# %%
import re
s = 'Dec 13 00:10:35 submitty sshd[19716]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.247  user=root'
breakdown_failed(s)
result = re.findall("\d+.\d+.\d+.\d+", breakdown_failed(s)[3])[0]
print(result)
# Out:
# 218.92.0.247

# %% [markdown]
# ### Ip address finder method

# %%
import re
def find_ip( line ):
    ip = re.findall("\d+.\d+.\d+.\d+", breakdown_failed(line)[3])
    if(len(ip) > 0):
        return ip[0]
    else:
        return ""

# %% [markdown]
# ### Testing ip address finder method

# %%
s = 'Dec 13 00:10:36 submitty sshd[19716]: Failed password for root from 218.92.0.247 port 16026 ssh2'
find_ip(s)
# Out:
# '218.92.0.247'

# %% [markdown]
# ### Gets each root fails ip address then sorts then by error message and ip address

# %%
import re
filterFails = rootFails.filter(lambda line: len(breakdown_failed(line)[3])>1)
rootFailsIPAddress = filterFails.map(lambda line: (find_ip(line), breakdown_failed(line)[3]))
rootFailsIPAddress.take(5)
# Out:
# [('218.92.0.184',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root'),
#  ('218.92.0.184', 'Failed password for root from 218.92.0.184 port 3753 ssh2'),
#  ('218.92.0.184', 'Failed password for root from 218.92.0.184 port 3753 ssh2'),
#  ('218.92.0.247',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.247  user=root'),
#  ('218.92.0.247',
#   'Failed password for root from 218.92.0.247 port 16026 ssh2')]

# %% [markdown]
# ### Takes a random sample of all the root error messages and ip addresses

# %%
rootFailsIPAddress.takeSample(False,50)
# Out:
# [('112.85.42.98',
#   'Failed password for root from 112.85.42.98 port 51872 ssh2'),
#  ('94.191.81.127',
#   'Failed password for root from 94.191.81.127 port 49870 ssh2'),
#  ('190.104.245.164',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=190.104.245.164  user=root'),
#  ('218.92.0.185',
#   'Failed password for root from 218.92.0.185 port 14143 ssh2'),
#  ('218.92.0.223',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.223  user=root'),
#  ('112.85.42.180',
#   'Failed password for root from 112.85.42.180 port 58609 ssh2'),
#  ('173.225.104.57',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=173.225.104.57  user=root'),
#  ('87.236.233.108',
#   'Disconnected from authenticating user root 87.236.233.108 port 15319 [preauth]'),
#  ('14.18.154.186',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=14.18.154.186  user=root'),
#  ('67.207.94.180',
#   'Failed password for root from 67.207.94.180 port 39768 ssh2'),
#  ('112.85.42.180',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=112.85.42.180  user=root'),
#  ('197.237.174.150',
#   'Connection closed by authenticating user root 197.237.174.150 port 33840 [preauth]'),
#  ('144.217.163.179',
#   'Disconnected from authenticating user root 144.217.163.179 port 56420 [preauth]'),
#  ('140.143.225.42',
#   'Failed password for root from 140.143.225.42 port 36818 ssh2'),
#  ('218.92.0.250',
#   'Failed password for root from 218.92.0.250 port 22057 ssh2'),
#  ('119.45.141.115',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=119.45.141.115  user=root'),
#  ('221.181.185.36',
#   'Failed password for root from 221.181.185.36 port 63937 ssh2'),
#  ('43.226.144.80',
#   'Disconnected from authenticating user root 43.226.144.80 port 53568 [preauth]'),
#  ('62.122.156.74',
#   'Failed password for root from 62.122.156.74 port 59416 ssh2'),
#  ('129.152.141.71',
#   'Disconnected from authenticating user root 129.152.141.71 port 16222 [preauth]'),
#  ('1.119.153.110',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=1.119.153.110  user=root'),
#  ('112.85.42.96',
#   'Failed password for root from 112.85.42.96 port 30452 ssh2'),
#  ('193.233.6.156',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=193.233.6.156  user=root'),
#  ('198.199.73.239',
#   'Disconnected from authenticating user root 198.199.73.239 port 35771 [preauth]'),
#  ('201.150.34.28',
#   'Disconnected from authenticating user root 201.150.34.28 port 35198 [preauth]'),
#  ('129.144.9.93',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=129.144.9.93  user=root'),
#  ('218.92.0.248',
#   'Failed password for root from 218.92.0.248 port 48599 ssh2'),
#  ('51.222.29.39',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=51.222.29.39  user=root'),
#  ('61.177.172.104',
#   'Failed password for root from 61.177.172.104 port 46136 ssh2'),
#  ('218.92.0.145',
#   'Failed password for root from 218.92.0.145 port 18086 ssh2'),
#  ('187.189.51.117',
#   'Disconnected from authenticating user root 187.189.51.117 port 56291 [preauth]'),
#  ('58.221.62.228',
#   'Failed password for root from 58.221.62.228 port 42710 ssh2'),
#  ('118.27.38.41',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=118.27.38.41  user=root'),
#  ('218.93.207.94',
#   'Failed password for root from 218.93.207.94 port 45420 ssh2'),
#  ('66.98.115.108',
#   'Failed password for root from 66.98.115.108 port 39692 ssh2'),
#  ('112.85.42.98',
#   'Failed password for root from 112.85.42.98 port 54180 ssh2'),
#  ('61.177.172.54',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=61.177.172.54  user=root'),
#  ('27.72.109.15',
#   'Disconnected from authenticating user root 27.72.109.15 port 24202 [preauth]'),
#  ('119.28.89.228',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=119.28.89.228  user=root'),
#  ('116.12.52.141',
#   'Failed password for root from 116.12.52.141 port 41540 ssh2'),
#  ('218.92.0.248',
#   'Failed password for root from 218.92.0.248 port 16315 ssh2'),
#  ('112.85.42.172',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=112.85.42.172  user=root'),
#  ('65.49.201.168',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=65.49.201.168  user=root'),
#  ('112.85.42.98',
#   'Failed password for root from 112.85.42.98 port 44752 ssh2'),
#  ('49.88.112.111',
#   'message repeated 2 times: [ Failed password for root from 49.88.112.111 port 58042 ssh2]'),
#  ('159.65.142.192',
#   'Disconnected from authenticating user root 159.65.142.192 port 39766 [preauth]'),
#  ('121.236.175.251',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=121.236.175.251  user=root'),
#  ('54.37.235.183',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=54.37.235.183  user=root'),
#  ('61.164.248.135',
#   'Failed password for root from 61.164.248.135 port 50634 ssh2'),
#  ('218.93.207.94',
#   'message repeated 2 times: [ Failed password for root from 218.93.207.94 port 37076 ssh2]')]

# %% [markdown]
# # Answer to how many root fails is 75630

# %%
rootFailsCount = rootFailsIPAddress.count()
print(rootFailsCount)
# Out:
# 75630

# %% [markdown]
# ### Gets only unique ip addresses

# %%
abc = rootFailsIPAddress.groupByKey().mapValues(list)
abc.take(10)
# Out:
# [('218.92.0.184',
#   ['pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 3753 ssh2',
#    'Failed password for root from 218.92.0.184 port 3753 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 51581 ssh2',
#    'Failed password for root from 218.92.0.184 port 51581 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 63832 ssh2',
#    'Failed password for root from 218.92.0.184 port 63832 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 6955 ssh2',
#    'Failed password for root from 218.92.0.184 port 6955 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 33633 ssh2',
#    'Failed password for root from 218.92.0.184 port 33633 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 31289 ssh2',
#    'Failed password for root from 218.92.0.184 port 31289 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 27041 ssh2',
#    'Failed password for root from 218.92.0.184 port 27041 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 45590 ssh2',
#    'Failed password for root from 218.92.0.184 port 45590 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 60288 ssh2',
#    'Failed password for root from 218.92.0.184 port 60288 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 40027 ssh2',
#    'Failed password for root from 218.92.0.184 port 40027 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 1711 ssh2',
#    'Failed password for root from 218.92.0.184 port 1711 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 16919 ssh2',
#    'Failed password for root from 218.92.0.184 port 16919 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 50323 ssh2',
#    'Failed password for root from 218.92.0.184 port 50323 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 38883 ssh2',
#    'Failed password for root from 218.92.0.184 port 38883 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 52986 ssh2',
#    'Failed password for root from 218.92.0.184 port 52986 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 54351 ssh2',
#    'Failed password for root from 218.92.0.184 port 54351 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 22540 ssh2',
#    'Failed password for root from 218.92.0.184 port 22540 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 37106 ssh2',
#    'Failed password for root from 218.92.0.184 port 37106 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 37407 ssh2',
#    'Failed password for root from 218.92.0.184 port 37407 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 56742 ssh2',
#    'Failed password for root from 218.92.0.184 port 56742 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 41009 ssh2',
#    'Failed password for root from 218.92.0.184 port 41009 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 59995 ssh2',
#    'Failed password for root from 218.92.0.184 port 59995 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 47626 ssh2',
#    'Failed password for root from 218.92.0.184 port 47626 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 51513 ssh2',
#    'Failed password for root from 218.92.0.184 port 51513 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 15082 ssh2',
#    'Failed password for root from 218.92.0.184 port 15082 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 25960 ssh2',
#    'Failed password for root from 218.92.0.184 port 25960 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 60325 ssh2',
#    'Failed password for root from 218.92.0.184 port 60325 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 17274 ssh2',
#    'Failed password for root from 218.92.0.184 port 17274 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 31971 ssh2',
#    'Failed password for root from 218.92.0.184 port 31971 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 19898 ssh2',
#    'Failed password for root from 218.92.0.184 port 19898 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 6664 ssh2',
#    'Failed password for root from 218.92.0.184 port 6664 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 60598 ssh2',
#    'Failed password for root from 218.92.0.184 port 60598 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 21803 ssh2',
#    'Failed password for root from 218.92.0.184 port 21803 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 33004 ssh2',
#    'Failed password for root from 218.92.0.184 port 33004 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 36790 ssh2',
#    'Failed password for root from 218.92.0.184 port 36790 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 60420 ssh2',
#    'Failed password for root from 218.92.0.184 port 60420 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 33008 ssh2',
#    'Failed password for root from 218.92.0.184 port 33008 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 5962 ssh2',
#    'Failed password for root from 218.92.0.184 port 5962 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 19764 ssh2',
#    'Failed password for root from 218.92.0.184 port 19764 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 58859 ssh2',
#    'Failed password for root from 218.92.0.184 port 58859 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 18537 ssh2',
#    'Failed password for root from 218.92.0.184 port 18537 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 60722 ssh2',
#    'Failed password for root from 218.92.0.184 port 60722 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 22656 ssh2',
#    'Failed password for root from 218.92.0.184 port 22656 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 64389 ssh2',
#    'Failed password for root from 218.92.0.184 port 64389 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 52502 ssh2',
#    'Failed password for root from 218.92.0.184 port 52502 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 12958 ssh2',
#    'Failed password for root from 218.92.0.184 port 12958 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 14574 ssh2',
#    'Failed password for root from 218.92.0.184 port 14574 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 52957 ssh2',
#    'Failed password for root from 218.92.0.184 port 52957 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 32225 ssh2',
#    'Failed password for root from 218.92.0.184 port 32225 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 45267 ssh2',
#    'Failed password for root from 218.92.0.184 port 45267 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 29529 ssh2',
#    'Failed password for root from 218.92.0.184 port 29529 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 12906 ssh2',
#    'Failed password for root from 218.92.0.184 port 12906 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 42250 ssh2',
#    'Failed password for root from 218.92.0.184 port 42250 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 54073 ssh2',
#    'Failed password for root from 218.92.0.184 port 54073 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 4185 ssh2',
#    'Failed password for root from 218.92.0.184 port 4185 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 62622 ssh2',
#    'Failed password for root from 218.92.0.184 port 62622 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 17336 ssh2',
#    'Failed password for root from 218.92.0.184 port 17336 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 48426 ssh2',
#    'Failed password for root from 218.92.0.184 port 48426 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 7115 ssh2',
#    'Failed password for root from 218.92.0.184 port 7115 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 59878 ssh2',
#    'Failed password for root from 218.92.0.184 port 59878 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 25905 ssh2',
#    'Failed password for root from 218.92.0.184 port 25905 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 43128 ssh2',
#    'Failed password for root from 218.92.0.184 port 43128 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 11427 ssh2',
#    'Failed password for root from 218.92.0.184 port 11427 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 44976 ssh2',
#    'Failed password for root from 218.92.0.184 port 44976 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 14937 ssh2',
#    'Failed password for root from 218.92.0.184 port 14937 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 65437 ssh2',
#    'Failed password for root from 218.92.0.184 port 65437 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 44392 ssh2',
#    'Failed password for root from 218.92.0.184 port 44392 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 18964 ssh2',
#    'Failed password for root from 218.92.0.184 port 18964 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 11327 ssh2',
#    'Failed password for root from 218.92.0.184 port 11327 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 63652 ssh2',
#    'Failed password for root from 218.92.0.184 port 63652 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 14848 ssh2',
#    'Failed password for root from 218.92.0.184 port 14848 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 43901 ssh2',
#    'Failed password for root from 218.92.0.184 port 43901 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 10822 ssh2',
#    'Failed password for root from 218.92.0.184 port 10822 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 3456 ssh2',
#    'Failed password for root from 218.92.0.184 port 3456 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 52288 ssh2',
#    'Failed password for root from 218.92.0.184 port 52288 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 14145 ssh2',
#    'Failed password for root from 218.92.0.184 port 14145 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 24934 ssh2',
#    'Failed password for root from 218.92.0.184 port 24934 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 26285 ssh2',
#    'Failed password for root from 218.92.0.184 port 26285 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 23954 ssh2',
#    'Failed password for root from 218.92.0.184 port 23954 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 62158 ssh2',
#    'Failed password for root from 218.92.0.184 port 62158 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 54821 ssh2',
#    'Failed password for root from 218.92.0.184 port 54821 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 42804 ssh2',
#    'Failed password for root from 218.92.0.184 port 42804 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 43292 ssh2',
#    'Failed password for root from 218.92.0.184 port 43292 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 7956 ssh2',
#    'Failed password for root from 218.92.0.184 port 7956 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 3951 ssh2',
#    'Failed password for root from 218.92.0.184 port 3951 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 19705 ssh2',
#    'Failed password for root from 218.92.0.184 port 19705 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 35591 ssh2',
#    'Failed password for root from 218.92.0.184 port 35591 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 58695 ssh2',
#    'Failed password for root from 218.92.0.184 port 58695 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 6232 ssh2',
#    'Failed password for root from 218.92.0.184 port 6232 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 5201 ssh2',
#    'Failed password for root from 218.92.0.184 port 5201 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 28143 ssh2',
#    'Failed password for root from 218.92.0.184 port 28143 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 25775 ssh2',
#    'Failed password for root from 218.92.0.184 port 25775 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 27578 ssh2',
#    'Failed password for root from 218.92.0.184 port 27578 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 55230 ssh2',
#    'Failed password for root from 218.92.0.184 port 55230 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 3276 ssh2',
#    'message repeated 2 times: [ Failed password for root from 218.92.0.184 port 3276 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 62416 ssh2',
#    'Failed password for root from 218.92.0.184 port 62416 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 2070 ssh2',
#    'Failed password for root from 218.92.0.184 port 2070 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 35944 ssh2',
#    'Failed password for root from 218.92.0.184 port 35944 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 49542 ssh2',
#    'Failed password for root from 218.92.0.184 port 49542 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 5330 ssh2',
#    'Failed password for root from 218.92.0.184 port 5330 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 17138 ssh2',
#    'Failed password for root from 218.92.0.184 port 17138 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 60401 ssh2',
#    'Failed password for root from 218.92.0.184 port 60401 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 14196 ssh2',
#    'Failed password for root from 218.92.0.184 port 14196 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 33219 ssh2',
#    'Failed password for root from 218.92.0.184 port 33219 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 32540 ssh2',
#    'Failed password for root from 218.92.0.184 port 32540 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 7959 ssh2',
#    'Failed password for root from 218.92.0.184 port 7959 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 51169 ssh2',
#    'Failed password for root from 218.92.0.184 port 51169 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 1982 ssh2',
#    'Failed password for root from 218.92.0.184 port 1982 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 50651 ssh2',
#    'Failed password for root from 218.92.0.184 port 50651 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 52612 ssh2',
#    'Failed password for root from 218.92.0.184 port 52612 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 35644 ssh2',
#    'Failed password for root from 218.92.0.184 port 35644 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 57199 ssh2',
#    'Failed password for root from 218.92.0.184 port 57199 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 44016 ssh2',
#    'Failed password for root from 218.92.0.184 port 44016 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 3554 ssh2',
#    'Failed password for root from 218.92.0.184 port 3554 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 7462 ssh2',
#    'Failed password for root from 218.92.0.184 port 7462 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 9054 ssh2',
#    'Failed password for root from 218.92.0.184 port 9054 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 29464 ssh2',
#    'Failed password for root from 218.92.0.184 port 29464 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 58716 ssh2',
#    'Failed password for root from 218.92.0.184 port 58716 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 62969 ssh2',
#    'Failed password for root from 218.92.0.184 port 62969 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 49792 ssh2',
#    'Failed password for root from 218.92.0.184 port 49792 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 29569 ssh2',
#    'Failed password for root from 218.92.0.184 port 29569 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 32407 ssh2',
#    'Failed password for root from 218.92.0.184 port 32407 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 32053 ssh2',
#    'Failed password for root from 218.92.0.184 port 32053 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 33036 ssh2',
#    'Failed password for root from 218.92.0.184 port 33036 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=218.92.0.184  user=root',
#    'Failed password for root from 218.92.0.184 port 28054 ssh2',
#    'Failed password for root from 218.92.0.184 port 28054 ssh2']),
#  ('221.131.165.81',
#   ['pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 24832 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 24832 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 32685 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 32685 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 16739 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 16739 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 25714 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 25714 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 23632 ssh2',
#    'Failed password for root from 221.131.165.81 port 23632 ssh2',
#    'Failed password for root from 221.131.165.81 port 23632 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 19717 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 19717 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 33305 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 33305 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 17925 ssh2',
#    'Failed password for root from 221.131.165.81 port 17925 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 64563 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 64563 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 12155 ssh2',
#    'Failed password for root from 221.131.165.81 port 12155 ssh2',
#    'Failed password for root from 221.131.165.81 port 12155 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 42843 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 42843 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 11246 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 11246 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 28236 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 28236 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 58580 ssh2',
#    'Failed password for root from 221.131.165.81 port 58580 ssh2',
#    'Failed password for root from 221.131.165.81 port 58580 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 29906 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 29906 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 37143 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 37143 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 46914 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 46914 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 55558 ssh2',
#    'Failed password for root from 221.131.165.81 port 55558 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 41968 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 41968 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 53068 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 53068 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 41913 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 41913 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 49296 ssh2',
#    'Failed password for root from 221.131.165.81 port 49296 ssh2',
#    'Failed password for root from 221.131.165.81 port 49296 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 37732 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 37732 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 20592 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 20592 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 53694 ssh2',
#    'Failed password for root from 221.131.165.81 port 53694 ssh2',
#    'Failed password for root from 221.131.165.81 port 53694 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 12766 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 12766 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 59618 ssh2',
#    'Failed password for root from 221.131.165.81 port 59618 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 29753 ssh2',
#    'Failed password for root from 221.131.165.81 port 29753 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 60015 ssh2',
#    'Failed password for root from 221.131.165.81 port 60015 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 18244 ssh2',
#    'Failed password for root from 221.131.165.81 port 18244 ssh2',
#    'Failed password for root from 221.131.165.81 port 18244 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 42443 ssh2',
#    'Failed password for root from 221.131.165.81 port 42443 ssh2',
#    'Failed password for root from 221.131.165.81 port 42443 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 31725 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 31725 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 54543 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 54543 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 15294 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 15294 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 40564 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 40564 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 50081 ssh2',
#    'Failed password for root from 221.131.165.81 port 50081 ssh2',
#    'Failed password for root from 221.131.165.81 port 50081 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 41210 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 41210 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 20279 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 20279 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 29629 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 29629 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 48529 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 48529 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 44798 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 44798 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 44291 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 44291 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 21065 ssh2',
#    'Failed password for root from 221.131.165.81 port 21065 ssh2',
#    'Failed password for root from 221.131.165.81 port 21065 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 60491 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 60491 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 29087 ssh2',
#    'Failed password for root from 221.131.165.81 port 29087 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 57064 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 57064 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 36873 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 36873 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 58583 ssh2',
#    'Failed password for root from 221.131.165.81 port 58583 ssh2',
#    'Failed password for root from 221.131.165.81 port 58583 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 49474 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 49474 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 16635 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.131.165.81 port 16635 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.131.165.81  user=root',
#    'Failed password for root from 221.131.165.81 port 29235 ssh2',
#    'Failed password for root from 221.131.165.81 port 29235 ssh2',
#    'Failed password for root from 221.131.165.81 port 29235 ssh2']),
#  ('222.187.222.53',
#   ['pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=222.187.222.53  user=root',
#    'Failed password for root from 222.187.222.53 port 44933 ssh2',
#    'Failed password for root from 222.187.222.53 port 44933 ssh2',
#    'Failed password for root from 222.187.222.53 port 44933 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=222.187.222.53  user=root',
#    'Failed password for root from 222.187.222.53 port 53398 ssh2',
#    'Failed password for root from 222.187.222.53 port 53398 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=222.187.222.53  user=root',
#    'Failed password for root from 222.187.222.53 port 49724 ssh2',
#    'message repeated 2 times: [ Failed password for root from 222.187.222.53 port 49724 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=222.187.222.53  user=root',
#    'Failed password for root from 222.187.222.53 port 57473 ssh2',
#    'message repeated 2 times: [ Failed password for root from 222.187.222.53 port 57473 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=222.187.222.53  user=root',
#    'Failed password for root from 222.187.222.53 port 22834 ssh2',
#    'message repeated 2 times: [ Failed password for root from 222.187.222.53 port 22834 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=222.187.222.53  user=root',
#    'Failed password for root from 222.187.222.53 port 20150 ssh2',
#    'Failed password for root from 222.187.222.53 port 20150 ssh2',
#    'Failed password for root from 222.187.222.53 port 20150 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=222.187.222.53  user=root',
#    'Failed password for root from 222.187.222.53 port 51907 ssh2',
#    'message repeated 2 times: [ Failed password for root from 222.187.222.53 port 51907 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=222.187.222.53  user=root',
#    'Failed password for root from 222.187.222.53 port 60197 ssh2',
# ...
#    'Failed password for root from 221.181.185.198 port 36186 ssh2',
#    'Failed password for root from 221.181.185.198 port 36186 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 29284 ssh2',
#    'Failed password for root from 221.181.185.198 port 29284 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 14633 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 14633 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 33750 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 33750 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 63741 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 63741 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 19354 ssh2',
#    'Failed password for root from 221.181.185.198 port 19354 ssh2',
#    'Failed password for root from 221.181.185.198 port 19354 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 50779 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 50779 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 28243 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 28243 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 23999 ssh2',
#    'Failed password for root from 221.181.185.198 port 23999 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 60767 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 60767 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 45306 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 45306 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 58867 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 58867 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 61907 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 61907 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 53173 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 53173 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 58444 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 58444 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 63821 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 63821 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 60665 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 60665 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 55711 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 55711 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 56245 ssh2',
#    'Failed password for root from 221.181.185.198 port 56245 ssh2',
#    'Failed password for root from 221.181.185.198 port 56245 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 20328 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 20328 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 41673 ssh2',
#    'Failed password for root from 221.181.185.198 port 41673 ssh2',
#    'Failed password for root from 221.181.185.198 port 41673 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 22769 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 22769 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 27362 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 27362 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 24914 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 24914 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 56759 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 56759 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 22369 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 22369 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 10322 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 10322 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 37808 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 37808 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 42057 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 42057 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 38417 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 38417 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 11185 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 11185 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 13511 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 13511 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 41665 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 41665 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 49689 ssh2',
#    'Failed password for root from 221.181.185.198 port 49689 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 52458 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 52458 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 14431 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 14431 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 37614 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 37614 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 36638 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 36638 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 11840 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 11840 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 28447 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 28447 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 42649 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 42649 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 16785 ssh2',
#    'Failed password for root from 221.181.185.198 port 16785 ssh2',
#    'Failed password for root from 221.181.185.198 port 16785 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 34006 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 34006 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 42159 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 42159 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 55168 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 55168 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 17992 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 17992 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 34266 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 34266 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 60180 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 60180 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 31017 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 31017 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 14723 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 14723 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 46130 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 46130 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 32063 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 32063 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 43161 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 43161 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 49251 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 49251 ssh2]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 57052 ssh2',
#    'Failed password for root from 221.181.185.198 port 57052 ssh2',
#    'Failed password for root from 221.181.185.198 port 57052 ssh2',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=221.181.185.198  user=root',
#    'Failed password for root from 221.181.185.198 port 39210 ssh2',
#    'message repeated 2 times: [ Failed password for root from 221.181.185.198 port 39210 ssh2]'])]

# %% [markdown]
# ### Lists just the unique ip addresses

# %%
rootFailsAddress = abc.map(lambda group: group[0])
rootFailsAddress.take(10)
# Out:
# ['218.92.0.184',
#  '221.131.165.81',
#  '222.187.222.53',
#  '222.187.238.87',
#  '221.181.185.18',
#  '112.85.42.96',
#  '185.156.74.65',
#  '221.181.185.200',
#  '218.92.0.249',
#  '221.181.185.198']

# %%
#import re
#ip6Addresses = rootFailsAddress.map(lambda line: line.replace(".", ""))
#ip6Addresses.collect()

# %% [markdown]
# ### Practice splitting by dot

# %%
s = '218.92.0.184'
s.split('.')
# Out:
# ['218', '92', '0', '184']

# %% [markdown]
# ### Splits all ip addresses by dot

# %%
rootIPAddressSplit = rootFailsAddress.map(lambda line: line.split('.'))
rootIPAddressSplit.collect()
# Out:
# [['218', '92', '0', '184'],
#  ['221', '131', '165', '81'],
#  ['222', '187', '222', '53'],
#  ['222', '187', '238', '87'],
#  ['221', '181', '185', '18'],
#  ['112', '85', '42', '96'],
#  ['185', '156', '74', '65'],
#  ['221', '181', '185', '200'],
#  ['218', '92', '0', '249'],
#  ['221', '181', '185', '198'],
#  ['218', '92', '0', '248'],
#  ['213', '32', '111', '53'],
#  ['222', '187', '222', '105'],
#  ['111', '231', '88', '39'],
#  ['218', '92', '0', '171'],
#  ['112', '85', '42', '85'],
#  ['128', '201', '76', '184'],
#  ['40', '87', '87', '198'],
#  ['142', '93', '254', '122'],
#  ['193', '169', '252', '59'],
#  ['119', '45', '26', '117'],
#  ['221', '181', '185', '143'],
#  ['49', '235', '11', '137'],
#  ['221', '181', '185', '149'],
#  ['183', '82', '102', '66'],
#  ['0 106', '12', '31'],
#  ['222', '187', '227', '224'],
#  ['103', '43', '185', '142'],
#  ['51', '195', '42', '242'],
#  ['148', '245', '13', '21'],
#  ['45', '82', '137', '35'],
#  ['167', '71', '1', '6'],
#  ['81', '68', '238', '7'],
#  ['112', '85', '42', '232'],
#  ['146', '59', '157', '181'],
#  ['111', '90', '190', '52'],
#  ['49', '234', '94', '59'],
#  ['183', '6', '107', '68'],
#  ['120', '203', '160', '18'],
#  ['144', '34', '193', '83'],
#  ['190', '144', '139', '76'],
#  ['42', '248', '78', '4'],
#  ['161', '35', '118', '14'],
#  ['190', '55', '5', '142'],
#  ['115', '159', '90', '184'],
#  ['80', '98', '150', '9'],
#  ['116', '92', '219', '162'],
#  ['143', '110', '250', '97'],
#  ['140', '143', '144', '140'],
#  ['188', '166', '187', '179'],
#  ['119', '28', '51', '99'],
#  ['5', '232', '197', '241'],
#  ['61', '160', '251', '98'],
#  ['118', '89', '248', '224'],
#  ['177', '220', '189', '111'],
#  ['96', '45', '173', '209'],
#  ['46', '101', '173', '231'],
#  ['60', '246', '171', '51'],
#  ['112', '78', '3', '39'],
#  ['109', '77', '135', '217'],
#  ['190', '64', '213', '155'],
#  ['117', '51', '150', '202'],
#  ['222', '112', '220', '12'],
#  ['101', '206', '162', '208'],
#  ['179', '211', '32', '189'],
#  ['157', '230', '220', '179'],
#  ['103', '63', '108', '25'],
#  ['161', '35', '30', '208'],
#  ['111', '230', '244', '13'],
#  ['76', '233', '80', '93'],
#  ['187', '162', '61', '184'],
#  ['27', '199', '140', '25'],
#  ['122', '51', '154', '84'],
#  ['139', '59', '10', '186'],
#  ['161', '189', '157', '7'],
#  ['111', '93', '2', '53'],
#  ['193', '70', '0', '228'],
#  ['111', '231', '199', '243'],
#  ['45', '151', '88', '213'],
#  ['101', '231', '146', '36'],
#  ['125', '89', '20', '89'],
#  ['106', '13', '94', '131'],
#  ['46', '101', '154', '242'],
#  ['200', '27', '212', '22'],
#  ['113', '76', '17', '95'],
#  ['119', '45', '184', '182'],
#  ['66', '143', '231', '89'],
#  ['106', '12', '132', '224'],
#  ['146', '185', '180', '57'],
#  ['140', '143', '0', '121'],
#  ['104', '131', '249', '57'],
#  ['191', '31', '104', '17'],
#  ['139', '59', '255', '166'],
#  ['49', '247', '213', '18'],
#  ['150', '158', '212', '170'],
#  ['162', '62', '26', '122'],
#  ['81', '68', '208', '67'],
#  ['206', '189', '128', '215'],
#  ['200', '70', '56', '204'],
#  ['213', '32', '111', '52'],
#  ['196', '220', '67', '2'],
#  ['158', '69', '220', '67'],
#  ['118', '27', '25', '231'],
#  ['51', '75', '131', '235'],
#  ['42', '3', '50', '109'],
#  ['77', '27', '69', '62'],
#  ['5', '62', '23', '10'],
#  ['115', '23', '81', '101'],
#  ['185', '166', '118', '140'],
#  ['104', '171', '52', '252'],
#  ['62', '152', '29', '130'],
#  ['121', '151', '228', '194'],
#  ['92', '251', '6', '61'],
#  ['149', '202', '56', '228'],
#  ['58', '250', '45', '39'],
#  ['176', '107', '57', '104'],
#  ['119', '194', '205', '9'],
#  ['218', '210', '38', '237'],
#  ['190', '140', '118', '186'],
#  ['77', '121', '241', '104'],
#  ['78', '85', '5', '188'],
#  ['210', '209', '200', '101'],
#  ['58', '176', '152', '92'],
#  ['189', '78', '87', '179'],
#  ['113', '252', '225', '104'],
#  ['190', '78', '46', '141'],
#  ['60', '246', '182', '86'],
#  ['178', '44', '245', '198'],
#  ['46', '21', '54', '122'],
#  ['109', '228', '130', '65'],
#  ['151', '127', '43', '175'],
#  ['157', '230', '119', '220'],
#  ['116', '103', '247', '48'],
#  ['3 49', '233', '14'],
#  ['177', '139', '194', '62'],
#  ['159', '65', '98', '176'],
#  ['104', '236', '124', '45'],
#  ['101', '36', '173', '44'],
#  ['13', '82', '24', '91'],
#  ['51', '83', '129', '228'],
#  ['42', '194', '210', '230'],
#  ['157', '92', '13', '155'],
#  ['167', '99', '110', '179'],
#  ['67', '207', '89', '137'],
#  ['144', '217', '163', '179'],
#  ['190', '98', '228', '54'],
#  ['103', '26', '136', '173'],
#  ['95', '165', '26', '27'],
#  ['106', '51', '73', '204'],
#  ['136', '228', '161', '67'],
#  ['200', '6', '137', '235'],
#  ['79', '120', '54', '174'],
#  ['159', '65', '238', '245'],
#  ['87', '98', '182', '93'],
#  ['3', '112', '67', '81'],
#  ['202', '109', '158', '139'],
#  ['68', '183', '215', '41'],
#  ['165', '227', '63', '165'],
#  ['49', '234', '94', '200'],
#  ['111', '229', '1', '180'],
#  ['134', '73', '154', '173'],
#  ['51', '83', '68', '213'],
#  ['190', '104', '149', '194'],
#  ['193', '112', '85', '35'],
#  ['67', '216', '209', '28'],
#  ['138', '197', '167', '213'],
#  ['120', '53', '118', '140'],
#  ['165', '22', '57', '175'],
#  ['106', '12', '28', '152'],
#  ['120', '92', '119', '90'],
#  ['49', '51', '163', '133'],
#  ['49', '233', '30', '96'],
#  ['80', '52', '72', '24'],
#  ['128', '199', '206', '90'],
#  ['1', '119', '153', '110'],
#  ['198', '199', '73', '239'],
#  ['109', '227', '63', '3'],
#  ['117', '192', '46', '40'],
#  ['119', '45', '42', '241'],
#  ['159', '89', '48', '31'],
#  ['118', '97', '23', '26'],
#  ['165', '22', '215', '99'],
#  ['197', '156', '65', '138'],
#  ['111', '229', '134', '68'],
#  ['160', '20', '200', '234'],
#  ['13', '71', '46', '226'],
#  ['104', '192', '6', '17'],
#  ['181', '111', '181', '50'],
#  ['125', '35', '92', '130'],
#  ['133', '167', '95', '209'],
#  ['134', '175', '218', '239'],
#  ['122', '51', '40', '61'],
#  ['46', '37', '188', '139'],
#  ['51', '210', '96', '169'],
#  ['128', '199', '31', '95'],
#  ['161', '117', '56', '255'],
#  ['95', '227', '234', '14'],
#  ['178', '128', '127', '62'],
#  ['217', '182', '141', '253'],
#  ['49', '234', '224', '88'],
#  ['73', '89', '52', '125'],
#  ['14', '56', '180', '103'],
#  ['49', '235', '221', '172'],
#  ['165', '227', '7', '187'],
#  ['159', '203', '72', '14'],
#  ['51', '210', '190', '104'],
#  ['119', '29', '102', '152'],
#  ['159', '65', '147', '235'],
#  ['119', '29', '177', '222'],
#  ['94', '191', '38', '203'],
#  ['159', '89', '237', '57'],
#  ['103', '56', '43', '225'],
#  ['54', '38', '65', '55'],
#  ['60', '191', '29', '210'],
#  ['123', '231', '160', '98'],
#  ['200', '96', '49', '76'],
#  ['52', '152', '238', '18'],
#  ['45', '116', '35', '165'],
#  ['195', '228', '148', '10'],
#  ['128', '199', '95', '60'],
#  ['49', '232', '111', '165'],
#  ['49', '234', '181', '60'],
#  ['106', '75', '132', '3'],
#  ['187', '189', '65', '241'],
#  ['175', '24', '187', '87'],
#  ['165', '22', '63', '151'],
#  ['201', '187', '41', '255'],
#  ['139', '155', '239', '207'],
#  ['182', '61', '173', '200'],
#  ['103', '40', '8', '185'],
#  ['113', '246', '243', '65'],
#  ['91', '122', '159', '193'],
#  ['13', '72', '64', '49'],
#  ['103', '233', '2', '162'],
#  ['165', '22', '208', '192'],
#  ['27', '115', '50', '114'],
#  ['176', '118', '216', '227'],
#  ['91', '121', '67', '151'],
#  ['222', '117', '13', '84'],
#  ['121', '227', '0', '17'],
#  ['61', '181', '80', '253'],
#  ['104', '248', '63', '30'],
#  ['101', '32', '46', '20'],
#  ['5', '196', '70', '107'],
#  ['51', '68', '190', '223'],
#  ['51', '68', '94', '206'],
#  ['176', '124', '59', '32'],
#  ['106', '54', '236', '226'],
#  ['157', '230', '212', '3'],
#  ['152', '250', '43', '54'],
#  ['190', '245', '22', '47'],
#  ['46', '146', '240', '185'],
#  ['14', '98', '117', '60'],
#  ['116', '255', '216', '34'],
#  ['113', '31', '113', '99'],
#  ['145', '239', '23', '254'],
#  ['159', '65', '78', '3'],
#  ['179', '174', '50', '74'],
#  ['51', '77', '223', '17'],
#  ['64', '227', '77', '253'],
#  ['139', '198', '121', '63'],
#  ['51', '178', '27', '206'],
#  ['148', '70', '118', '113'],
#  ['187', '17', '48', '86'],
#  ['51', '158', '189', '0'],
#  ['111', '92', '61', '220'],
#  ['45', '240', '88', '35'],
#  ['129', '226', '134', '163'],
#  ['66', '150', '71', '32'],
#  ['218', '89', '222', '16'],
#  ['49', '235', '132', '88'],
#  ['103', '105', '130', '136'],
#  ['106', '124', '131', '70'],
#  ['101', '187', '123', '101'],
#  ['81', '71', '26', '161'],
#  ['43', '229', '153', '76'],
#  ['212', '64', '77', '173'],
#  ['118', '25', '195', '244'],
#  ['220', '92', '137', '31'],
#  ['167', '99', '110', '42'],
#  ['198', '27', '82', '155'],
#  ['106', '12', '153', '211'],
#  ['172', '81', '240', '237'],
#  ['206', '189', '93', '218'],
#  ['106', '75', '240', '86'],
#  ['202', '147', '192', '242'],
#  ['103', '144', '180', '18'],
#  ['5', '160', '52', '130'],
#  ['122', '51', '149', '86'],
#  ['54', '38', '183', '181'],
#  ['196', '38', '70', '24'],
#  ['125', '65', '79', '161'],
#  ['36', '133', '109', '2'],
#  ['111', '95', '141', '34'],
#  ['140', '249', '205', '149'],
#  ['1 223', '247', '185'],
#  ['34', '70', '217', '179'],
#  ['167', '71', '46', '139'],
#  ['58', '87', '119', '220'],
#  ['113', '110', '166', '134'],
#  ['51', '68', '189', '69'],
#  ['106', '12', '207', '236'],
#  ['46', '182', '19', '49'],
#  ['188', '165', '56', '214'],
#  ['157', '245', '108', '35'],
#  ['132', '232', '84', '44'],
#  ['159', '89', '196', '75'],
#  ['106', '12', '218', '171'],
#  ['115', '159', '98', '28'],
#  ['136', '232', '226', '202'],
#  ['161', '35', '11', '118'],
#  ['103', '45', '107', '149'],
#  ['119', '61', '19', '87'],
#  ['51', '222', '29', '39'],
#  ['46', '218', '7', '227'],
#  ['203', '135', '20', '36'],
#  ['49', '232', '119', '253'],
#  ['49', '232', '56', '88'],
#  ['45', '55', '88', '16'],
#  ['106', '116', '118', '90'],
#  ['129', '211', '77', '44'],
#  ['106', '52', '132', '186'],
#  ['34', '101', '193', '173'],
#  ['212', '64', '80', '169'],
#  ['200', '116', '188', '62'],
#  ['192', '241', '139', '236'],
#  ['197', '5', '145', '27'],
#  ['179', '43', '60', '1'],
#  ['222', '128', '14', '106'],
#  ['159', '89', '202', '95'],
#  ['185', '152', '151', '10'],
#  ['183', '221', '243', '20'],
#  ['194', '156', '184', '28'],
#  ['159', '203', '85', '196'],
#  ['2', '82', '175', '119'],
#  ['185', '51', '76', '199'],
#  ['124', '156', '225', '159'],
#  ['129', '204', '115', '121'],
#  ['159', '65', '142', '192'],
#  ['148', '66', '143', '140'],
#  ['119', '28', '89', '228'],
#  ['106', '53', '202', '86'],
#  ['59', '125', '145', '88'],
#  ['142', '93', '103', '141'],
#  ['106', '12', '33', '195'],
#  ['119', '45', '140', '59'],
#  ['103', '42', '214', '18'],
#  ['200', '95', '239', '22'],
#  ['179', '210', '169', '148'],
#  ['79', '127', '36', '98'],
#  ['167', '99', '14', '237'],
#  ['61', '133', '232', '248'],
#  ['61', '133', '232', '253'],
#  ['128', '199', '170', '33'],
#  ['49', '234', '25', '89'],
#  ['165', '227', '144', '49'],
#  ['147', '147', '84', '206'],
#  ['129', '204', '45', '118'],
#  ['189', '203', '72', '138'],
#  ['67', '216', '223', '29'],
#  ['109', '160', '22', '211'],
#  ['23', '97', '155', '197'],
#  ['59', '144', '48', '34'],
#  ['139', '59', '159', '0'],
#  ['119', '28', '60', '45'],
#  ['199', '115', '228', '202'],
#  ['51', '178', '24', '61'],
#  ['171', '244', '139', '236'],
#  ['91', '207', '40', '45'],
#  ['161', '35', '148', '75'],
#  ['104', '214', '34', '1'],
#  ['161', '97', '64', '180'],
#  ['190', '52', '34', '43'],
#  ['150', '109', '114', '58'],
#  ['41', '226', '28', '83'],
#  ['118', '24', '142', '170'],
#  ['197', '5', '145', '102'],
#  ['220', '88', '1', '208'],
#  ['101', '32', '45', '10'],
#  ['139', '199', '94', '100'],
#  ['210', '104', '112', '207'],
#  ['129', '28', '157', '199'],
#  ['72', '42', '162', '79'],
#  ['119', '45', '205', '97'],
#  ['68', '183', '238', '175'],
#  ['49', '234', '107', '24'],
#  ['59', '27', '124', '26'],
#  ['114', '99', '232', '2'],
#  ['49', '233', '15', '54'],
#  ['14', '232', '214', '138'],
#  ['222', '252', '30', '29'],
#  ['218', '249', '73', '54'],
#  ['1', '11', '201', '18'],
#  ['51', '210', '5', '171'],
#  ['185', '123', '164', '54'],
#  ['79', '168', '204', '180'],
#  ['178', '212', '144', '5'],
#  ['51', '77', '213', '136'],
#  ['106', '12', '80', '246'],
#  ['67', '205', '163', '45'],
#  ['138', '68', '184', '70'],
#  ['62', '92', '48', '242'],
#  ['111', '229', '26', '25'],
#  ['165', '22', '68', '84'],
#  ['181', '55', '95', '52'],
#  ['222', '75', '1', '197'],
#  ['103', '42', '214', '128'],
#  ['195', '245', '239', '83'],
#  ['114', '231', '82', '30'],
#  ['103', '76', '252', '6'],
#  ['125', '99', '72', '27'],
#  ['34', '82', '103', '75'],
#  ['93', '117', '174', '151'],
#  ['183', '129', '159', '211'],
#  ['190', '85', '67', '171'],
#  ['110', '164', '189', '53'],
#  ['77', '199', '194', '217'],
#  ['137', '74', '198', '18'],
#  ['106', '55', '4', '113'],
#  ['222', '190', '145', '130'],
#  ['220', '247', '201', '109'],
#  ['118', '25', '24', '84'],
#  ['46', '101', '224', '184'],
#  ['13', '71', '21', '123'],
#  ['51', '178', '80', '229'],
#  ['107', '175', '150', '83'],
#  ['81', '68', '176', '101'],
#  ['14', '232', '210', '96'],
#  ['181', '48', '46', '195'],
#  ['115', '77', '188', '228'],
#  ['106', '13', '207', '205'],
#  ['81', '68', '198', '31'],
#  ['159', '89', '38', '228'],
#  ['118', '89', '63', '234'],
#  ['212', '47', '230', '238'],
#  ['167', '99', '109', '254'],
#  ['176', '235', '192', '133'],
#  ['129', '28', '14', '23'],
#  ['23', '105', '215', '254'],
#  ['95', '182', '120', '176'],
#  ['193', '112', '213', '187'],
#  ['49', '247', '204', '78'],
#  ['18', '221', '29', '76'],
#  ['112', '85', '42', '143'],
#  ['13', '49', '16', '6'],
#  ['138', '68', '94', '173'],
#  ['177', '103', '229', '58'],
#  ['185', '63', '46', '208'],
#  ['206', '189', '121', '234'],
#  ['128', '70', '119', '70'],
#  ['122', '14', '211', '208'],
#  ['101', '32', '26', '159'],
#  ['68', '183', '86', '159'],
#  ['119', '96', '92', '223'],
#  ['114', '67', '82', '217'],
#  ['158', '101', '7', '100'],
#  ['118', '70', '233', '117'],
#  ['195', '222', '163', '54'],
#  ['64', '227', '5', '37'],
#  ['119', '29', '115', '153'],
#  ['138', '68', '24', '88'],
#  ['49', '234', '233', '30'],
#  ['196', '1', '97', '216'],
#  ['198', '199', '67', '58'],
#  ['80', '66', '146', '84'],
#  ['152', '136', '169', '198'],
#  ['51', '254', '100', '56'],
#  ['186', '4', '235', '4'],
#  ['73', '207', '192', '158'],
#  ['188', '166', '242', '83'],
#  ['103', '136', '40', '88'],
#  ['49', '234', '239', '91'],
#  ['113', '116', '5', '139'],
#  ['145', '253', '133', '50'],
#  ['106', '54', '89', '231'],
#  ['164', '132', '145', '70'],
#  ['200', '146', '75', '58'],
#  ['51', '77', '150', '118'],
#  ['119', '27', '166', '193'],
#  ['156', '96', '114', '73'],
#  ['106', '54', '220', '54'],
#  ['154', '34', '24', '212'],
#  ['103', '199', '162', '153'],
#  ['128', '199', '131', '150'],
#  ['118', '24', '146', '186'],
#  ['146', '59', '154', '68'],
#  ['88', '121', '22', '235'],
#  ['42', '118', '242', '189'],
#  ['192', '241', '154', '168'],
#  ['45', '158', '199', '156'],
#  ['62', '210', '201', '246'],
#  ['182', '180', '128', '134'],
#  ['111', '40', '214', '20'],
#  ['54', '37', '68', '191'],
#  ['157', '92', '13', '105'],
#  ['45', '80', '64', '230'],
#  ['191', '235', '71', '181'],
#  ['37', '44', '244', '140'],
#  ['200', '169', '6', '206'],
#  ['178', '62', '49', '137'],
#  ['157', '230', '230', '152'],
#  ['206', '189', '174', '127'],
#  ['84', '42', '204', '37'],
#  ['165', '227', '205', '128'],
#  ['181', '188', '134', '133'],
#  ['106', '12', '96', '91'],
#  ['188', '166', '109', '87'],
#  ['54', '39', '22', '191'],
#  ['164', '90', '190', '224'],
#  ['83', '58', '135', '21'],
#  ['211', '112', '18', '37'],
#  ['103', '204', '52', '66'],
#  ['36', '82', '205', '202'],
#  ['36', '133', '54', '123'],
#  ['42', '192', '125', '230'],
#  ['49', '234', '100', '188'],
#  ['81', '68', '69', '68'],
#  ['39', '155', '215', '94'],
#  ['47', '92', '111', '112'],
#  ['193', '70', '91', '79'],
#  ['217', '182', '169', '183'],
#  ['109', '228', '168', '80'],
#  ['60', '241', '53', '60'],
#  ['188', '226', '192', '115'],
#  ['155', '94', '134', '152'],
#  ['181', '210', '30', '243'],
#  ['112', '21', '191', '10'],
#  ['218', '71', '141', '62'],
#  ['51', '68', '121', '235'],
#  ['119', '45', '240', '49'],
#  ['161', '35', '6', '188'],
#  ['159', '65', '158', '172'],
#  ['159', '65', '123', '91'],
#  ['129', '204', '12', '9'],
#  ['200', '44', '50', '155'],
#  ['45', '250', '37', '136'],
#  ['104', '218', '48', '98'],
#  ['120', '132', '99', '101'],
#  ['106', '55', '37', '174'],
#  ['120', '236', '105', '190'],
#  ['198', '27', '66', '37'],
#  ['146', '59', '154', '120'],
#  ['121', '58', '212', '108'],
#  ['157', '245', '194', '231'],
#  ['190', '156', '238', '155'],
#  ['5', '135', '186', '52'],
#  ['182', '150', '20', '11'],
#  ['36', '134', '75', '7'],
#  ['116', '228', '160', '22'],
#  ['207', '154', '201', '146'],
#  ['161', '35', '121', '130'],
#  ['202', '155', '248', '196'],
#  ['69', '158', '207', '141'],
#  ['111', '229', '211', '5'],
#  ['46', '101', '4', '101'],
#  ['119', '27', '165', '49'],
#  ['201', '72', '190', '98'],
#  ['103', '130', '214', '25'],
#  ['182', '61', '164', '198'],
#  ['58', '233', '240', '94'],
#  ['116', '22', '44', '158'],
#  ['45', '116', '106', '166'],
#  ['47', '188', '43', '153'],
#  ['111', '229', '132', '48'],
#  ['129', '204', '254', '71'],
#  ['35', '239', '60', '149'],
#  ['81', '68', '186', '207'],
#  ['106', '52', '217', '57'],
#  ['118', '24', '128', '19'],
#  ['132', '232', '99', '91'],
#  ['103', '232', '120', '109'],
#  ['195', '95', '215', '157'],
#  ['159', '203', '190', '189'],
#  ['121', '69', '44', '6'],
#  ['106', '12', '153', '161'],
#  ['69', '194', '8', '237'],
#  ['117', '27', '88', '61'],
#  ['152', '136', '237', '47'],
#  ['61', '141', '64', '20'],
#  ['159', '89', '115', '74'],
#  ['136', '56', '165', '251'],
#  ['116', '255', '213', '176'],
#  ['175', '24', '131', '113'],
#  ['128', '199', '124', '216'],
#  ['52', '188', '15', '144'],
#  ['104', '248', '230', '153'],
#  ['129', '211', '99', '254'],
#  ['51', '91', '110', '51'],
#  ['87', '106', '16', '62'],
#  ['128', '199', '246', '104'],
#  ['203', '159', '249', '215'],
#  ['138', '68', '226', '175'],
#  ['167', '71', '9', '180'],
#  ['110', '42', '1', '213'],
#  ['119', '45', '213', '69'],
#  ['223', '197', '188', '206'],
#  ['106', '52', '249', '134'],
#  ['119', '45', '151', '50'],
#  ['51', '91', '108', '57'],
#  ['223', '83', '216', '125'],
#  ['128', '199', '129', '68'],
#  ['35', '240', '68', '1'],
#  ['111', '229', '3', '206'],
#  ['35', '188', '49', '176'],
#  ['107', '170', '131', '23'],
#  ['45', '14', '150', '51'],
#  ['46', '101', '189', '37'],
#  ['201', '48', '115', '235'],
#  ['49', '233', '4', '143'],
#  ['220', '164', '161', '201'],
#  ['188', '131', '146', '251'],
#  ['112', '65', '125', '190'],
#  ['159', '65', '181', '26'],
#  ['142', '93', '34', '237'],
#  ['85', '111', '74', '140'],
#  ['206', '189', '138', '99'],
#  ['41', '223', '4', '155'],
#  ['173', '225', '104', '57'],
#  ['49', '49', '7', '52'],
#  ['132', '232', '21', '175'],
#  ['139', '99', '9', '87'],
#  ['134', '175', '28', '62'],
#  ['117', '2', '22', '85'],
#  ['111', '229', '226', '212'],
#  ['167', '172', '102', '128'],
#  ['210', '16', '187', '206'],
#  ['81', '68', '175', '38'],
#  ['159', '203', '31', '168'],
#  ['142', '93', '152', '23'],
#  ['188', '173', '80', '134'],
#  ['112', '85', '17', '55'],
#  ['213', '178', '252', '28'],
#  ['79', '137', '33', '20'],
#  ['206', '189', '216', '163'],
#  ['218', '146', '20', '61'],
#  ['178', '128', '217', '58'],
#  ['51', '15', '204', '27'],
#  ['27', '254', '206', '238'],
#  ['190', '202', '32', '2'],
#  ['176', '114', '199', '56'],
#  ['106', '12', '206', '3'],
#  ['125', '65', '86', '164'],
#  ['216', '45', '23', '6'],
#  ['201', '222', '57', '21'],
#  ['165', '22', '22', '250'],
#  ['128', '199', '15', '85'],
#  ['157', '230', '38', '102'],
#  ['180', '166', '228', '228'],
#  ['217', '10', '103', '227'],
#  ['129', '152', '141', '71'],
#  ['13', '235', '76', '20'],
#  ['178', '62', '187', '136'],
#  ['162', '14', '18', '148'],
#  ['46', '101', '204', '20'],
#  ['111', '229', '16', '97'],
#  ['211', '152', '55', '174'],
#  ['60', '254', '104', '109'],
#  ['120', '92', '114', '71'],
#  ['35', '193', '104', '24'],
#  ['180', '167', '195', '218'],
#  ['95', '84', '240', '62'],
#  ['189', '240', '117', '236'],
#  ['181', '49', '107', '180'],
#  ['178', '128', '117', '58'],
#  ['106', '13', '102', '197'],
#  ['113', '31', '102', '234'],
#  ['51', '68', '198', '113'],
#  ['178', '32', '205', '2'],
#  ['142', '93', '14', '102'],
#  ['46', '224', '2', '69'],
#  ['106', '13', '93', '252'],
#  ['36', '67', '82', '242'],
#  ['138', '68', '254', '244'],
#  ['110', '88', '160', '233'],
#  ['129', '204', '197', '29'],
#  ['60', '30', '98', '194'],
#  ['62', '94', '206', '57'],
#  ['220', '186', '138', '60'],
#  ['111', '231', '116', '149'],
#  ['152', '67', '199', '110'],
#  ['177', '73', '136', '228'],
#  ['218', '86', '31', '67'],
#  ['1', '255', '226', '37'],
#  ['210', '105', '82', '53'],
#  ['104', '248', '128', '125'],
#  ['202', '77', '105', '110'],
#  ['218', '92', '0', '247'],
#  ['140', '143', '228', '227'],
#  ['122', '194', '229', '59'],
#  ['218', '92', '0', '133'],
#  ['221', '181', '185', '19'],
#  ['222', '187', '239', '42'],
#  ['218', '93', '207', '84'],
#  ['221', '181', '185', '29'],
#  ['221', '131', '165', '87'],
#  ['218', '92', '0', '250'],
#  ['112', '85', '42', '172'],
#  ['218', '93', '207', '94'],
#  ['112', '85', '42', '180'],
#  ['112', '85', '42', '47'],
#  ['221', '131', '165', '119'],
#  ['221', '181', '185', '36'],
#  ['122', '194', '229', '122'],
#  ['112', '85', '42', '200'],
#  ['218', '93', '207', '40'],
#  ['61', '177', '172', '177'],
#  ['221', '131', '165', '124'],
#  ['222', '187', '222', '55'],
#  ['218', '92', '0', '173'],
#  ['222', '187', '232', '77'],
#  ['43', '226', '69', '100'],
#  ['106', '12', '68', '150'],
#  ['49', '88', '112', '111'],
#  ['112', '85', '42', '196'],
#  ['2', '233', '125', '227'],
#  ['49', '234', '208', '46'],
#  ['101', '36', '122', '64'],
#  ['115', '146', '121', '108'],
#  ['112', '85', '42', '176'],
#  ['106', '12', '80', '200'],
#  ['193', '169', '252', '19'],
#  ['101', '78', '209', '39'],
#  ['107', '182', '22', '83'],
#  ['211', '143', '253', '166'],
#  ['211', '157', '162', '3'],
#  ['119', '92', '243', '101'],
#  ['139', '59', '96', '96'],
#  ['183', '82', '113', '143'],
#  ['123', '150', '244', '226'],
#  ['118', '113', '95', '60'],
#  ['116', '59', '25', '189'],
#  ['181', '10', '18', '188'],
#  ['45', '6', '72', '20'],
#  ['218', '93', '208', '34'],
#  ['106', '54', '94', '237'],
#  ['157', '230', '153', '75'],
#  ['51', '79', '141', '100'],
#  ['101', '32', '48', '90'],
#  ['106', '54', '247', '167'],
#  ['106', '54', '166', '168'],
#  ['194', '87', '139', '119'],
#  ['83', '15', '108', '140'],
#  ['180', '103', '210', '68'],
#  ['157', '230', '46', '86'],
#  ['117', '220', '15', '119'],
#  ['129', '204', '249', '11'],
#  ['203', '251', '11', '118'],
#  ['14', '99', '176', '210'],
#  ['203', '190', '148', '180'],
#  ['46', '101', '228', '29'],
#  ['219', '143', '38', '232'],
#  ['183', '162', '79', '39'],
#  ['122', '51', '55', '171'],
#  ['106', '75', '211', '166'],
#  ['106', '53', '17', '135'],
#  ['191', '191', '105', '95'],
#  ['172', '104', '39', '111'],
#  ['191', '239', '250', '168'],
#  ['116', '59', '25', '192'],
#  ['62', '57', '227', '12'],
#  ['197', '255', '160', '226'],
#  ['42', '192', '54', '8'],
#  ['165', '227', '193', '157'],
#  ['46', '105', '148', '221'],
#  ['148', '70', '102', '225'],
#  ['165', '232', '103', '3'],
#  ['95', '169', '6', '47'],
#  ['140', '238', '49', '143'],
#  ['190', '202', '124', '93'],
#  ['49', '234', '209', '124'],
#  ['49', '232', '2', '249'],
#  ['220', '78', '28', '68'],
#  ['195', '201', '88', '102'],
#  ['128', '199', '177', '224'],
#  ['185', '2', '140', '155'],
#  ['190', '145', '254', '138'],
#  ['85', '232', '25', '226'],
#  ['42', '159', '80', '91'],
#  ['211', '112', '187', '197'],
#  ['140', '143', '228', '18'],
#  ['51', '222', '25', '197'],
#  ['159', '89', '206', '167'],
#  ['206', '189', '178', '171'],
#  ['119', '132', '85', '199'],
#  ['118', '89', '153', '32'],
#  ['106', '12', '22', '208'],
#  ['66', '37', '110', '238'],
#  ['219', '135', '78', '208'],
#  ['83', '220', '32', '76'],
#  ['190', '104', '245', '164'],
#  ['180', '100', '206', '35'],
#  ['49', '234', '80', '94'],
#  ['119', '62', '142', '225'],
#  ['92', '81', '222', '217'],
#  ['161', '35', '45', '62'],
#  ['221', '144', '161', '172'],
#  ['154', '8', '169', '66'],
#  ['138', '128', '216', '220'],
#  ['101', '89', '192', '64'],
#  ['62', '234', '6', '147'],
#  ['88', '198', '127', '201'],
#  ['167', '99', '204', '24'],
#  ['106', '13', '182', '60'],
#  ['208', '109', '13', '208'],
#  ['45', '153', '160', '132'],
#  ['137', '74', '199', '180'],
#  ['132', '145', '159', '39'],
#  ['72', '137', '167', '242'],
#  ['115', '143', '208', '52'],
#  ['42', '2', '239', '46'],
#  ['190', '219', '220', '234'],
#  ['172', '88', '28', '253'],
#  ['178', '44', '223', '252'],
#  ['119', '237', '209', '239'],
#  ['223', '18', '152', '11'],
#  ['219', '73', '96', '39'],
#  ['14', '48', '195', '66'],
#  ['183', '230', '248', '105'],
#  ['90', '231', '204', '119'],
#  ['223', '17', '156', '213'],
#  ['217', '24', '169', '241'],
#  ['112', '85', '42', '119'],
#  ['49', '233', '14', '36'],
#  ['134', '209', '217', '73'],
#  ['61', '147', '107', '94'],
#  ['186', '147', '129', '110'],
#  ['139', '199', '119', '76'],
#  ['119', '28', '4', '87'],
#  ['51', '77', '220', '222'],
#  ['64', '227', '94', '175'],
#  ['180', '76', '124', '150'],
#  ['182', '61', '37', '144'],
#  ['62', '210', '125', '53'],
#  ['159', '89', '9', '84'],
#  ['51', '255', '199', '33'],
#  ['189', '112', '196', '1'],
#  ['42', '194', '201', '156'],
#  ['95', '104', '194', '16'],
#  ['49', '88', '112', '60'],
#  ['45', '249', '88', '41'],
#  ['142', '44', '161', '132'],
#  ['159', '89', '130', '126'],
#  ['159', '65', '91', '105'],
#  ['161', '35', '26', '90'],
#  ['146', '59', '153', '189'],
#  ['191', '252', '205', '182'],
#  ['49', '233', '177', '99'],
#  ['112', '85', '42', '194'],
#  ['184', '82', '227', '22'],
#  ['94', '134', '1', '54'],
#  ['35', '200', '114', '187'],
#  ['81', '70', '155', '138'],
#  ['119', '254', '145', '18'],
#  ['118', '34', '12', '117'],
#  ['152', '136', '133', '109'],
#  ['202', '29', '80', '133'],
#  ['49', '235', '90', '166'],
#  ['154', '8', '149', '6'],
#  ['192', '141', '107', '58'],
#  ['106', '54', '194', '35'],
#  ['167', '71', '72', '70'],
#  ['176', '31', '255', '63'],
#  ['170', '0', '113', '38'],
#  ['130', '61', '227', '100'],
#  ['1', '251', '239', '18'],
#  ['202', '99', '48', '156'],
#  ['128', '199', '149', '111'],
#  ['134', '209', '228', '253'],
#  ['186', '212', '190', '76'],
#  ['129', '205', '112', '253'],
#  ['118', '25', '63', '170'],
#  ['61', '216', '146', '85'],
#  ['115', '159', '214', '200'],
#  ['52', '203', '221', '18'],
#  ['181', '53', '251', '199'],
#  ['195', '223', '211', '242'],
#  ['134', '175', '146', '231'],
#  ['106', '52', '130', '172'],
#  ['210', '245', '92', '228'],
#  ['111', '229', '129', '64'],
#  ['144', '34', '196', '101'],
#  ['36', '66', '40', '13'],
#  ['77', '75', '128', '202'],
#  ['200', '174', '156', '62'],
#  ['208', '68', '39', '220'],
#  ['119', '45', '138', '133'],
#  ['183', '100', '31', '47'],
#  ['113', '204', '228', '66'],
#  ['195', '138', '76', '69'],
#  ['122', '51', '254', '201'],
#  ['52', '229', '159', '234'],
#  ['103', '24', '179', '85'],
#  ['180', '76', '147', '52'],
#  ['206', '81', '2', '133'],
#  ['118', '25', '27', '67'],
#  ['187', '189', '51', '117'],
#  ['81', '68', '200', '73'],
#  ['134', '175', '227', '112'],
#  ['143', '110', '182', '228'],
#  ['49', '233', '90', '200'],
#  ['129', '226', '188', '130'],
#  ['180', '102', '129', '127'],
#  ['170', '210', '83', '119'],
#  ['46', '35', '19', '18'],
#  ['202', '77', '105', '100'],
#  ['133', '130', '89', '23'],
#  ['111', '230', '56', '118'],
#  ['61', '244', '80', '223'],
#  ['132', '232', '77', '85'],
#  ['51', '39', '189', '65'],
#  ['116', '12', '52', '141'],
#  ['111', '229', '222', '118'],
#  ['95', '181', '188', '200'],
#  ['43', '226', '152', '191'],
#  ['188', '166', '247', '82'],
#  ['223', '247', '218', '112'],
#  ['51', '254', '141', '18'],
#  ['134', '122', '103', '82'],
#  ['51', '158', '20', '200'],
#  ['203', '177', '71', '254'],
#  ['142', '93', '66', '172'],
#  ['65', '49', '201', '168'],
#  ['200', '73', '128', '183'],
#  ['134', '175', '46', '166'],
#  ['159', '192', '143', '249'],
#  ['139', '59', '102', '170'],
#  ['49', '235', '192', '23'],
#  ['139', '155', '73', '60'],
#  ['36', '102', '232', '2'],
#  ['79', '137', '36', '108'],
#  ['132', '232', '47', '59'],
#  ['78', '85', '20', '134'],
#  ['58', '33', '49', '196'],
#  ['106', '55', '58', '118'],
#  ['191', '13', '195', '65'],
#  ['165', '231', '143', '129'],
#  ['120', '53', '122', '66'],
#  ['45', '153', '240', '17'],
#  ['45', '15', '25', '76'],
#  ['213', '150', '206', '88'],
#  ['103', '45', '175', '71'],
#  ['212', '47', '241', '15'],
#  ['139', '59', '129', '45'],
#  ['111', '93', '200', '50'],
#  ['113', '76', '149', '26'],
#  ['82', '193', '145', '123'],
#  ['220', '186', '128', '149'],
#  ['222', '73', '114', '78'],
#  ['14', '232', '226', '92'],
#  ['106', '52', '135', '88'],
#  ['192', '144', '217', '101'],
#  ['202', '165', '22', '247'],
#  ['128', '199', '146', '137'],
#  ['49', '234', '163', '189'],
#  ['69', '245', '71', '26'],
#  ['49', '233', '212', '154'],
#  ['91', '144', '20', '198'],
#  ['182', '61', '150', '202'],
#  ['49', '235', '151', '50'],
#  ['220', '180', '119', '192'],
#  ['36', '156', '154', '154'],
#  ['104', '36', '71', '215'],
#  ['129', '204', '238', '250'],
#  ['132', '232', '55', '173'],
#  ['81', '68', '72', '231'],
#  ['103', '144', '180', '20'],
#  ['5', '196', '75', '140'],
#  ['138', '68', '245', '12'],
#  ['175', '24', '49', '210'],
#  ['37', '187', '106', '104'],
#  ['119', '29', '173', '247'],
#  ['45', '187', '192', '1'],
#  ['80', '82', '64', '124'],
#  ['113', '200', '105', '23'],
#  ['182', '61', '136', '3'],
#  ['5', '3', '6', '82'],
#  ['150', '109', '99', '68'],
#  ['35', '200', '203', '6'],
#  ['160', '16', '136', '28'],
#  ['203', '151', '146', '216'],
#  ['119', '28', '61', '162'],
#  ['43', '254', '158', '178'],
#  ['79', '129', '29', '237'],
#  ['106', '12', '34', '57'],
#  ['175', '24', '189', '160'],
#  ['178', '62', '104', '58'],
#  ['58', '33', '160', '139'],
#  ['165', '22', '247', '221'],
#  ['119', '45', '139', '59'],
#  ['51', '68', '174', '83'],
#  ['61', '76', '169', '138'],
#  ['43', '229', '55', '61'],
#  ['14', '23', '170', '234'],
#  ['94', '191', '75', '220'],
#  ['154', '8', '192', '65'],
#  ['58', '40', '118', '114'],
#  ['49', '234', '149', '92'],
#  ['102', '37', '10', '155'],
#  ['91', '134', '240', '130'],
#  ['20', '52', '155', '148'],
#  ...]

# %% [markdown]
# ### Method to convery split ip address to decimal format to easily plug into the ipv4 table

# %%
def ip_conversion(enter):
    try:
        enter[0] = int(enter[0]) * (256 * 256 * 256)
        enter[1] = int(enter[1]) * (256 * 256)
        enter[2] = int(enter[2]) * (256)
        sum = enter[0] + enter[1] + enter[2] + int(enter[3])
        return sum
    except:
        sum = "unknown"

# %% [markdown]
# ### Practice conversion method

# %%
s = ['218', '92', '0', '184']
ip_conversion(s)
# Out:
# 3663462584

# %% [markdown]
# ### Converts all the ip addresses to decimal format

# %%
rootDecimalIP = rootIPAddressSplit.map(lambda line: ip_conversion(line))
rootDecimalIP.collect()
# Out:
# [3663462584,
#  3716392273,
#  3736854069,
#  3736858199,
#  3719674130,
#  1884629600,
#  3114027585,
#  3719674312,
#  3663462649,
#  3719674310,
#  3663462648,
#  3575672629,
#  3736854121,
#  1877432359,
#  3663462571,
#  1884629589,
#  2160676024,
#  676812742,
#  2388524666,
#  3249142843,
#  1999444597,
#  3719674255,
#  837487497,
#  3719674261,
#  3075630658,
#  None,
#  3736855520,
#  1730918798,
#  868428530,
#  2499087637,
#  760383779,
#  2806448390,
#  1363471879,
#  1884629736,
#  2453380533,
#  1868217908,
#  837443131,
#  3070651204,
#  2026610706,
#  2418196819,
#  3197143884,
#  720915972,
#  2703455758,
#  3191276942,
#  1939823288,
#  1348638217,
#  1952242594,
#  2406414945,
#  2358218892,
#  3165043635,
#  1998336867,
#  99141105,
#  1033960290,
#  1985607904,
#  2984033647,
#  1613606353,
#  778415591,
#  1022798643,
#  1884160807,
#  1833797593,
#  3191920027,
#  1966315210,
#  3731938316,
#  1708040912,
#  3016958141,
#  2649152691,
#  1732209689,
#  2703433424,
#  1877406733,
#  1290358877,
#  3147972024,
#  466062361,
#  2050202196,
#  2335902394,
#  2713558279,
#  1868366389,
#  3242590436,
#  1877460979,
#  764893397,
#  1709675044,
#  2102989913,
#  1779261059,
#  778410738,
#  3357266966,
#  1900810591,
#  1999485110,
#  1116727129,
#  1779205344,
#  2461643833,
#  2358182009,
#  1753479481,
#  3206506513,
#  2335965094,
#  838325522,
#  2526991530,
#  2721979002,
#  1363464259,
#  3468525783,
#  3360045260,
#  3575672628,
#  3302769410,
#  2655378499,
#  1981487591,
#  860586987,
#  704852589,
#  1293632830,
#  87955210,
#  1930908005,
#  3114694284,
#  1756050684,
#  1050156418,
#  2039997634,
#  1559955005,
#  2513058020,
#  989474087,
#  2959817064,
#  2009255177,
#  3671205613,
#  3196876474,
#  1299837288,
#  1314194876,
#  3536963685,
#  984651868,
#  3176028083,
#  1912398184,
#  3192794765,
#  1022801494,
#  2989290950,
#  773142138,
#  1843692097,
#  2541693871,
#  2649126876,
#  1952970544,
#  None,
#  2978726462,
#  2671862448,
#  1760328749,
#  1696902444,
#  223483995,
#  861110756,
#  717411046,
#  2640055707,
#  2808311475,
#  1137662345,
#  2430182323,
#  3194151990,
#  1729792173,
#  1604655643,
#  1781746124,
#  2296684867,
#  3355871723,
#  1333278382,
#  2671898357,
#  1466087005,
#  57688913,
#  3396181643,
#  1152898857,
#  2783133605,
#  837443272,
#  1877279156,
#  2252970669,
#  861095125,
#  3194525122,
#  3245364515,
#  1138282780,
#  2328209365,
#  2016769676,
#  2769697199,
#  1779178648,
#  2019325786,
#  825467781,
#  837361248,
#  1345603608,
#  2160578138,
#  24615278,
#  3334949359,
#  1843609347,
#  1975529000,
#  1999448817,
#  2673422367,
#  1986074394,
#  2769737571,
#  3315351946,
#  1877313092,
#  2685716714,
#  222768866,
#  1757414929,
#  3043996978,
#  2099469442,
#  2242338769,
#  2259671791,
#  2050172989,
#  774225035,
#  869425321,
#  2160533343,
#  2708814079,
#  1608772110,
#  2994765630,
#  3652619773,
#  837476440,
#  1230582909,
#  238597223,
#  837541292,
#  2783119291,
#  2680899598,
#  869449320,
#  1998415512,
#  2671875051,
#  1998434782,
#  1589585611,
#  2673470777,
#  1731734497,
#  908476727,
#  1019157970,
#  2078777442,
#  3361747276,
#  882437650,
#  762586021,
#  3286537226,
#  2160549692,
#  837316517,
#  837465404,
#  1783333891,
#  3149742577,
#  2937633623,
#  2769698711,
#  3384486399,
#  2342252495,
#  3057495496,
#  1730676921,
#  1912009537,
#  1534762945,
#  222838833,
#  1743323810,
#  2769735872,
#  460534386,
#  2960578787,
#  1534673815,
#  3732213076,
#  2044919825,
#  1035292925,
#  1761099550,
#  1696607764,
#  96749163,
#  860143327,
#  860118734,
#  2960931616,
#  1781984482,
#  2649150467,
#  2566531894,
#  3203733039,
#  781381817,
#  241333564,
#  1962924066,
#  1897886051,
#  2448365566,
#  2671857155,
#  3014537802,
#  860741393,
#  1088638461,
#  2345040191,
#  867310542,
#  2487645809,
#  3138465878,
#  866041088,
#  1868316124,
#  770725923,
#  2179106467,
#  1117144864,
#  3663322640,
#  837518424,
#  1734967944,
#  1786544966,
#  1706785637,
#  1363614369,
#  736467276,
#  3560983981,
#  1981400052,
#  3697051935,
#  2808311338,
#  3323679387,
#  1779210707,
#  2891051245,
#  3468516826,
#  1783361622,
#  3398680818,
#  1737536530,
#  94385282,
#  2050200918,
#  908507061,
#  3290842648,
#  2101432225,
#  612723970,
#  1868533026,
#  2365181333,
#  None,
#  575068595,
#  2806460043,
#  978810844,
#  1903076998,
#  860142917,
#  1779224556,
#  783684401,
#  3164944598,
#  2650106915,
#  2229818412,
#  2673460299,
#  1779227307,
#  1939825180,
#  2296963786,
#  2703428470,
#  1731029909,
#  2000491351,
#  870194471,
#  786040803,
#  3414627364,
#  837318653,
#  837302360,
#  758601744,
#  1786017370,
#  2178108716,
#  1781826746,
#  577094061,
#  3560984745,
#  3363093566,
#  3237055468,
#  3305476379,
#  3005955073,
#  3732934250,
#  2673461855,
#  3113785098,
#  3084776212,
#  3265050652,
#  2680903108,
#  38973303,
#  3107146951,
#  2090656159,
#  2177659769,
#  2671873728,
#  2487390092,
#  1998346724,
#  1781910102,
#  998084952,
#  2388486029,
#  1779179971,
#  1999473723,
#  1730860562,
#  3361730326,
#  3016927636,
#  1333732450,
#  2808286957,
#  1032186104,
#  1032186109,
#  2160568865,
#  837425497,
#  2783154225,
#  2475906254,
#  2177641846,
#  3184216202,
#  1138286365,
#  1839208147,
#  392272837,
#  999305250,
#  2335940352,
#  1998339117,
#  3346261194,
#  867309629,
#  2884930540,
#  1540302893,
#  2703463499,
#  1758863873,
#  2707505332,
#  3191087659,
#  2523755066,
#  702684243,
#  1981320874,
#  3305476454,
#  3696755152,
#  1696607498,
#  2345098852,
#  3530059983,
#  2166136263,
#  1210753615,
#  1999490401,
#  1152904879,
#  837446424,
#  991656986,
#  1919150082,
#  837357366,
#  250140298,
#  3741064733,
#  3673770294,
#  17549586,
#  869402027,
#  3111887926,
#  1336462516,
#  3000274949,
#  860738952,
#  1779192054,
#  1137550125,
#  2319759430,
#  1046229234,
#  1877285401,
#  2769699924,
#  3040304948,
#  3729457605,
#  1730860672,
#  3287674707,
#  1927762462,
#  1733098502,
#  2103658523,
#  575825739,
#  1567993495,
#  3078725587,
#  3193258923,
#  1856290101,
#  1304937177,
#  2303378962,
#  1781990513,
#  3737031042,
#  3707226477,
#  1981356116,
#  778428600,
#  222762363,
#  867324133,
#  1806669395,
#  1363456101,
#  250139232,
#  3039833795,
#  1934474468,
#  1779290061,
#  1363461663,
#  2673420004,
#  1985560554,
#  3559909102,
#  2808311294,
#  2968240261,
#  2166099479,
#  392812542,
#  1605793968,
#  3245397435,
#  838323278,
#  316480844,
#  1884629647,
#  221319174,
#  2319736493,
#  2976376122,
#  3107925712,
#  3468524010,
#  2152101702,
#  2047792080,
#  1696602783,
#  1152865951,
#  2002803935,
#  1917014745,
#  2657421156,
#  1984358773,
#  3286147894,
#  1088619813,
#  1998418841,
#  2319718488,
#  837478686,
#  3288424920,
#  3334947642,
#  1346540116,
#  2559093190,
#  872309816,
#  3120884484,
#  1238352030,
#  3165057619,
#  1736976472,
#  837480283,
#  1903429003,
#  2449311026,
#  1781946855,
#  2760151366,
#  3365030714,
#  860722806,
#  1998300865,
#  2623566409,
#  1781980214,
#  2585925844,
#  1741136537,
#  2160558998,
#  1981321914,
#  2453379652,
#  1484330731,
#  712438461,
#  3237059240,
#  765380508,
#  1054001654,
#  3065282694,
#  1864947220,
#  908412095,
#  2640055657,
#  760234214,
#  3219867573,
#  623703180,
#  3366520526,
#  2990420361,
#  2649155224,
#  3468537471,
#  1412090917,
#  2783169920,
#  3049031301,
#  1779195995,
#  3165023575,
#  908531391,
#  2757410528,
#  1396344597,
#  3547337253,
#  1741435970,
#  609406410,
#  612710011,
#  717258214,
#  837444796,
#  1363428676,
#  664524638,
#  794586992,
#  3242613583,
#  3652626871,
#  1843701840,
#  1022440764,
#  3168977011,
#  2606663320,
#  3050446579,
#  1880473354,
#  3662122302,
#  860125675,
#  1999499313,
#  2703427260,
#  2671877804,
#  2671868763,
#  2177633289,
#  3358339739,
#  771368328,
#  1759129698,
#  2021942117,
#  1781999022,
#  2028759486,
#  3323675173,
#  2453379704,
#  2033898604,
#  2650129127,
#  3197955739,
#  92781108,
#  3063288843,
#  612780807,
#  1961140246,
#  3483027858,
#  2703456642,
#  3399219396,
#  1168035725,
#  1877332741,
#  778372197,
#  1998300465,
#  3376987746,
#  1736627737,
#  3057493190,
#  988409950,
#  1947610270,
#  762604198,
#  800861081,
#  1877312560,
#  2177695303,
#  602881173,
#  1363458767,
#  1781848377,
#  1981317139,
#  2229822299,
#  1743288429,
#  3277838237,
#  2680929981,
#  2034576390,
#  1779210657,
#  1170344173,
#  1964726333,
#  2559110447,
#  1032667156,
#  2673439562,
#  2285413883,
#  1962923440,
#  2937619313,
#  2160557272,
#  884739984,
#  1761142425,
#  2178114558,
#  861630003,
#  1466568766,
#  2160588392,
#  3416259031,
#  2319770287,
#  2806450612,
#  1848246741,
#  1999492421,
#  3754278094,
#  1781856646,
#  1999476530,
#  861629497,
#  3746814077,
#  2160558404,
#  602948609,
#  1877279694,
#  599536048,
#  1806336791,
#  755930675,
#  778419493,
#  3375395819,
#  837354639,
#  3701776841,
#  3162739451,
#  1883340222,
#  2671883546,
#  2388468461,
#  1433356940,
#  3468528227,
#  702481563,
#  2917230649,
#  825296692,
#  2229802415,
#  2338523479,
#  2259622974,
#  1963071061,
#  1877336788,
#  2813093504,
#  3524312014,
#  1363455782,
#  2680889256,
#  2388498455,
#  3165474950,
#  1884623159,
#  3585276956,
#  1334386964,
#  3468548259,
#  3667006525,
#  2994788666,
#  856673307,
#  469683950,
#  3200917506,
#  2960312120,
#  1779224067,
#  2101434020,
#  3626833670,
#  3386784021,
#  2769688314,
#  2160529237,
#  2649106022,
#  3030836452,
#  3641337827,
#  2174258503,
#  233524244,
#  2990455688,
#  2718831252,
#  778423316,
#  1877282913,
#  3549968302,
#  1023305837,
#  2019324487,
#  599877656,
#  3030893530,
#  1599402046,
#  3186652652,
#  3039914932,
#  2994763066,
#  1779263173,
#  1897883370,
#  860145265,
#  2988494082,
#  2388463206,
#  786432581,
#  1779260924,
#  608391922,
#  2319777524,
#  1851302121,
#  2177680669,
#  1008624322,
#  1046400569,
#  3703212604,
#  1877439637,
#  2554578798,
#  2974386404,
#  3663077187,
#  33546789,
#  3530117685,
#  1761116285,
#  3394070894,
#  3663462647,
#  2358240483,
#  2059593019,
#  3663462533,
#  3719674131,
#  3736858410,
#  3663581012,
#  3719674141,
#  3716392279,
#  3663462650,
#  1884629676,
#  3663581022,
#  1884629684,
#  1884629551,
#  3716392311,
#  3719674148,
#  2059593082,
#  1884629704,
#  3663580968,
#  1035054257,
#  3716392316,
#  3736854071,
#  3663462573,
#  3736856653,
#  736249188,
#  1779188886,
#  827879535,
#  1884629700,
#  48856547,
#  837472302,
#  1696889408,
#  1938979180,
#  1884629680,
#  1779192008,
#  3249142803,
#  1699664167,
#  1807095379,
#  3549429158,
#  3550323203,
#  2002580325,
#  2335924320,
#  3075633551,
#  2073490658,
#  1987141436,
#  1950030269,
#  3037336252,
#  755386388,
#  3663581218,
#  1781948141,
#  2649135435,
#  860851556,
#  1696608346,
#  1781987239,
#  1781966504,
#  3260517239,
#  1393519756,
#  3026702916,
#  2649108054,
#  1977356151,
#  2177693963,
#  3422227318,
#  241414354,
#  3418264756,
#  778429469,
#  3683591912,
#  3080867623,
#  2050176939,
#  1783354278,
#  1781862791,
#  3216992607,
#  2892506991,
#  3220175528,
#  1950030272,
#  1043981068,
#  3321864418,
#  717239816,
#  2783166877,
#  778671325,
#  2487641825,
#  2783471363,
#  1604912687,
#  2364420495,
#  3200941149,
#  837472636,
#  837288697,
#  3696106564,
#  3284752486,
#  2160570848,
#  3103952027,
#  3197238922,
#  1441274338,
#  715083867,
#  3547380677,
#  2358240274,
#  870193605,
#  2673462951,
#  3468538539,
#  2005161415,
#  1985583392,
#  1779177168,
#  1109749486,
#  3683077840,
#  1406935116,
#  3194549668,
#  3026505251,
#  837439582,
#  2000588513,
#  1548869337,
#  2703437118,
#  3717243308,
#  2584258882,
#  2323699932,
#  1700380736,
#  1055524499,
#  1489403849,
#  2808335384,
#  1779283516,
#  3496807888,
#  765042820,
#  2303379380,
#  2224135975,
#  1216980978,
#  1938804788,
#  704835374,
#  3202079978,
#  2891455741,
#  2989285372,
#  2012074479,
#  3742537739,
#  3679019047,
#  238076738,
#  3085367401,
#  1525140599,
#  3742473429,
#  3642272241,
#  1884629623,
#  837357092,
#  2261899593,
#  1033071454,
#  3130229102,
#  2345105228,
#  1998324823,
#  860740830,
#  1088642735,
#  3024911510,
#  3057460624,
#  1053982005,
#  2673412436,
#  872400673,
#  3178284033,
#  717408668,
#  1600700944,
#  827879484,
#  771315753,
#  2385289604,
#  2673443454,
#  2671860585,
#  2703432282,
#  2453379517,
#  3221015990,
#  837398883,
#  1884629698,
#  3092439830,
#  1585840438,
#  600339131,
#  1363581834,
#  2013171986,
#  1981942901,
#  2559083885,
#  3390918789,
#  837507750,
#  2584253702,
#  3230493498,
#  1781973539,
#  2806466630,
#  2954886975,
#  2852155686,
#  2185093988,
#  33287954,
#  3395498140,
#  2160563567,
#  2261902589,
#  3134504524,
#  2177724669,
#  1981366186,
#  1037603413,
#  1939855048,
#  885775634,
#  3040213959,
#  3286225906,
#  2259653351,
#  1781826220,
#  3539295460,
#  1877311808,
#  2418197605,
#  608315405,
#  1296793802,
#  3366886462,
#  3494127580,
#  1999473285,
#  3076792111,
#  1909253186,
#  3280620613,
#  2050227913,
#  887463914,
#  1729672021,
#  3024917300,
#  3461415557,
#  1981356867,
#  3149738869,
#  1363462217,
#  2259673968,
#  2406397668,
#  837376712,
#  2179120258,
#  3026616703,
#  2865910647,
#  774050578,
#  3394070884,
#  2239912215,
#  1877358710,
#  1039421663,
#  2229816661,
#  858242369,
#  1946956941,
#  1877335670,
#  1605745864,
#  736270527,
#  3165058898,
#  3757562480,
#  872320274,
#  2256168786,
#  865998024,
#  3417393150,
#  2388476588,
#  1093781928,
#  3360260279,
#  2259627686,
#  2680197113,
#  2335925930,
#  837533719,
#  2342209852,
#  610723842,
#  1334387820,
#  2229808955,
#  1314198662,
#  975253956,
#  1782004342,
#  3205350209,
#  2783416193,
#  2016770626,
#  765063185,
#  755964236,
#  3583430232,
#  1731047239,
#  3559911695,
#  2335932717,
#  1868417074,
#  1900844314,
#  1388417403,
#  3703210133,
#  3729355342,
#  250143324,
#  1781827416,
#  3230718309,
#  3399816951,
#  2160562825,
#  837460925,
#  1173702426,
#  837407898,
#  1536169158,
#  3057489610,
#  837523250,
#  3702814656,
#  614242970,
#  1747208151,
#  2177691386,
#  2229811117,
#  1363429607,
#  1737536532,
#  96750476,
#  2319774988,
#  2937598418,
#  633039464,
#  1998433783,
#  767279105,
#  1347567740,
#  1908959511,
#  3057485827,
#  84084306,
#  2523751236,
#  600361734,
#  2685437980,
#  3415708376,
#  1998339490,
#  738107058,
#  1333861869,
#  1779180089,
#  2937634208,
#  2990434362,
#  975282315,
#  2769745885,
#  1999473467,
#  860139091,
#  1028434314,
#  736442173,
#  236432106,
#  1589595100,
#  2584264769,
#  975730290,
#  837457244,
#  1713703579,
#  1535570050,
#  338992020,
#  ...]

# %% [markdown]
# ### Make sure this is the right csv file

# %%
countriesApi = sc.textFile("C://Users//samue//Downloads//IP2LOCATION-LITE-DB1.CSV//IP2LOCATION-LITE-DB1.CSV")

# %% [markdown]
# ### Make sure the right csv file

# %%
countriesApi.take(5)
# Out:
# ['"0","16777215","-","-"',
#  '"16777216","16777471","US","United States of America"',
#  '"16777472","16778239","CN","China"',
#  '"16778240","16779263","AU","Australia"',
#  '"16779264","16781311","CN","China"']

# %% [markdown]
# ### Method to turn decimal ip into country by search the csv file to find the country the decimal ip belongs to

# %%
import csv
def find_country( address ):
    with open (r"C://Users//samue//Downloads//IP2LOCATION-LITE-DB1.CSV//IP2LOCATION-LITE-DB1.CSV", "r") as isp4:
        try:
            address = int(address)
            ip_reader = csv.reader(isp4)
            for line in ip_reader:
                if int(address) >= int(line[0]) and address <= int(line[1]):
                    if line[3] != "":
                        country = line[3]
                        return country
        except:
            country = "unknown"
find_country(3663462584)
# Out:
# 'China'

# %% [markdown]
# ### Practice country conversion

# %%
s = ["16777216","16777471","US","United States of America"]
find_country(16777218)
# Out:
# 'United States of America'

# %% [markdown]
# ### Converts the decimal ip addresses into countries

# %%
resultCountries = rootDecimalIP.map(lambda line: find_country(line))
resultCountries.collect()
# Out:
# ['China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'Azerbaijan',
#  'China',
#  'China',
#  'China',
#  'China',
#  'France',
#  'China',
#  'China',
#  'China',
#  'China',
#  'Brazil',
#  'United States of America',
#  'United States of America',
#  'Poland',
#  'China',
#  'China',
#  'China',
#  'China',
#  'India',
#  None,
#  'China',
#  'China',
#  'Germany',
#  'Mexico',
#  'Iran (Islamic Republic of)',
#  'Netherlands',
#  'China',
#  'China',
#  'France',
#  'Thailand',
#  'China',
#  'China',
#  'China',
#  'United States of America',
#  'Colombia',
#  'China',
#  'United States of America',
#  'Argentina',
#  'China',
#  'Hungary',
#  'Hong Kong',
#  'India',
#  'China',
#  'Singapore',
#  'Hong Kong',
#  'Iran (Islamic Republic of)',
#  'China',
#  'China',
#  'Brazil',
#  'United States of America',
#  'Germany',
#  'Macao',
#  'Viet Nam',
#  'Ireland',
#  'Uruguay',
#  'China',
#  'Korea (Republic of)',
#  'China',
#  'Brazil',
#  'United States of America',
#  'Viet Nam',
#  'Germany',
#  'China',
#  'United States of America',
#  'Mexico',
#  'China',
#  'China',
#  'India',
#  'China',
#  'India',
#  'France',
#  'China',
#  'Ukraine',
#  'China',
#  'China',
#  'China',
#  'Germany',
#  'Chile',
#  'China',
#  'China',
#  'United States of America',
#  'China',
#  'Netherlands',
#  'China',
#  'United States of America',
#  'Brazil',
#  'Singapore',
#  'Korea (Republic of)',
#  'China',
#  'Russian Federation',
#  'China',
#  'India',
#  'Argentina',
#  'France',
#  'Nigeria',
#  'Canada',
#  'Japan',
#  'France',
#  'Hong Kong',
#  'Spain',
#  'Australia',
#  'Korea (Republic of)',
#  'Cyprus',
#  'Canada',
#  'Cyprus',
#  'Korea (Republic of)',
#  'Malta',
#  'France',
#  'China',
#  'Ukraine',
#  'Korea (Republic of)',
#  'Taiwan (Province of China)',
#  'Panama',
#  'Ukraine',
#  'Russian Federation',
#  'Taiwan (Province of China)',
#  'Hong Kong',
#  'Brazil',
#  'Hong Kong',
#  'Venezuela (Bolivarian Republic of)',
#  'Macao',
#  'Russian Federation',
#  'Cyprus',
#  'Sweden',
#  'France',
#  'Germany',
#  'Viet Nam',
#  None,
#  'Brazil',
#  'United States of America',
#  'United States of America',
#  'China',
#  'United States of America',
#  'Poland',
#  'China',
#  'Argentina',
#  'United States of America',
#  'United States of America',
#  'Canada',
#  'Chile',
#  'Bangladesh',
#  'Russian Federation',
#  'India',
#  'Myanmar',
#  'Brazil',
#  'Russian Federation',
#  'United States of America',
#  'France',
#  'Japan',
#  'China',
#  'Germany',
#  'United States of America',
#  'China',
#  'China',
#  'United States of America',
#  'France',
#  'Paraguay',
#  'China',
#  'United States of America',
#  'Canada',
#  'China',
#  'Singapore',
#  'China',
#  'China',
#  'Germany',
#  'China',
#  'Spain',
#  'Singapore',
#  'China',
#  'United States of America',
#  'Croatia',
#  'India',
#  'China',
#  'United States of America',
#  'Indonesia',
#  'India',
#  'Ethiopia',
#  'China',
#  'Brazil',
#  'India',
#  'United States of America',
#  'Argentina',
#  'China',
#  'Japan',
#  'China',
#  'China',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'France',
#  'India',
#  'Singapore',
#  'Italy',
#  'Singapore',
#  'France',
#  'China',
#  'United States of America',
#  'Korea (Republic of)',
#  'China',
#  'United States of America',
#  'United States of America',
#  'France',
#  'Hong Kong',
#  'India',
#  'Hong Kong',
#  'China',
#  'United States of America',
#  'India',
#  'France',
#  'China',
#  'Indonesia',
#  'Brazil',
#  'United States of America',
#  'China',
#  'Hungary',
#  'Singapore',
#  'China',
#  'China',
#  'China',
#  'Mexico',
#  'China',
#  'Singapore',
#  'Chile',
#  'China',
#  'China',
#  'Singapore',
#  'China',
#  'Russian Federation',
#  'United States of America',
#  'Malaysia',
#  'India',
#  'China',
#  'Russian Federation',
#  'France',
#  'Korea (Republic of)',
#  'China',
#  'China',
#  'United States of America',
#  'Hong Kong',
#  'France',
#  'Germany',
#  'France',
#  'Romania',
#  'China',
#  'United States of America',
#  'Brazil',
#  'Argentina',
#  'Russian Federation',
#  'India',
#  'China',
#  'China',
#  'Poland',
#  'United States of America',
#  'Brazil',
#  'France',
#  'Netherlands',
#  'China',
#  'France',
#  'China',
#  'Brazil',
#  'Netherlands',
#  'India',
#  'Egypt',
#  'Hong Kong',
#  'United States of America',
#  'China',
#  'China',
#  'Indonesia',
#  'China',
#  'Australia',
#  'China',
#  'Hong Kong',
#  'China',
#  'China',
#  'Korea (Republic of)',
#  'United States of America',
#  'Canada',
#  'China',
#  'China',
#  'Singapore',
#  'China',
#  'Indonesia',
#  'Indonesia',
#  'Iran (Islamic Republic of)',
#  'China',
#  'France',
#  'South Africa',
#  'China',
#  'China',
#  'Indonesia',
#  'China',
#  None,
#  'United States of America',
#  'Germany',
#  'China',
#  'China',
#  'Germany',
#  'China',
#  'Germany',
#  'France',
#  'India',
#  'China',
#  'Singapore',
#  'China',
#  'China',
#  'India',
#  'United States of America',
#  'China',
#  'China',
#  'Canada',
#  'France',
#  'Pakistan',
#  'China',
#  'China',
#  'United States of America',
#  'China',
#  'China',
#  'China',
#  'Indonesia',
#  'China',
#  'Colombia',
#  'United States of America',
#  'Tunisia',
#  'Brazil',
#  'China',
#  'Singapore',
#  'Italy',
#  'China',
#  'Russian Federation',
#  'United States of America',
#  'Portugal',
#  'Denmark',
#  'Japan',
#  'China',
#  'Singapore',
#  'Singapore',
#  'Hong Kong',
#  'China',
#  'Taiwan (Province of China)',
#  'Germany',
#  'China',
#  'China',
#  'Hong Kong',
#  'Mexico',
#  'Brazil',
#  'Iran (Islamic Republic of)',
#  'United States of America',
#  'China',
#  'China',
#  'Singapore',
#  'China',
#  'Germany',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'China',
#  'Mexico',
#  'United States of America',
#  'Bulgaria',
#  'Netherlands',
#  'India',
#  'Germany',
#  'Hong Kong',
#  'United States of America',
#  'France',
#  'Viet Nam',
#  'Russian Federation',
#  'Netherlands',
#  'United States of America',
#  'Germany',
#  'Argentina',
#  'Hong Kong',
#  'Tunisia',
#  'China',
#  'Tunisia',
#  'Korea (Republic of)',
#  'Hong Kong',
#  'China',
#  'Korea (Republic of)',
#  'China',
#  'United States of America',
#  'China',
#  'Singapore',
#  'China',
#  'Korea (Republic of)',
#  'China',
#  'China',
#  'Viet Nam',
#  'Viet Nam',
#  'China',
#  'Korea (Republic of)',
#  'France',
#  'Russian Federation',
#  'Portugal',
#  'Poland',
#  'France',
#  'China',
#  'United States of America',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'Norway',
#  'China',
#  'Germany',
#  'Colombia',
#  'China',
#  'Hong Kong',
#  'Russian Federation',
#  'China',
#  'India',
#  'India',
#  'United States of America',
#  'Spain',
#  'China',
#  'Colombia',
#  'Thailand',
#  'France',
#  'France',
#  'China',
#  'China',
#  'Sri Lanka',
#  'China',
#  'Germany',
#  'India',
#  'France',
#  'United States of America',
#  'China',
#  'Viet Nam',
#  'Colombia',
#  'Viet Nam',
#  'China',
#  'China',
#  'United States of America',
#  'China',
#  'France',
#  'United States of America',
#  'Turkey',
#  'China',
#  'United States of America',
#  'Russian Federation',
#  'China',
#  'Korea (Republic of)',
#  'United States of America',
#  'China',
#  'Sweden',
#  'Germany',
#  'Brazil',
#  'Hungary',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'Russian Federation',
#  'China',
#  'Hong Kong',
#  'India',
#  'China',
#  'China',
#  'United States of America',
#  'Viet Nam',
#  'Russian Federation',
#  'United States of America',
#  'Hong Kong',
#  'United States of America',
#  'China',
#  'Senegal',
#  'United States of America',
#  'Russian Federation',
#  'China',
#  'France',
#  'Ecuador',
#  'United States of America',
#  'Singapore',
#  'Netherlands',
#  'China',
#  'China',
#  'Germany',
#  'China',
#  'France',
#  'Brazil',
#  'France',
#  'China',
#  'United States of America',
#  'China',
#  'Japan',
#  'India',
#  'Singapore',
#  'China',
#  'France',
#  'France',
#  'Viet Nam',
#  'United States of America',
#  'United States of America',
#  'France',
#  'Pakistan',
#  'China',
#  'France',
#  'Argentina',
#  'Russian Federation',
#  'Brazil',
#  'Singapore',
#  'Brazil',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'United States of America',
#  'United States of America',
#  'Czechia',
#  'United States of America',
#  'Bolivia (Plurinational State of)',
#  'China',
#  'Netherlands',
#  'Canada',
#  'Germany',
#  'Spain',
#  'Korea (Republic of)',
#  'India',
#  'Indonesia',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'France',
#  'France',
#  'Sweden',
#  'Australia',
#  'Netherlands',
#  'United States of America',
#  'Honduras',
#  'China',
#  'China',
#  'France',
#  'China',
#  'United States of America',
#  'India',
#  'Germany',
#  'China',
#  'Venezuela (Bolivarian Republic of)',
#  'China',
#  'United States of America',
#  'China',
#  'China',
#  'China',
#  'Canada',
#  'France',
#  'Philippines',
#  'Singapore',
#  'Colombia',
#  'France',
#  'China',
#  'China',
#  'China',
#  'Germany',
#  'United States of America',
#  'Hong Kong',
#  'Canada',
#  'China',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'China',
#  'Brazil',
#  'Viet Nam',
#  'China',
#  'Korea (Republic of)',
#  'China',
#  'India',
#  'United States of America',
#  'China',
#  'China',
#  'United States of America',
#  'China',
#  'China',
#  'China',
#  'China',
#  'Viet Nam',
#  'Russian Federation',
#  'United States of America',
#  'China',
#  'China',
#  'United States of America',
#  'China',
#  'China',
#  'China',
#  'Canada',
#  'United States of America',
#  'China',
#  'China',
#  'Singapore',
#  'United States of America',
#  'United States of America',
#  'China',
#  'France',
#  'Germany',
#  'Singapore',
#  'Thailand',
#  'United States of America',
#  'Netherlands',
#  'China',
#  'China',
#  'Hong Kong',
#  'China',
#  'China',
#  'France',
#  'China',
#  'Singapore',
#  'Belgium',
#  'China',
#  'United States of America',
#  'United States of America',
#  'France',
#  'Germany',
#  'Brazil',
#  'China',
#  'China',
#  'China',
#  'China',
#  'United States of America',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'Turkey',
#  'India',
#  'Tanzania, United Republic of',
#  'United States of America',
#  'Thailand',
#  'China',
#  'Singapore',
#  'China',
#  'Viet Nam',
#  'China',
#  'Germany',
#  'China',
#  'China',
#  'Canada',
#  'Canada',
#  'Romania',
#  'China',
#  'Syrian Arab Republic',
#  'France',
#  'United States of America',
#  'Korea (Republic of)',
#  'Singapore',
#  'France',
#  'Thailand',
#  'Venezuela (Bolivarian Republic of)',
#  'Russian Federation',
#  'China',
#  'China',
#  'United States of America',
#  'Argentina',
#  'Germany',
#  'United States of America',
#  'Singapore',
#  'China',
#  'Sweden',
#  'United States of America',
#  'India',
#  'Netherlands',
#  'China',
#  'Germany',
#  'China',
#  'China',
#  'India',
#  'China',
#  'United States of America',
#  'China',
#  'Russian Federation',
#  'Mexico',
#  'Colombia',
#  'Singapore',
#  'China',
#  'China',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'Poland',
#  'United States of America',
#  'Iran (Islamic Republic of)',
#  'China',
#  'Indonesia',
#  'United States of America',
#  'China',
#  'China',
#  'China',
#  'Italy',
#  'China',
#  'China',
#  'Korea (Republic of)',
#  'Brazil',
#  'China',
#  'Korea (Republic of)',
#  'Korea (Republic of)',
#  'Germany',
#  'Indonesia',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'Italy',
#  'China',
#  'Hong Kong',
#  'Viet Nam',
#  'China',
#  'China',
#  'Poland',
#  'Hong Kong',
#  'United States of America',
#  'China',
#  'China',
#  'Philippines',
#  'Singapore',
#  'India',
#  'China',
#  'China',
#  'Taiwan (Province of China)',
#  'Argentina',
#  'Brazil',
#  'China',
#  'China',
#  'United States of America',
#  'Singapore',
#  'Hong Kong',
#  'China',
#  'China',
#  'United States of America',
#  'Poland',
#  'China',
#  'Singapore',
#  'India',
#  'China',
#  'Korea (Republic of)',
#  'India',
#  'India',
#  'Germany',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'Brazil',
#  'Singapore',
#  'Brazil',
#  'Taiwan (Province of China)',
#  'Spain',
#  'Nigeria',
#  'China',
#  'United States of America',
#  'France',
#  'China',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'United States of America',
#  'Japan',
#  'Venezuela (Bolivarian Republic of)',
#  'China',
#  'China',
#  'Korea (Republic of)',
#  'Germany',
#  'Singapore',
#  'Germany',
#  'Colombia',
#  'Germany',
#  'China',
#  'Korea (Republic of)',
#  'China',
#  'Canada',
#  'Singapore',
#  'United States of America',
#  'China',
#  'China',
#  'China',
#  'United States of America',
#  'China',
#  'Russian Federation',
#  'Argentina',
#  'China',
#  'China',
#  'China',
#  'Romania',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'Korea (Republic of)',
#  'China',
#  'Netherlands',
#  'China',
#  'China',
#  'Germany',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'China',
#  'Singapore',
#  'Netherlands',
#  'France',
#  'United States of America',
#  'Canada',
#  'Korea (Republic of)',
#  'Hong Kong',
#  'Panama',
#  'United States of America',
#  'Russian Federation',
#  'Hong Kong',
#  'Hong Kong',
#  'Hong Kong',
#  'Korea (Republic of)',
#  'China',
#  'Sweden',
#  'Hong Kong',
#  'Ukraine',
#  'China',
#  'China',
#  'United States of America',
#  'China',
#  'Colombia',
#  'China',
#  'Hong Kong',
#  'France',
#  'United States of America',
#  'China',
#  'China',
#  'France',
#  'Germany',
#  'France',
#  'Brazil',
#  'China',
#  'Russian Federation',
#  'China',
#  'Hong Kong',
#  'Canada',
#  'United States of America',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'Germany',
#  'France',
#  'Brazil',
#  'China',
#  'China',
#  'Thailand',
#  'Germany',
#  'Japan',
#  'China',
#  'China',
#  'Korea (Republic of)',
#  'China',
#  'Thailand',
#  'China',
#  'China',
#  'Brazil',
#  'China',
#  'Netherlands',
#  'France',
#  'Brazil',
#  'Germany',
#  'Korea (Republic of)',
#  'China',
#  'Singapore',
#  'Germany',
#  'Brazil',
#  'Nigeria',
#  'China',
#  'Taiwan (Province of China)',
#  'China',
#  'United States of America',
#  'Colombia',
#  'Italy',
#  'China',
#  'China',
#  'Viet Nam',
#  'China',
#  'United States of America',
#  'Indonesia',
#  'Russian Federation',
#  'Brazil',
#  'United States of America',
#  'China',
#  'Korea (Republic of)',
#  'China',
#  'Ukraine',
#  'China',
#  'Hong Kong',
#  'China',
#  'China',
#  'United States of America',
#  'China',
#  'Mexico',
#  'China',
#  'China',
#  'India',
#  'China',
#  'Hong Kong',
#  'China',
#  'Argentina',
#  'France',
#  'Indonesia',
#  'Japan',
#  'China',
#  'Hong Kong',
#  'China',
#  'Saudi Arabia',
#  'Singapore',
#  'China',
#  'United States of America',
#  'China',
#  'Singapore',
#  'China',
#  'France',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'France',
#  'Philippines',
#  'United States of America',
#  'United States of America',
#  'Argentina',
#  'China',
#  'Thailand',
#  'Singapore',
#  'China',
#  'China',
#  'China',
#  'France',
#  'China',
#  'Russian Federation',
#  'China',
#  'China',
#  'Brazil',
#  'Germany',
#  'China',
#  'Germany',
#  'United States of America',
#  'South Africa',
#  'China',
#  'France',
#  'Germany',
#  'India',
#  'China',
#  'Russian Federation',
#  'China',
#  'China',
#  'Viet Nam',
#  'China',
#  'China',
#  'Malaysia',
#  'Singapore',
#  'China',
#  'United States of America',
#  'China',
#  'Syrian Arab Republic',
#  'China',
#  'China',
#  'China',
#  'China',
#  'United States of America',
#  'China',
#  'China',
#  'China',
#  'Indonesia',
#  'France',
#  'United States of America',
#  'China',
#  'France',
#  'Hong Kong',
#  'Brazil',
#  'Netherlands',
#  'China',
#  'China',
#  'Russian Federation',
#  'Hong Kong',
#  'India',
#  'Japan',
#  'Thailand',
#  'Hong Kong',
#  'China',
#  'Greece',
#  'China',
#  'China',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'China',
#  'Singapore',
#  'China',
#  'Germany',
#  'Korea (Republic of)',
#  'Hong Kong',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'South Africa',
#  'France',
#  'Germany',
#  ...]

# %% [markdown]
# ### Groups all the countries with each other

# %%
rootCountries = resultCountries.map(lambda name: (name, 1)) \
          .reduceByKey(lambda a, b: a + b)
rootCountries.take(1)
# Out:
# [('Poland', 23)]

# %% [markdown]
# # Answer to list all the countries root fail ip addresses are from

# %%
rootCountries.collect()
# Out:
# [('Poland', 23),
#  ('India', 129),
#  (None, 7),
#  ('Germany', 122),
#  ('Thailand', 20),
#  ('Viet Nam', 44),
#  ('Uruguay', 3),
#  ('Ukraine', 18),
#  ('Canada', 60),
#  ('Japan', 29),
#  ('Taiwan (Province of China)', 23),
#  ('Bangladesh', 4),
#  ('Malaysia', 14),
#  ('Romania', 6),
#  ('Tunisia', 4),
#  ('Denmark', 2),
#  ('Belgium', 4),
#  ('Syrian Arab Republic', 2),
#  ('Saudi Arabia', 1),
#  ('Serbia', 2),
#  ('Uganda', 1),
#  ('United Arab Emirates', 2),
#  ('New Zealand', 1),
#  ('Finland', 2),
#  ('Mongolia', 1),
#  ('Cambodia', 1),
#  ('Zimbabwe', 1),
#  ('Guatemala', 1),
#  ('Mexico', 28),
#  ('Netherlands', 71),
#  ('Macao', 2),
#  ('Korea (Republic of)', 106),
#  ('Chile', 8),
#  ('Australia', 8),
#  ('Cyprus', 5),
#  ('Panama', 4),
#  ('Norway', 1),
#  ('Senegal', 2),
#  ('Mozambique', 1),
#  ('Algeria', 1),
#  ('Azerbaijan', 2),
#  ('Argentina', 30),
#  ('Spain', 12),
#  ('Ethiopia', 2),
#  ('United Kingdom of Great Britain and Northern Ireland', 48),
#  ('Portugal', 8),
#  ('Bulgaria', 3),
#  ('Ecuador', 4),
#  ('Slovenia', 2),
#  ('Morocco', 2),
#  ('Peru', 2),
#  ('Costa Rica', 1),
#  ('Uzbekistan', 3),
#  ('Austria', 1),
#  ('China', 1292),
#  ('Colombia', 26),
#  ('Hungary', 9),
#  ('Ireland', 2),
#  ('Malta', 2),
#  ('Venezuela (Bolivarian Republic of)', 8),
#  ('Sweden', 12),
#  ('Myanmar', 2),
#  ('Paraguay', 4),
#  ('Croatia', 6),
#  ('Indonesia', 45),
#  ('Pakistan', 6),
#  ('Sri Lanka', 2),
#  ('Czechia', 4),
#  ('Tanzania, United Republic of', 1),
#  ('Greece', 2),
#  ('Kazakhstan', 2),
#  ('Kenya', 2),
#  ('Libya', 1),
#  ('Belarus', 1),
#  ('France', 193),
#  ('Brazil', 102),
#  ('United States of America', 394),
#  ('Iran (Islamic Republic of)', 10),
#  ('Hong Kong', 110),
#  ('Singapore', 126),
#  ('Russian Federation', 85),
#  ('Nigeria', 4),
#  ('Italy', 21),
#  ('Egypt', 4),
#  ('South Africa', 10),
#  ('Turkey', 4),
#  ('Bolivia (Plurinational State of)', 5),
#  ('Honduras', 1),
#  ('Philippines', 11),
#  ('Dominican Republic', 1),
#  ('Slovakia', 1),
#  ('Lithuania', 1),
#  ('Jordan', 2),
#  ('Palestine, State of', 1),
#  ('Guadeloupe', 1),
#  ('Switzerland', 1)]

# %%
#resultCountries = ip6Addresses.map(lambda address: find_country(l))
#resultCountries.collect()

# %% [markdown]
# ### Gets all the fails that weren't root fails

# %%
nonRootFails = fails.filter(lambda line: line.find("root") < 0)
nonRootFails.take(5)
# Out:
# ['Dec 13 00:08:29 submitty sshd[19552]: Invalid user shalini from 27.128.173.81 port 49454',
#  'Dec 13 00:08:29 submitty sshd[19552]: pam_unix(sshd:auth): check pass; user unknown',
#  'Dec 13 00:08:29 submitty sshd[19552]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=27.128.173.81',
#  'Dec 13 00:08:32 submitty sshd[19552]: Failed password for invalid user shalini from 27.128.173.81 port 49454 ssh2',
#  'Dec 13 00:08:40 submitty sshd[19560]: Invalid user user5 from 134.175.17.32 port 44532']

# %% [markdown]
# # Answer to how many attempts by non root users is 88623

# %%
nonRootFails.count()
# Out:
# 88623

# %% [markdown]
# ### Fixing my ip method to work for non root messages

# %%
import re
def find_ip2( line ):
    ip = re.findall("\d+\\.\d+\\.\d+\\.\d+", breakdown_failed(line)[3])
    if(len(ip) > 0):
        return ip[0]
    else:
        return ""

# %% [markdown]
# ### Find the ip addresses for non roots in messages

# %%
import re
filternonRootFails = nonRootFails.filter(lambda line: len(breakdown_failed(line)[3])>1)
nonrootFailsIPAddress = filternonRootFails.map(lambda line: (find_ip2(line), breakdown_failed(line)[3]))
nonrootFailsIPAddress.take(30)
# Out:
# [('27.128.173.81', 'Invalid user shalini from 27.128.173.81 port 49454'),
#  ('', 'pam_unix(sshd:auth): check pass; user unknown'),
#  ('27.128.173.81',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=27.128.173.81'),
#  ('27.128.173.81',
#   'Failed password for invalid user shalini from 27.128.173.81 port 49454 ssh2'),
#  ('134.175.17.32', 'Invalid user user5 from 134.175.17.32 port 44532'),
#  ('', 'pam_unix(sshd:auth): check pass; user unknown'),
#  ('134.175.17.32',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=134.175.17.32'),
#  ('201.90.101.165', 'Invalid user lms from 201.90.101.165 port 44854'),
#  ('', 'pam_unix(sshd:auth): check pass; user unknown'),
#  ('201.90.101.165',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=201.90.101.165'),
#  ('134.175.17.32',
#   'Failed password for invalid user user5 from 134.175.17.32 port 44532 ssh2'),
#  ('134.175.17.32',
#   'Received disconnect from 134.175.17.32 port 44532:11: Bye Bye [preauth]'),
#  ('134.175.17.32',
#   'Disconnected from invalid user user5 134.175.17.32 port 44532 [preauth]'),
#  ('201.90.101.165',
#   'Failed password for invalid user lms from 201.90.101.165 port 44854 ssh2'),
#  ('201.90.101.165',
#   'Received disconnect from 201.90.101.165 port 44854:11: Bye Bye [preauth]'),
#  ('201.90.101.165',
#   'Disconnected from invalid user lms 201.90.101.165 port 44854 [preauth]'),
#  ('119.45.22.71', 'Invalid user ttf from 119.45.22.71 port 60804'),
#  ('', 'pam_unix(sshd:auth): check pass; user unknown'),
#  ('119.45.22.71',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=119.45.22.71'),
#  ('119.45.22.71',
#   'Failed password for invalid user ttf from 119.45.22.71 port 60804 ssh2'),
#  ('119.45.22.71',
#   'Received disconnect from 119.45.22.71 port 60804:11: Bye Bye [preauth]'),
#  ('119.45.22.71',
#   'Disconnected from invalid user ttf 119.45.22.71 port 60804 [preauth]'),
#  ('58.17.200.197', 'Invalid user finn from 58.17.200.197 port 49650'),
#  ('', 'pam_unix(sshd:auth): check pass; user unknown'),
#  ('58.17.200.197',
#   'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=58.17.200.197'),
#  ('58.17.200.197',
#   'Failed password for invalid user finn from 58.17.200.197 port 49650 ssh2'),
#  ('58.17.200.197',
#   'Received disconnect from 58.17.200.197 port 49650:11: Bye Bye [preauth]'),
#  ('58.17.200.197',
#   'Disconnected from invalid user finn 58.17.200.197 port 49650 [preauth]'),
#  ('',
#   'warning: /etc/hosts.allow, line 13: host name/name mismatch: static.vnpt.vn != dnsfirewall.wcupa.edu'),
#  ('14.161.45.187', 'Invalid user merle from 14.161.45.187 port 56273')]

# %% [markdown]
# ### Finds the unique ip addresses

# %%
groupingNonRoot = nonrootFailsIPAddress.groupByKey().mapValues(list)
groupingNonRoot.take(10)
# Out:
# [('',
#   ['pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'warning: /etc/hosts.allow, line 13: host name/name mismatch: static.vnpt.vn != dnsfirewall.wcupa.edu',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(177-069-227-169.static.ctbctelecom.com.br, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(HSI-KBW-185-002-140-155.hsi20.kabel-badenwuerttemberg.de, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(136-61-209-73.googlefiber.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(177-069-227-169.static.ctbctelecom.com.br, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(136-61-209-73.googlefiber.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(mail.ljcproyectos.com, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(static.cmcti.vn, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(zg-0915b-63.stretchoid.com, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(mail.ljcproyectos.com, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(host29.138-99-7.telmex.net.ar, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(static.cmcti.vn, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(mail.ljcproyectos.com, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(dsl-189-237-113-4-dyn.prod-infinitum.com.mx, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(host29.138-99-7.telmex.net.ar, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(201-91-210-130.customer.tdatabrasil.net.br, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'warning: /etc/hosts.allow, line 13: host name/name mismatch: winnti-scanner-victims-will-be-notified.threatsinkhole.com != dnsfirewall.wcupa.edu',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(static.cmcti.vn, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(host29.138-99-7.telmex.net.ar, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(201-91-210-130.customer.tdatabrasil.net.br, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(zg-0915a-37.stretchoid.com, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(223-197-151-55.static.imsbiz.com, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(223-197-151-55.static.imsbiz.com, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(static-200-116-195-124.une.net.co, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'warning: /etc/hosts.allow, line 13: host name/name mismatch: vmi473069.contaboserver.net != dnsfirewall.wcupa.edu',
#    'warning: /etc/hosts.allow, line 13: host name/name mismatch: vmi473069.contaboserver.net != dnsfirewall.wcupa.edu',
#    'warning: /etc/hosts.allow, line 13: host name/name mismatch: vmi473069.contaboserver.net != dnsfirewall.wcupa.edu',
#    'warning: /etc/hosts.allow, line 13: host name/name mismatch: vmi473069.contaboserver.net != dnsfirewall.wcupa.edu',
#    'warning: /etc/hosts.allow, line 13: host name/name mismatch: vmi473069.contaboserver.net != dnsfirewall.wcupa.edu',
#    'warning: /etc/hosts.allow, line 13: host name/name mismatch: vmi473069.contaboserver.net != dnsfirewall.wcupa.edu',
#    'warning: /etc/hosts.allow, line 13: host name/name mismatch: vmi473069.contaboserver.net != dnsfirewall.wcupa.edu',
#    'warning: /etc/hosts.allow, line 13: host name/name mismatch: vmi473069.contaboserver.net != dnsfirewall.wcupa.edu',
#    'warning: /etc/hosts.allow, line 13: host name/name mismatch: vmi473069.contaboserver.net != dnsfirewall.wcupa.edu',
#    'warning: /etc/hosts.allow, line 13: host name/name mismatch: vmi473069.contaboserver.net != dnsfirewall.wcupa.edu',
#    'warning: /etc/hosts.allow, line 13: host name/name mismatch: vmi473069.contaboserver.net != dnsfirewall.wcupa.edu',
#    'warning: /etc/hosts.allow, line 13: host name/name mismatch: vmi473069.contaboserver.net != dnsfirewall.wcupa.edu',
#    'warning: /etc/hosts.allow, line 13: host name/name mismatch: vmi473069.contaboserver.net != dnsfirewall.wcupa.edu',
#    'warning: /etc/hosts.allow, line 13: host name/name mismatch: vmi473069.contaboserver.net != dnsfirewall.wcupa.edu',
#    'warning: /etc/hosts.allow, line 13: host name/name mismatch: vmi473069.contaboserver.net != dnsfirewall.wcupa.edu',
#    'warning: /etc/hosts.allow, line 13: host name/name mismatch: vmi473069.contaboserver.net != dnsfirewall.wcupa.edu',
#    'warning: /etc/hosts.allow, line 13: host name/name mismatch: vmi473069.contaboserver.net != dnsfirewall.wcupa.edu',
#    'warning: /etc/hosts.allow, line 13: host name/name mismatch: vmi473069.contaboserver.net != dnsfirewall.wcupa.edu',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(46x146x136x8.static-business.perm.ertelecom.ru, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(static-200-116-195-124.une.net.co, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(mail5.corecorporativo.com, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(host-186-225-252-38.unetvale.com.br, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(46x146x136x8.static-business.perm.ertelecom.ru, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(linkisrv180.dvcimportaciones.com, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(static-200-116-195-124.une.net.co, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(linkisrv180.dvcimportaciones.com, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(mail5.corecorporativo.com, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(host-186-225-252-38.unetvale.com.br, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(46x146x136x8.static-business.perm.ertelecom.ru, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(linkisrv180.dvcimportaciones.com, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(mail5.corecorporativo.com, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(host-186-225-252-38.unetvale.com.br, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(91-231-213-51.obit.ru, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(linkisrv180.dvcimportaciones.com, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(184-175-47-179.cable.teksavvy.com, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'warning: /etc/hosts.allow, line 13: host name/name mismatch: shutcupid.com != dnsfirewall.wcupa.edu',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(91-231-213-51.obit.ru, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(static-43-254-43-122.ctrls.in, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(mail.jfc.com.ec, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(host-103-123-25-80.pky.kalteng.go.id, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(bento2.axa.de, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(184-175-47-179.cable.teksavvy.com, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(smtp3.teceng-gaming.com.ar, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(91-231-213-51.obit.ru, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(mail.jfc.com.ec, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(dsl-187-212-181-128-dyn.prod-infinitum.com.mx, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(bento2.axa.de, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(184-175-47-179.cable.teksavvy.com, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(smtp3.teceng-gaming.com.ar, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(pei-190-128-cxviii-clxxxv.une.net.co, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(dsl-187-212-181-128-dyn.prod-infinitum.com.mx, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(bento2.axa.de, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(smtp3.teceng-gaming.com.ar, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(editoracip.sfo1, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(dsl-187-212-181-128-dyn.prod-infinitum.com.mx, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'warning: /etc/hosts.allow, line 13: host name/name mismatch: 45-64-184-140.static.bangmod-idc.com != dnsfirewall.wcupa.edu',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(pool-54-72-121-181.telecel.com.py, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(91-231-213-51.obit.ru, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(ip-178-112-68-164.static.contabo.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(editoracip.sfo1, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(35-253.adsl.static.espeed.com.bn, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(191-5-100-133.dyn.redeglobaltelecom.net.br, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(zg-0915b-133.stretchoid.com, AF_INET) failed",
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(pool-54-72-121-181.telecel.com.py, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(pool-222-209-16-186.telecel.com.py, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(91-231-213-51.obit.ru, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(editoracip.sfo1, AF_INET) failed",
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
#    'pam_unix(sshd:auth): check pass; user unknown',
# ...
#    'Connection closed by invalid user admin 185.156.74.65 port 11172 [preauth]',
#    'Invalid user admin from 185.156.74.65 port 62125',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user admin from 185.156.74.65 port 62125 ssh2',
#    'Connection closed by invalid user admin 185.156.74.65 port 62125 [preauth]',
#    'Invalid user ubnt from 185.156.74.65 port 24814',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user ubnt from 185.156.74.65 port 24814 ssh2',
#    'Connection closed by invalid user ubnt 185.156.74.65 port 24814 [preauth]',
#    'Invalid user admin from 185.156.74.65 port 14826',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user admin from 185.156.74.65 port 14826 ssh2',
#    'Connection closed by invalid user admin 185.156.74.65 port 14826 [preauth]',
#    'Invalid user admin from 185.156.74.65 port 21156',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user admin from 185.156.74.65 port 21156 ssh2',
#    'Connection closed by invalid user admin 185.156.74.65 port 21156 [preauth]',
#    'Invalid user admin from 185.156.74.65 port 63114',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user admin from 185.156.74.65 port 63114 ssh2',
#    'Connection closed by invalid user admin 185.156.74.65 port 63114 [preauth]',
#    'Invalid user username from 185.156.74.65 port 52413',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user username from 185.156.74.65 port 52413 ssh2',
#    'Connection closed by invalid user username 185.156.74.65 port 52413 [preauth]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65  user=uucp',
#    'Failed password for uucp from 185.156.74.65 port 33931 ssh2',
#    'Connection closed by authenticating user uucp 185.156.74.65 port 33931 [preauth]',
#    'Invalid user mysql from 185.156.74.65 port 52943',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user mysql from 185.156.74.65 port 52943 ssh2',
#    'Connection closed by invalid user mysql 185.156.74.65 port 52943 [preauth]',
#    'Invalid user admin from 185.156.74.65 port 57441',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user admin from 185.156.74.65 port 57441 ssh2',
#    'Connection closed by invalid user admin 185.156.74.65 port 57441 [preauth]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65  user=sshd',
#    'Failed password for sshd from 185.156.74.65 port 48722 ssh2',
#    'Connection closed by authenticating user sshd 185.156.74.65 port 48722 [preauth]',
#    'Invalid user admin from 185.156.74.65 port 50383',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user admin from 185.156.74.65 port 50383 ssh2',
#    'Connection closed by invalid user admin 185.156.74.65 port 50383 [preauth]',
#    'Invalid user system from 185.156.74.65 port 63286',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user system from 185.156.74.65 port 63286 ssh2',
#    'Connection closed by invalid user system 185.156.74.65 port 63286 [preauth]',
#    'Invalid user support from 185.156.74.65 port 34896',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user support from 185.156.74.65 port 34896 ssh2',
#    'Connection closed by invalid user support 185.156.74.65 port 34896 [preauth]',
#    'Invalid user admin from 185.156.74.65 port 31065',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user admin from 185.156.74.65 port 31065 ssh2',
#    'Connection closed by invalid user admin 185.156.74.65 port 31065 [preauth]',
#    'Invalid user guest from 185.156.74.65 port 42127',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user guest from 185.156.74.65 port 42127 ssh2',
#    'Connection closed by invalid user guest 185.156.74.65 port 42127 [preauth]',
#    'Invalid user adobe1 from 185.156.74.65 port 5862',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user adobe1 from 185.156.74.65 port 5862 ssh2',
#    'Connection closed by invalid user adobe1 185.156.74.65 port 5862 [preauth]',
#    'Invalid user service from 185.156.74.65 port 61069',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user service from 185.156.74.65 port 61069 ssh2',
#    'Connection closed by invalid user service 185.156.74.65 port 61069 [preauth]',
#    'Invalid user ftp from 185.156.74.65 port 34566',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user ftp from 185.156.74.65 port 34566 ssh2',
#    'Connection closed by invalid user ftp 185.156.74.65 port 34566 [preauth]',
#    'Invalid user user from 185.156.74.65 port 20539',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user user from 185.156.74.65 port 20539 ssh2',
#    'Connection closed by invalid user user 185.156.74.65 port 20539 [preauth]',
#    'Invalid user operator from 185.156.74.65 port 30743',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user operator from 185.156.74.65 port 30743 ssh2',
#    'Connection closed by invalid user operator 185.156.74.65 port 30743 [preauth]',
#    'Invalid user admin from 185.156.74.65 port 1963',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user admin from 185.156.74.65 port 1963 ssh2',
#    'Connection closed by invalid user admin 185.156.74.65 port 1963 [preauth]',
#    'Invalid user ubnt from 185.156.74.65 port 59930',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user ubnt from 185.156.74.65 port 59930 ssh2',
#    'Connection closed by invalid user ubnt 185.156.74.65 port 59930 [preauth]',
#    'Invalid user admin from 185.156.74.65 port 6770',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user admin from 185.156.74.65 port 6770 ssh2',
#    'Connection closed by invalid user admin 185.156.74.65 port 6770 [preauth]',
#    'Invalid user ubnt from 185.156.74.65 port 13513',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user ubnt from 185.156.74.65 port 13513 ssh2',
#    'Connection closed by invalid user ubnt 185.156.74.65 port 13513 [preauth]',
#    'Invalid user admin from 185.156.74.65 port 42675',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user admin from 185.156.74.65 port 42675 ssh2',
#    'Connection closed by invalid user admin 185.156.74.65 port 42675 [preauth]',
#    'Invalid user admin from 185.156.74.65 port 5950',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user admin from 185.156.74.65 port 5950 ssh2',
#    'Connection closed by invalid user admin 185.156.74.65 port 5950 [preauth]',
#    'Invalid user admin from 185.156.74.65 port 47776',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user admin from 185.156.74.65 port 47776 ssh2',
#    'Connection closed by invalid user admin 185.156.74.65 port 47776 [preauth]',
#    'Invalid user username from 185.156.74.65 port 12678',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#    'Failed password for invalid user username from 185.156.74.65 port 12678 ssh2',
#    'Connection closed by invalid user username 185.156.74.65 port 12678 [preauth]',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65  user=uucp',
#    'Failed password for uucp from 185.156.74.65 port 39142 ssh2',
#    'Connection closed by authenticating user uucp 185.156.74.65 port 39142 [preauth]']),
#  ('61.181.80.253',
#   ['Invalid user lionya from 61.181.80.253 port 60023',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=61.181.80.253',
#    'Failed password for invalid user lionya from 61.181.80.253 port 60023 ssh2',
#    'Received disconnect from 61.181.80.253 port 60023:11: Bye Bye [preauth]',
#    'Disconnected from invalid user lionya 61.181.80.253 port 60023 [preauth]',
#    'Invalid user rudolph from 61.181.80.253 port 57070',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=61.181.80.253',
#    'Failed password for invalid user rudolph from 61.181.80.253 port 57070 ssh2',
#    'Invalid user test from 61.181.80.253 port 57250',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=61.181.80.253',
#    'Failed password for invalid user test from 61.181.80.253 port 57250 ssh2',
#    'Received disconnect from 61.181.80.253 port 40134:11: Bye Bye [preauth]']),
#  ('140.143.24.26',
#   ['Invalid user named from 140.143.24.26 port 44024',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=140.143.24.26',
#    'Failed password for invalid user named from 140.143.24.26 port 44024 ssh2',
#    'Received disconnect from 140.143.24.26 port 44024:11: Bye Bye [preauth]',
#    'Disconnected from invalid user named 140.143.24.26 port 44024 [preauth]',
#    'Invalid user ubuntu from 140.143.24.26 port 41138',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=140.143.24.26',
#    'Failed password for invalid user ubuntu from 140.143.24.26 port 41138 ssh2',
#    'Received disconnect from 140.143.24.26 port 41138:11: Bye Bye [preauth]',
#    'Disconnected from invalid user ubuntu 140.143.24.26 port 41138 [preauth]',
#    'Invalid user git from 140.143.24.26 port 49292',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=140.143.24.26',
#    'Failed password for invalid user git from 140.143.24.26 port 49292 ssh2']),
#  ('79.127.36.98',
#   ['Invalid user signup from 79.127.36.98 port 48340',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=79.127.36.98',
#    'Failed password for invalid user signup from 79.127.36.98 port 48340 ssh2',
#    'Received disconnect from 79.127.36.98 port 48340:11: Bye Bye [preauth]',
#    'Disconnected from invalid user signup 79.127.36.98 port 48340 [preauth]',
#    'Invalid user csgo2 from 79.127.36.98 port 49008',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=79.127.36.98',
#    'Failed password for invalid user csgo2 from 79.127.36.98 port 49008 ssh2',
#    'Received disconnect from 79.127.36.98 port 49008:11: Bye Bye [preauth]',
#    'Disconnected from invalid user csgo2 79.127.36.98 port 49008 [preauth]',
#    'Invalid user zimbra from 79.127.36.98 port 56586',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=79.127.36.98',
#    'Failed password for invalid user zimbra from 79.127.36.98 port 56586 ssh2',
#    'Received disconnect from 79.127.36.98 port 56586:11: Bye Bye [preauth]',
#    'Disconnected from invalid user zimbra 79.127.36.98 port 56586 [preauth]',
#    'Received disconnect from 79.127.36.98 port 38242:11: Bye Bye [preauth]',
#    'Received disconnect from 79.127.36.98 port 35482:11: Bye Bye [preauth]',
#    'Received disconnect from 79.127.36.98 port 37472:11: Bye Bye [preauth]',
#    'Received disconnect from 79.127.36.98 port 39474:11: Bye Bye [preauth]']),
#  ('157.230.183.86',
#   ['Invalid user giovanni from 157.230.183.86 port 53250',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=157.230.183.86',
#    'Failed password for invalid user giovanni from 157.230.183.86 port 53250 ssh2',
#    'Received disconnect from 157.230.183.86 port 53250:11: Bye Bye [preauth]',
#    'Disconnected from invalid user giovanni 157.230.183.86 port 53250 [preauth]',
#    'Invalid user tim from 157.230.183.86 port 56842',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=157.230.183.86',
#    'Failed password for invalid user tim from 157.230.183.86 port 56842 ssh2',
#    'Received disconnect from 157.230.183.86 port 56842:11: Bye Bye [preauth]',
#    'Disconnected from invalid user tim 157.230.183.86 port 56842 [preauth]']),
#  ('70.108.185.122',
#   ["warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(nsg-corporate-70.108.185.122.airtel.in, AF_INET) failed",
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(nsg-corporate-70.108.185.122.airtel.in, AF_INET) failed",
#    "warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(nsg-corporate-70.108.185.122.airtel.in, AF_INET) failed"]),
#  ('177.12.2.53',
#   ['Invalid user amod from 177.12.2.53 port 60226',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=177.12.2.53',
#    'Failed password for invalid user amod from 177.12.2.53 port 60226 ssh2',
#    'Received disconnect from 177.12.2.53 port 60226:11: Bye Bye [preauth]',
#    'Disconnected from invalid user amod 177.12.2.53 port 60226 [preauth]']),
#  ('68.183.238.175',
#   ['Invalid user ttf from 68.183.238.175 port 52336',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=68.183.238.175',
#    'Failed password for invalid user ttf from 68.183.238.175 port 52336 ssh2',
#    'Received disconnect from 68.183.238.175 port 52336:11: Bye Bye [preauth]',
#    'Disconnected from invalid user ttf 68.183.238.175 port 52336 [preauth]',
#    'Invalid user ts3 from 68.183.238.175 port 57004',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=68.183.238.175',
#    'Failed password for invalid user ts3 from 68.183.238.175 port 57004 ssh2',
#    'Invalid user info1 from 68.183.238.175 port 51898',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=68.183.238.175',
#    'Failed password for invalid user info1 from 68.183.238.175 port 51898 ssh2',
#    'Received disconnect from 68.183.238.175 port 51898:11: Bye Bye [preauth]',
#    'Disconnected from invalid user info1 68.183.238.175 port 51898 [preauth]',
#    'Received disconnect from 68.183.238.175 port 38354:11: Bye Bye [preauth]',
#    'Invalid user test1 from 68.183.238.175 port 36994',
#    'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=68.183.238.175',
#    'Failed password for invalid user test1 from 68.183.238.175 port 36994 ssh2'])]

# %% [markdown]
# ### Lists the ip unique ip addresses has to remove the first one because first one is nothing

# %%
nonRootFailsAddress = groupingNonRoot.map(lambda group: group[0])
header = nonRootFailsAddress.first()
realAttempt = nonRootFailsAddress.filter(lambda x: x != header)
realAttempt.take(5)
# Out:
# ['134.175.17.32',
#  '185.156.74.65',
#  '61.181.80.253',
#  '140.143.24.26',
#  '79.127.36.98']

# %% [markdown]
# ### Splits the unique ip addresses by removing the dot

# %%
nonRootIPAddressSplit = realAttempt.map(lambda line: line.split('.'))
nonRootIPAddressSplit.collect()
# Out:
# [['134', '175', '17', '32'],
#  ['185', '156', '74', '65'],
#  ['61', '181', '80', '253'],
#  ['140', '143', '24', '26'],
#  ['79', '127', '36', '98'],
#  ['157', '230', '183', '86'],
#  ['70', '108', '185', '122'],
#  ['177', '12', '2', '53'],
#  ['68', '183', '238', '175'],
#  ['213', '32', '111', '53'],
#  ['138', '99', '7', '29'],
#  ['111', '231', '88', '39'],
#  ['110', '42', '1', '213'],
#  ['178', '128', '127', '126'],
#  ['165', '22', '210', '35'],
#  ['139', '199', '35', '168'],
#  ['161', '117', '57', '88'],
#  ['132', '232', '98', '228'],
#  ['198', '199', '73', '239'],
#  ['60', '235', '24', '222'],
#  ['193', '169', '252', '59'],
#  ['42', '200', '80', '42'],
#  ['81', '70', '46', '31'],
#  ['95', '111', '253', '158'],
#  ['54', '37', '71', '204'],
#  ['123', '231', '160', '98'],
#  ['128', '199', '1', '184'],
#  ['189', '1', '163', '101'],
#  ['179', '253', '179', '216'],
#  ['81', '30', '179', '11'],
#  ['122', '51', '211', '131'],
#  ['206', '189', '157', '50'],
#  ['51', '178', '47', '46'],
#  ['128', '199', '167', '234'],
#  ['161', '35', '51', '18'],
#  ['51', '68', '121', '235'],
#  ['109', '160', '22', '211'],
#  ['185', '46', '18', '99'],
#  ['142', '112', '81', '183'],
#  ['119', '28', '83', '164'],
#  ['137', '74', '119', '50'],
#  ['106', '12', '25', '152'],
#  ['173', '254', '225', '123'],
#  ['113', '209', '128', '114'],
#  ['167', '172', '164', '37'],
#  ['98', '142', '139', '4'],
#  ['60', '174', '40', '118'],
#  ['183', '159', '127', '86'],
#  ['106', '12', '33', '195'],
#  ['165', '22', '63', '151'],
#  ['181', '121', '72', '54'],
#  ['128', '116', '154', '5'],
#  ['118', '24', '5', '125'],
#  ['104', '248', '41', '56'],
#  ['84', '213', '201', '188'],
#  ['218', '106', '92', '66'],
#  ['175', '162', '9', '53'],
#  ['52', '243', '103', '160'],
#  ['111', '93', '2', '53'],
#  ['119', '29', '119', '151'],
#  ['141', '98', '81', '196'],
#  ['149', '56', '100', '209'],
#  ['203', '135', '20', '36'],
#  ['142', '93', '121', '47'],
#  ['62', '92', '48', '242'],
#  ['181', '48', '46', '195'],
#  ['146', '59', '154', '120'],
#  ['88', '135', '1', '138'],
#  ['107', '182', '177', '38'],
#  ['119', '9', '93', '85'],
#  ['2', '18', '157', '61'],
#  ['218', '92', '0', '171'],
#  ['82', '117', '226', '12'],
#  ['92', '190', '177', '39'],
#  ['187', '188', '107', '115'],
#  ['58', '221', '204', '114'],
#  ['122', '228', '19', '79'],
#  ['194', '67', '90', '236'],
#  ['142', '238', '81', '118'],
#  ['211', '159', '171', '238'],
#  ['125', '99', '72', '27'],
#  ['177', '152', '124', '23'],
#  ['49', '235', '120', '117'],
#  ['122', '51', '178', '89'],
#  ['111', '231', '165', '121'],
#  ['89', '35', '50', '5'],
#  ['52', '175', '223', '122'],
#  ['138', '197', '180', '102'],
#  ['111', '75', '164', '143'],
#  ['194', '190', '143', '48'],
#  ['36', '250', '5', '117'],
#  ['178', '62', '187', '136'],
#  ['128', '201', '76', '184'],
#  ['52', '82', '43', '234'],
#  ['64', '227', '13', '158'],
#  ['93', '76', '71', '130'],
#  ['40', '87', '87', '198'],
#  ['111', '229', '215', '184'],
#  ['218', '22', '27', '14'],
#  ['167', '71', '226', '130'],
#  ['129', '28', '193', '154'],
#  ['117', '2', '22', '85'],
#  ['1', '11', '201', '18'],
#  ['185', '123', '164', '52'],
#  ['175', '24', '95', '240'],
#  ['142', '93', '254', '122'],
#  ['124', '13', '248', '206'],
#  ['211', '75', '215', '176'],
#  ['216', '215', '13', '59'],
#  ['89', '45', '226', '116'],
#  ['60', '254', '104', '109'],
#  ['45', '80', '64', '246'],
#  ['106', '75', '132', '3'],
#  ['119', '45', '223', '42'],
#  ['119', '45', '26', '117'],
#  ['167', '248', '133', '39'],
#  ['14', '141', '61', '171'],
#  ['115', '78', '4', '219'],
#  ['111', '2', '23', '244'],
#  ['49', '232', '55', '26'],
#  ['179', '108', '19', '214'],
#  ['49', '235', '11', '137'],
#  ['112', '21', '191', '10'],
#  ['192', '162', '68', '185'],
#  ['49', '233', '77', '12'],
#  ['51', '68', '190', '223'],
#  ['81', '86', '206', '220'],
#  ['59', '15', '3', '197'],
#  ['103', '43', '185', '142'],
#  ['183', '82', '102', '66'],
#  ['152', '32', '144', '26'],
#  ['81', '68', '224', '66'],
#  ['162', '142', '125', '37'],
#  ['42', '192', '128', '191'],
#  ['103', '136', '40', '88'],
#  ['116', '24', '64', '29'],
#  ['182', '61', '147', '176'],
#  ['129', '204', '245', '6'],
#  ['101', '255', '81', '91'],
#  ['148', '245', '13', '21'],
#  ['172', '93', '40', '173'],
#  ['106', '54', '83', '253'],
#  ['211', '253', '129', '225'],
#  ['134', '175', '218', '239'],
#  ['103', '79', '90', '72'],
#  ['117', '172', '253', '135'],
#  ['119', '29', '91', '38'],
#  ['102', '98', '88', '110'],
#  ['161', '35', '148', '75'],
#  ['192', '241', '237', '98'],
#  ['119', '45', '51', '206'],
#  ['139', '155', '17', '74'],
#  ['49', '232', '204', '241'],
#  ['52', '152', '238', '18'],
#  ['160', '251', '21', '74'],
#  ['49', '235', '107', '186'],
#  ['192', '241', '237', '214'],
#  ['14', '49', '38', '47'],
#  ['60', '246', '171', '51'],
#  ['45', '82', '137', '35'],
#  ['222', '90', '28', '99'],
#  ['139', '59', '159', '0'],
#  ['167', '71', '1', '6'],
#  ['221', '232', '57', '161'],
#  ['204', '48', '28', '157'],
#  ['165', '22', '115', '214'],
#  ['220', '76', '192', '95'],
#  ['120', '92', '79', '133'],
#  ['50', '75', '7', '82'],
#  ['103', '238', '69', '169'],
#  ['140', '143', '144', '140'],
#  ['2', '232', '250', '91'],
#  ['81', '68', '238', '7'],
#  ['120', '136', '29', '201'],
#  ['188', '166', '226', '47'],
#  ['81', '70', '145', '250'],
#  ['220', '117', '141', '40'],
#  ['119', '45', '205', '97'],
#  ['111', '229', '192', '233'],
#  ['119', '45', '213', '69'],
#  ['94', '57', '252', '133'],
#  ['37', '187', '117', '187'],
#  ['49', '234', '43', '39'],
#  ['71', '6', '165', '200'],
#  ['94', '191', '38', '203'],
#  ['113', '142', '58', '155'],
#  ['195', '136', '66', '5'],
#  ['150', '158', '4', '230'],
#  ['114', '103', '137', '254'],
#  ['176', '235', '82', '165'],
#  ['149', '202', '56', '228'],
#  ['111', '57', '0', '90'],
#  ['142', '93', '138', '73'],
#  ['170', '106', '155', '8'],
#  ['138', '197', '167', '213'],
#  ['146', '59', '157', '181'],
#  ['49', '233', '30', '96'],
#  ['148', '66', '143', '140'],
#  ['104', '236', '111', '220'],
#  ['177', '73', '2', '57'],
#  ['120', '203', '160', '18'],
#  ['133', '242', '231', '162'],
#  ['202', '44', '40', '193'],
#  ['111', '90', '190', '52'],
#  ['139', '59', '96', '95'],
#  ['182', '151', '59', '205'],
#  ['65', '0', '220', '72'],
#  ['51', '75', '16', '138'],
#  ['167', '114', '155', '2'],
#  ['139', '99', '40', '44'],
#  ['120', '92', '149', '124'],
#  ['49', '234', '94', '59'],
#  ['183', '6', '107', '68'],
#  ['144', '34', '193', '83'],
#  ['192', '241', '237', '197'],
#  ['190', '144', '139', '76'],
#  ['42', '248', '78', '4'],
#  ['161', '35', '118', '14'],
#  ['190', '55', '5', '142'],
#  ['115', '159', '90', '184'],
#  ['162', '142', '125', '56'],
#  ['80', '98', '150', '9'],
#  ['116', '92', '219', '162'],
#  ['143', '110', '250', '97'],
#  ['188', '166', '187', '179'],
#  ['119', '28', '51', '99'],
#  ['5', '232', '197', '241'],
#  ['61', '160', '251', '98'],
#  ['118', '89', '248', '224'],
#  ['111', '189', '220', '177'],
#  ['177', '220', '189', '111'],
#  ['96', '45', '173', '209'],
#  ['46', '101', '173', '231'],
#  ['103', '47', '57', '165'],
#  ['112', '78', '3', '39'],
#  ['109', '77', '135', '217'],
#  ['190', '64', '213', '155'],
#  ['117', '51', '150', '202'],
#  ['222', '112', '220', '12'],
#  ['101', '206', '162', '208'],
#  ['179', '211', '32', '189'],
#  ['84', '96', '26', '63'],
#  ['192', '241', '234', '235'],
#  ['157', '230', '220', '179'],
#  ['103', '63', '108', '25'],
#  ['161', '35', '30', '208'],
#  ['111', '230', '244', '13'],
#  ['76', '233', '80', '93'],
#  ['187', '162', '61', '184'],
#  ['141', '105', '132', '91'],
#  ['27', '199', '140', '25'],
#  ['122', '51', '154', '84'],
#  ['36', '90', '15', '63'],
#  ['139', '59', '10', '186'],
#  ['161', '189', '157', '7'],
#  ['193', '70', '0', '228'],
#  ['111', '231', '199', '243'],
#  ['45', '151', '88', '213'],
#  ['101', '231', '146', '36'],
#  ['103', '78', '17', '250'],
#  ['103', '99', '206', '1'],
#  ['89', '20', '89', '125'],
#  ['125', '89', '20', '89'],
#  ['106', '13', '94', '131'],
#  ['46', '101', '154', '242'],
#  ['200', '27', '212', '22'],
#  ['159', '11', '89', '125'],
#  ['113', '76', '17', '95'],
#  ['119', '45', '184', '182'],
#  ['123', '18', '79', '223'],
#  ['223', '31', '12', '34'],
#  ['66', '143', '231', '89'],
#  ['106', '12', '132', '224'],
#  ['146', '185', '180', '57'],
#  ['140', '143', '0', '121'],
#  ['104', '131', '249', '57'],
#  ['191', '31', '104', '17'],
#  ['139', '59', '255', '166'],
#  ['49', '247', '213', '18'],
#  ['150', '158', '212', '170'],
#  ['162', '62', '26', '122'],
#  ['58', '181', '98', '179'],
#  ['81', '68', '208', '67'],
#  ['206', '189', '128', '215'],
#  ['182', '76', '142', '58'],
#  ['200', '70', '56', '204'],
#  ['213', '32', '111', '52'],
#  ['185', '172', '213', '251'],
#  ['167', '99', '99', '80'],
#  ['203', '189', '253', '170'],
#  ['186', '4', '235', '4'],
#  ['14', '6', '215', '163'],
#  ['196', '220', '67', '2'],
#  ['124', '137', '205', '59'],
#  ['157', '245', '168', '191'],
#  ['94', '129', '87', '222'],
#  ['120', '133', '136', '75'],
#  ['175', '24', '187', '87'],
#  ['81', '16', '122', '128'],
#  ['42', '118', '242', '189'],
#  ['200', '196', '249', '170'],
#  ['112', '78', '188', '194'],
#  ['87', '251', '122', '178'],
#  ['64', '79', '70', '125'],
#  ['190', '0', '8', '134'],
#  ['111', '40', '50', '116'],
#  ['142', '44', '211', '57'],
#  ['165', '21', '103', '192'],
#  ['190', '205', '111', '140'],
#  ['61', '222', '155', '229'],
#  ['49', '235', '221', '172'],
#  ['158', '69', '220', '67'],
#  ['14', '35', '229', '148'],
#  ['64', '227', '5', '37'],
#  ['178', '62', '22', '142'],
#  ['59', '126', '51', '197'],
#  ['145', '239', '80', '14'],
#  ['118', '27', '25', '231'],
#  ['139', '72', '156', '27'],
#  ['169', '62', '84', '7'],
#  ['144', '34', '201', '197'],
#  ['81', '69', '243', '46'],
#  ['153', '120', '166', '129'],
#  ['5', '196', '70', '107'],
#  ['209', '97', '160', '105'],
#  ['165', '22', '99', '216'],
#  ['91', '121', '91', '82'],
#  ['54', '37', '159', '12'],
#  ['115', '159', '214', '247'],
#  ['62', '234', '94', '202'],
#  ['51', '195', '91', '161'],
#  ['38', '72', '132', '186'],
#  ['191', '235', '71', '181'],
#  ['178', '128', '217', '58'],
#  ['192', '241', '238', '208'],
#  ['18', '188', '77', '20'],
#  ['119', '45', '151', '50'],
#  ['118', '89', '247', '113'],
#  ['212', '199', '145', '190'],
#  ['37', '46', '246', '186'],
#  ['218', '102', '138', '206'],
#  ['51', '75', '131', '235'],
#  ['95', '165', '26', '27'],
#  ['95', '71', '196', '62'],
#  ['190', '155', '88', '40'],
#  ['116', '49', '107', '236'],
#  ['118', '25', '192', '122'],
#  ['123', '58', '5', '243'],
#  ['2', '45', '179', '5'],
#  ['114', '245', '243', '18'],
#  ['202', '168', '64', '147'],
#  ['14', '35', '215', '226'],
#  ['82', '96', '38', '203'],
#  ['179', '119', '178', '121'],
#  ['46', '200', '31', '86'],
#  ['68', '175', '59', '13'],
#  ['190', '140', '240', '74'],
#  ['149', '34', '23', '85'],
#  ['157', '230', '119', '220'],
#  ['103', '231', '46', '66'],
#  ['165', '22', '123', '86'],
#  ['119', '45', '223', '241'],
#  ['115', '76', '7', '86'],
#  ['116', '103', '247', '48'],
#  ['119', '27', '185', '241'],
#  ['45', '183', '193', '1'],
#  ['103', '235', '170', '162'],
#  ['104', '248', '238', '105'],
#  ['91', '121', '173', '98'],
#  ['186', '215', '235', '9'],
#  ['221', '181', '185', '18'],
#  ['177', '139', '194', '62'],
#  ['129', '159', '36', '93'],
#  ['151', '253', '125', '136'],
#  ['152', '67', '47', '139'],
#  ['111', '2', '188', '193'],
#  ['167', '172', '142', '125'],
#  ['38', '72', '132', '202'],
#  ['183', '6', '49', '68'],
#  ['191', '5', '102', '74'],
#  ['192', '35', '169', '48'],
#  ['221', '181', '185', '198'],
#  ['221', '131', '165', '81'],
#  ['175', '24', '233', '78'],
#  ['42', '192', '125', '230'],
#  ['106', '12', '95', '45'],
#  ['159', '65', '98', '176'],
#  ['132', '232', '84', '44'],
#  ['103', '105', '67', '146'],
#  ['119', '28', '160', '192'],
#  ['138', '68', '94', '173'],
#  ['177', '25', '153', '138'],
#  ['150', '136', '220', '58'],
#  ['49', '51', '163', '133'],
#  ['53', '55', '149', '201'],
#  ['49', '234', '22', '37'],
#  ['183', '221', '243', '20'],
#  ['202', '154', '180', '51'],
#  ['165', '227', '45', '249'],
#  ['15', '207', '58', '214'],
#  ['51', '178', '80', '229'],
#  ['188', '166', '4', '178'],
#  ['134', '209', '217', '28'],
#  ['46', '101', '191', '77'],
#  ['138', '197', '142', '81'],
#  ['104', '236', '124', '45'],
#  ['104', '131', '88', '229'],
#  ['185', '32', '222', '172'],
#  ['79', '168', '204', '180'],
#  ['159', '65', '144', '102'],
#  ['158', '69', '199', '225'],
#  ['210', '183', '46', '232'],
#  ['161', '35', '57', '121'],
#  ['35', '230', '150', '70'],
#  ['103', '145', '190', '25'],
#  ['139', '199', '4', '191'],
#  ['101', '36', '173', '44'],
#  ['113', '31', '113', '99'],
#  ['159', '65', '139', '163'],
#  ['61', '7', '235', '211'],
#  ['121', '58', '212', '108'],
#  ['118', '89', '229', '84'],
#  ['103', '233', '2', '162'],
#  ['51', '254', '102', '19'],
#  ['119', '149', '136', '46'],
#  ['111', '161', '74', '105'],
#  ['183', '234', '11', '43'],
#  ['51', '83', '129', '228'],
#  ['61', '147', '107', '95'],
#  ['23', '115', '214', '92'],
#  ['13', '82', '24', '91'],
#  ['61', '80', '179', '118'],
#  ['217', '12', '66', '26'],
#  ['129', '204', '249', '36'],
#  ['190', '245', '22', '47'],
#  ['49', '235', '141', '55'],
#  ['107', '170', '20', '247'],
#  ['111', '229', '3', '206'],
#  ['111', '229', '33', '175'],
#  ['115', '159', '157', '154'],
#  ['42', '194', '210', '230'],
#  ['202', '21', '123', '124'],
#  ['210', '105', '82', '53'],
#  ['89', '248', '174', '3'],
#  ['49', '235', '35', '79'],
#  ['119', '27', '165', '49'],
#  ['107', '175', '33', '240'],
#  ['138', '99', '7', '75'],
#  ['153', '120', '170', '120'],
#  ['157', '92', '13', '155'],
#  ['46', '185', '138', '163'],
#  ['49', '234', '239', '91'],
#  ['128', '199', '129', '144'],
#  ['76', '169', '19', '239'],
#  ['167', '99', '110', '179'],
#  ['118', '89', '138', '117'],
#  ['77', '68', '20', '215'],
#  ['67', '207', '89', '137'],
#  ['132', '232', '89', '186'],
#  ['192', '241', '239', '108'],
#  ['58', '233', '240', '94'],
#  ['42', '194', '206', '209'],
#  ['196', '47', '67', '180'],
#  ['52', '149', '180', '228'],
#  ['218', '71', '141', '62'],
#  ['211', '112', '18', '37'],
#  ['106', '53', '238', '111'],
#  ['119', '123', '225', '208'],
#  ['139', '155', '42', '189'],
#  ['216', '221', '152', '148'],
#  ['170', '210', '176', '254'],
#  ['211', '180', '175', '198'],
#  ['181', '40', '73', '86'],
#  ['46', '218', '7', '227'],
#  ['106', '13', '216', '115'],
#  ['159', '89', '115', '126'],
#  ['185', '78', '133', '208'],
#  ['54', '219', '196', '112'],
#  ['218', '91', '95', '180'],
#  ['207', '154', '244', '110'],
#  ['122', '51', '40', '61'],
#  ['177', '69', '237', '54'],
#  ['181', '49', '246', '20'],
#  ['106', '13', '46', '123'],
#  ['103', '26', '136', '173'],
#  ['144', '217', '163', '179'],
#  ['183', '196', '214', '64'],
#  ['190', '98', '228', '54'],
#  ['49', '234', '91', '78'],
#  ['54', '241', '69', '245'],
#  ['106', '51', '73', '204'],
#  ['134', '19', '106', '21'],
#  ['136', '228', '161', '67'],
#  ['200', '6', '137', '235'],
#  ['79', '120', '54', '174'],
#  ['159', '65', '238', '245'],
#  ['162', '243', '116', '41'],
#  ['192', '241', '239', '55'],
#  ['87', '98', '182', '93'],
#  ['3', '112', '67', '81'],
#  ['186', '1', '205', '230'],
#  ['180', '166', '228', '228'],
#  ['40', '65', '159', '0'],
#  ['38', '72', '132', '194'],
#  ['118', '27', '19', '96'],
#  ['115', '77', '188', '228'],
#  ['91', '121', '86', '22'],
#  ['203', '210', '232', '136'],
#  ['115', '75', '181', '149'],
#  ['194', '5', '177', '243'],
#  ['156', '67', '221', '90'],
#  ['106', '12', '86', '205'],
#  ['192', '241', '237', '154'],
#  ['192', '241', '175', '250'],
#  ['157', '230', '38', '176'],
#  ['201', '218', '215', '106'],
#  ['134', '209', '96', '131'],
#  ['159', '89', '130', '178'],
#  ['51', '68', '189', '69'],
#  ['173', '225', '104', '57'],
#  ['85', '234', '117', '151'],
#  ['114', '84', '212', '242'],
#  ['51', '68', '94', '206'],
#  ['194', '152', '206', '17'],
#  ['159', '89', '115', '74'],
#  ['159', '89', '106', '247'],
#  ['2', '136', '179', '77'],
#  ['212', '64', '7', '134'],
#  ['106', '12', '23', '44'],
#  ['192', '241', '238', '5'],
#  ['96', '21', '19', '172'],
#  ['177', '39', '222', '53'],
#  ['134', '73', '154', '173'],
#  ['190', '104', '149', '194'],
#  ['128', '199', '246', '104'],
#  ['49', '233', '214', '16'],
#  ['20', '43', '33', '55'],
#  ['150', '136', '12', '28'],
#  ['76', '251', '85', '6'],
#  ['111', '231', '71', '157'],
#  ['198', '98', '53', '133'],
#  ['67', '253', '3', '15'],
#  ['120', '53', '121', '178'],
#  ['34', '95', '137', '251'],
#  ['202', '29', '232', '90'],
#  ['162', '243', '128', '161'],
#  ['165', '22', '208', '192'],
#  ['64', '52', '85', '184'],
#  ['192', '241', '223', '186'],
#  ['174', '137', '56', '118'],
#  ['121', '227', '0', '17'],
#  ['51', '75', '255', '250'],
#  ['176', '118', '46', '219'],
#  ['210', '12', '168', '79'],
#  ['112', '122', '5', '6'],
#  ['195', '228', '148', '10'],
#  ['54', '223', '37', '106'],
#  ['106', '37', '223', '54'],
#  ['159', '65', '185', '39'],
#  ['119', '45', '214', '43'],
#  ['106', '12', '123', '239'],
#  ['160', '153', '251', '87'],
#  ['68', '183', '215', '41'],
#  ['50', '25', '13', '135'],
#  ['175', '193', '13', '3'],
#  ['192', '241', '232', '227'],
#  ['221', '204', '145', '112'],
#  ['106', '53', '232', '157'],
#  ['196', '49', '33', '58'],
#  ['159', '65', '77', '254'],
#  ['125', '74', '28', '28'],
#  ['109', '244', '35', '48'],
#  ['49', '234', '25', '89'],
#  ['191', '13', '117', '211'],
#  ['35', '185', '59', '105'],
#  ['62', '234', '157', '228'],
#  ['139', '155', '239', '207'],
#  ['201', '48', '115', '235'],
#  ['58', '220', '10', '164'],
#  ['157', '230', '62', '50'],
#  ['155', '94', '134', '152'],
#  ['122', '51', '204', '45'],
#  ['218', '92', '0', '248'],
#  ['190', '96', '237', '25'],
#  ['201', '103', '204', '219'],
#  ['210', '179', '174', '113'],
#  ['106', '55', '150', '24'],
#  ['212', '64', '78', '151'],
#  ['218', '29', '188', '139'],
#  ['192', '35', '168', '32'],
#  ['223', '99', '170', '130'],
#  ['129', '211', '77', '44'],
#  ['206', '189', '174', '127'],
#  ['178', '128', '147', '39'],
#  ['128', '199', '124', '216'],
#  ['119', '45', '18', '205'],
#  ['111', '229', '194', '130'],
#  ['165', '227', '63', '165'],
#  ['49', '234', '94', '200'],
#  ['111', '229', '1', '180'],
#  ['116', '3', '198', '246'],
#  ['51', '83', '68', '213'],
#  ['193', '112', '85', '35'],
#  ['67', '216', '209', '28'],
#  ['120', '53', '118', '140'],
#  ['165', '22', '57', '175'],
#  ['106', '12', '28', '152'],
#  ['120', '92', '119', '90'],
#  ['80', '52', '72', '24'],
#  ['128', '199', '206', '90'],
#  ['1', '119', '153', '110'],
#  ['109', '227', '63', '3'],
#  ['117', '192', '46', '40'],
#  ['119', '45', '42', '241'],
#  ['159', '89', '48', '31'],
#  ['83', '143', '86', '62'],
#  ['118', '97', '23', '26'],
#  ['165', '22', '215', '99'],
#  ['197', '156', '65', '138'],
#  ['111', '229', '134', '68'],
#  ['160', '20', '200', '234'],
#  ['13', '71', '46', '226'],
#  ['104', '192', '6', '17'],
#  ['181', '111', '181', '50'],
#  ['125', '35', '92', '130'],
#  ['133', '167', '95', '209'],
#  ['79', '182', '39', '144'],
#  ['46', '37', '188', '139'],
#  ['51', '210', '96', '169'],
#  ['128', '199', '31', '95'],
#  ['161', '117', '56', '255'],
#  ['95', '227', '234', '14'],
#  ['178', '128', '127', '62'],
#  ['217', '182', '141', '253'],
#  ['49', '234', '224', '88'],
#  ['73', '89', '52', '125'],
#  ['104', '140', '242', '72'],
#  ['14', '56', '180', '103'],
#  ['165', '227', '7', '187'],
#  ['159', '203', '72', '14'],
#  ['60', '178', '14', '100'],
#  ['64', '139', '73', '170'],
#  ['51', '210', '190', '104'],
#  ['119', '29', '102', '152'],
#  ['159', '65', '147', '235'],
#  ['119', '29', '177', '222'],
#  ['159', '89', '237', '57'],
#  ['103', '56', '43', '225'],
#  ['54', '38', '65', '55'],
#  ['192', '241', '214', '181'],
#  ['37', '46', '150', '14'],
#  ['60', '191', '29', '210'],
#  ['200', '96', '49', '76'],
#  ['45', '116', '35', '165'],
#  ['128', '199', '95', '60'],
#  ['49', '232', '111', '165'],
#  ['49', '234', '181', '60'],
#  ['187', '189', '65', '241'],
#  ['182', '84', '124', '63'],
#  ['201', '187', '41', '255'],
#  ['182', '61', '173', '200'],
#  ['103', '40', '8', '185'],
#  ['113', '246', '243', '65'],
#  ['173', '215', '63', '148'],
#  ['91', '122', '159', '193'],
#  ['13', '72', '64', '49'],
#  ['27', '115', '50', '114'],
#  ['176', '118', '216', '227'],
#  ['71', '230', '64', '96'],
#  ['91', '121', '67', '151'],
#  ['192', '241', '239', '21'],
#  ['67', '42', '76', '22'],
#  ['146', '56', '201', '34'],
#  ['222', '117', '13', '84'],
#  ['61', '185', '220', '60'],
#  ['104', '248', '63', '30'],
#  ['101', '32', '46', '20'],
#  ['221', '219', '103', '30'],
#  ['111', '229', '109', '26'],
#  ['176', '124', '59', '32'],
#  ['106', '54', '236', '226'],
#  ['157', '230', '212', '3'],
#  ['152', '250', '43', '54'],
#  ['46', '146', '240', '185'],
#  ['14', '98', '117', '60'],
#  ['173', '167', '195', '113'],
#  ['116', '255', '216', '34'],
#  ['145', '239', '23', '254'],
#  ['159', '65', '78', '3'],
#  ['179', '174', '50', '74'],
#  ['51', '77', '223', '17'],
#  ['64', '227', '77', '253'],
#  ['139', '198', '121', '63'],
#  ['51', '178', '27', '206'],
#  ['148', '70', '118', '113'],
#  ['187', '17', '48', '86'],
#  ['51', '158', '189', '0'],
#  ['111', '92', '61', '220'],
#  ['45', '240', '88', '35'],
#  ['129', '226', '134', '163'],
#  ['106', '75', '234', '61'],
#  ['66', '150', '71', '32'],
#  ['218', '89', '222', '16'],
#  ['49', '235', '132', '88'],
#  ['103', '105', '130', '136'],
#  ['106', '124', '131', '70'],
#  ['149', '128', '186', '220'],
#  ['101', '187', '123', '101'],
#  ['81', '71', '26', '161'],
#  ['43', '229', '153', '76'],
#  ['70', '179', '94', '30'],
#  ['212', '64', '77', '173'],
#  ['118', '25', '195', '244'],
#  ['220', '92', '137', '31'],
#  ['167', '99', '110', '42'],
#  ['198', '27', '82', '155'],
#  ['106', '12', '153', '211'],
#  ['172', '81', '240', '237'],
#  ['206', '189', '93', '218'],
#  ['106', '75', '240', '86'],
#  ['202', '147', '192', '242'],
#  ['103', '144', '180', '18'],
#  ['5', '160', '52', '130'],
#  ['122', '51', '149', '86'],
#  ['54', '38', '183', '181'],
#  ['196', '38', '70', '24'],
#  ['125', '65', '79', '161'],
#  ['36', '133', '109', '2'],
#  ['111', '95', '141', '34'],
#  ['140', '249', '205', '149'],
#  ['34', '70', '217', '179'],
#  ['167', '71', '46', '139'],
#  ['58', '87', '119', '220'],
#  ['113', '110', '166', '134'],
#  ['37', '212', '242', '208'],
#  ['193', '252', '189', '37'],
#  ['54', '147', '194', '17'],
#  ['129', '145', '193', '194'],
#  ['106', '12', '207', '236'],
#  ['46', '182', '19', '49'],
#  ['188', '165', '56', '214'],
#  ['157', '245', '108', '35'],
#  ['200', '216', '30', '196'],
#  ['159', '89', '196', '75'],
#  ['106', '12', '218', '171'],
#  ['115', '159', '98', '28'],
#  ['136', '232', '226', '202'],
#  ['161', '35', '11', '118'],
#  ['103', '45', '107', '149'],
#  ['119', '61', '19', '87'],
#  ['109', '225', '99', '187'],
#  ['51', '222', '29', '39'],
#  ['49', '232', '119', '253'],
#  ['49', '232', '56', '88'],
#  ['45', '55', '88', '16'],
#  ['106', '116', '118', '90'],
#  ['106', '55', '37', '174'],
#  ['106', '52', '132', '186'],
#  ['34', '101', '193', '173'],
#  ['212', '64', '80', '169'],
#  ['5', '8', '10', '202'],
#  ['200', '116', '188', '62'],
#  ['192', '241', '139', '236'],
#  ['197', '5', '145', '27'],
#  ['179', '43', '60', '1'],
#  ['222', '128', '14', '106'],
#  ['159', '89', '202', '95'],
#  ['72', '43', '65', '222'],
#  ['185', '152', '151', '10'],
#  ['194', '156', '184', '28'],
#  ['159', '203', '85', '196'],
#  ['123', '252', '89', '103'],
#  ['2', '82', '175', '119'],
#  ['185', '51', '76', '199'],
#  ['124', '156', '225', '159'],
#  ['129', '204', '115', '121'],
#  ['159', '65', '142', '192'],
#  ['119', '28', '89', '228'],
#  ['106', '53', '202', '86'],
#  ['59', '125', '145', '88'],
#  ['142', '93', '103', '141'],
#  ['119', '45', '140', '59'],
#  ['103', '42', '214', '18'],
#  ['218', '92', '0', '184'],
#  ['200', '95', '239', '22'],
#  ['179', '210', '169', '148'],
#  ['167', '99', '14', '237'],
#  ['61', '133', '232', '248'],
#  ['61', '133', '232', '253'],
#  ['128', '199', '170', '33'],
#  ['113', '162', '184', '22'],
#  ['165', '227', '144', '49'],
#  ['147', '147', '84', '206'],
#  ['129', '204', '45', '118'],
#  ['189', '203', '72', '138'],
#  ['67', '216', '223', '29'],
#  ['159', '89', '174', '217'],
#  ['188', '27', '33', '153'],
#  ['23', '97', '155', '197'],
#  ['185', '32', '222', '173'],
#  ['59', '144', '48', '34'],
#  ['222', '187', '238', '87'],
#  ['39', '129', '18', '28'],
#  ['82', '196', '14', '163'],
#  ['80', '182', '120', '119'],
#  ['51', '178', '24', '61'],
#  ['119', '28', '60', '45'],
#  ['106', '54', '219', '237'],
#  ['91', '207', '40', '45'],
#  ['199', '115', '228', '202'],
#  ['171', '244', '139', '236'],
#  ['104', '214', '34', '1'],
#  ['119', '45', '246', '61'],
#  ['161', '97', '64', '180'],
#  ['190', '52', '34', '43'],
#  ['150', '109', '114', '58'],
#  ['41', '226', '28', '83'],
#  ['118', '24', '142', '170'],
#  ['172', '245', '211', '58'],
#  ['197', '5', '145', '102'],
#  ['220', '88', '1', '208'],
#  ['139', '199', '94', '100'],
#  ['101', '32', '45', '10'],
#  ['18', '221', '29', '76'],
#  ['111', '224', '248', '191'],
#  ['210', '104', '112', '207'],
#  ['129', '28', '157', '199'],
#  ['72', '42', '162', '79'],
#  ['49', '234', '107', '24'],
#  ['59', '27', '124', '26'],
#  ['114', '99', '232', '2'],
#  ['218', '249', '73', '54'],
#  ['49', '233', '15', '54'],
#  ['14', '232', '214', '138'],
#  ['200', '73', '128', '181'],
#  ['222', '252', '30', '29'],
#  ['51', '210', '5', '171'],
#  ['203', '130', '255', '2'],
#  ['154', '120', '242', '70'],
#  ['178', '212', '144', '5'],
#  ['185', '123', '164', '54'],
#  ['111', '229', '26', '25'],
#  ['181', '55', '95', '52'],
#  ['185', '120', '28', '19'],
#  ['51', '77', '213', '136'],
#  ['106', '12', '80', '246'],
#  ['67', '205', '163', '45'],
#  ['138', '68', '184', '70'],
#  ['165', '22', '68', '84'],
#  ['203', '98', '76', '172'],
#  ['222', '75', '1', '197'],
#  ['111', '231', '82', '143'],
#  ['103', '42', '214', '128'],
#  ['195', '245', '239', '83'],
#  ['34', '82', '103', '75'],
#  ['114', '231', '82', '30'],
#  ['103', '76', '252', '6'],
#  ['93', '117', '174', '151'],
#  ['183', '129', '159', '211'],
#  ['190', '85', '67', '171'],
#  ['35', '161', '186', '220'],
#  ['110', '164', '189', '53'],
#  ['220', '247', '201', '109'],
#  ['77', '199', '194', '217'],
#  ['118', '25', '24', '84'],
#  ['137', '74', '198', '18'],
#  ['106', '55', '4', '113'],
#  ['222', '190', '145', '130'],
#  ['159', '65', '196', '65'],
#  ['107', '175', '150', '83'],
#  ['46', '101', '224', '184'],
#  ['13', '71', '21', '123'],
#  ['142', '93', '143', '46'],
#  ['58', '87', '94', '75'],
#  ['81', '68', '176', '101'],
#  ['14', '232', '210', '96'],
#  ['65', '190', '128', '233'],
#  ['212', '47', '230', '238'],
#  ['182', '61', '147', '252'],
#  ['106', '13', '207', '205'],
#  ['167', '99', '109', '254'],
#  ['81', '68', '198', '31'],
#  ['159', '89', '38', '228'],
#  ['118', '89', '63', '234'],
#  ['95', '182', '120', '176'],
#  ['176', '235', '192', '133'],
#  ['23', '105', '215', '254'],
#  ['129', '28', '14', '23'],
#  ['119', '45', '52', '62'],
#  ['193', '112', '213', '187'],
#  ['49', '247', '204', '78'],
#  ['191', '194', '9', '106'],
#  ['104', '145', '223', '166'],
#  ['13', '49', '16', '6'],
#  ['177', '229', '65', '182'],
#  ['37', '221', '183', '10'],
#  ['64', '225', '64', '215'],
#  ['177', '103', '229', '58'],
#  ['185', '63', '46', '208'],
#  ['122', '14', '211', '208'],
#  ['222', '98', '34', '86'],
#  ['206', '189', '121', '234'],
#  ['128', '70', '119', '70'],
#  ['14', '152', '112', '181'],
#  ['68', '183', '86', '159'],
#  ['186', '9', '22', '125'],
#  ['101', '32', '26', '159'],
#  ['76', '186', '73', '35'],
#  ['119', '96', '92', '223'],
#  ['114', '67', '82', '217'],
#  ['71', '92', '88', '102'],
#  ['158', '101', '7', '100'],
#  ['195', '222', '163', '54'],
#  ['119', '29', '115', '153'],
#  ['118', '70', '233', '117'],
#  ['96', '66', '79', '73'],
#  ['138', '68', '24', '88'],
#  ['49', '234', '233', '30'],
#  ['82', '120', '224', '145'],
#  ['198', '199', '67', '58'],
#  ['51', '254', '100', '56'],
#  ['196', '1', '97', '216'],
#  ['80', '66', '146', '84'],
#  ['152', '136', '169', '198'],
#  ['73', '207', '192', '158'],
#  ['188', '166', '242', '83'],
#  ['68', '170', '66', '96'],
#  ['164', '132', '145', '70'],
#  ['113', '116', '5', '139'],
#  ['145', '253', '133', '50'],
#  ['106', '54', '89', '231'],
#  ['51', '77', '150', '118'],
#  ['200', '146', '75', '58'],
#  ['103', '4', '217', '138'],
#  ['119', '27', '166', '193'],
#  ['156', '96', '114', '73'],
#  ['106', '54', '220', '54'],
#  ['154', '34', '24', '212'],
#  ['103', '199', '162', '153'],
#  ['192', '241', '234', '137'],
#  ['128', '199', '131', '150'],
#  ['62', '210', '201', '246'],
#  ['118', '24', '146', '186'],
#  ['146', '59', '154', '68'],
#  ['88', '121', '22', '235'],
#  ['192', '241', '154', '168'],
#  ['201', '243', '233', '85'],
#  ['18', '232', '176', '40'],
#  ['45', '80', '64', '230'],
#  ['45', '158', '199', '156'],
#  ['182', '180', '128', '134'],
#  ['111', '40', '214', '20'],
#  ['54', '37', '68', '191'],
#  ['157', '92', '13', '105'],
#  ['37', '44', '244', '140'],
#  ['200', '169', '6', '206'],
#  ['84', '42', '204', '37'],
#  ['178', '62', '49', '137'],
#  ['157', '230', '230', '152'],
#  ['165', '227', '205', '128'],
#  ['111', '229', '198', '182'],
#  ['54', '39', '22', '191'],
#  ['181', '188', '134', '133'],
#  ['106', '12', '96', '91'],
#  ['188', '166', '109', '87'],
#  ['164', '90', '190', '224'],
#  ['83', '58', '135', '21'],
#  ['51', '111', '110', '36'],
#  ['103', '204', '52', '66'],
#  ['36', '82', '205', '202'],
#  ['217', '182', '169', '183'],
#  ['36', '133', '54', '123'],
#  ['218', '108', '52', '58'],
#  ['60', '241', '53', '60'],
#  ['49', '234', '100', '188'],
#  ['81', '68', '69', '68'],
#  ['181', '210', '30', '243'],
#  ['39', '155', '215', '94'],
#  ['47', '92', '111', '112'],
#  ['193', '70', '91', '79'],
#  ['109', '228', '168', '80'],
#  ['188', '226', '192', '115'],
#  ['112', '85', '42', '85'],
#  ['58', '250', '86', '44'],
#  ['72', '167', '227', '34'],
#  ['119', '45', '240', '49'],
#  ['161', '35', '6', '188'],
#  ['159', '65', '158', '172'],
#  ['159', '65', '123', '91'],
#  ['161', '35', '49', '78'],
#  ['192', '144', '230', '43'],
#  ['129', '204', '12', '9'],
#  ['91', '53', '85', '115'],
#  ['200', '44', '50', '155'],
#  ['120', '132', '99', '101'],
#  ['45', '250', '37', '136'],
#  ['104', '218', '48', '98'],
#  ['81', '68', '70', '18'],
#  ['120', '236', '105', '190'],
#  ['198', '27', '66', '37'],
#  ...]

# %% [markdown]
# ### Turning the non root ip address into decimal ip address for ipv4

# %%
nonRootDecimalIP = nonRootIPAddressSplit.map(lambda line: ip_conversion(line))
nonRootDecimalIP.collect()
# Out:
# [2259620128,
#  3114027585,
#  1035292925,
#  2358188058,
#  1333732450,
#  2649143126,
#  1181530490,
#  2970354229,
#  1152904879,
#  3575672629,
#  2321745693,
#  1877432359,
#  1848246741,
#  2994765694,
#  2769736227,
#  2345083816,
#  2708814168,
#  2229822180,
#  3334949359,
#  1022040286,
#  3249142843,
#  717770794,
#  1363553823,
#  1601174942,
#  908412876,
#  2078777442,
#  2160525752,
#  3171001189,
#  3019748312,
#  1360966411,
#  2050216835,
#  3468533042,
#  867315502,
#  2160568298,
#  2703438610,
#  860125675,
#  1839208147,
#  3106804323,
#  2389725623,
#  1998345124,
#  2303358770,
#  1779177880,
#  2919162235,
#  1909555314,
#  2813109285,
#  1653508868,
#  1018046582,
#  3080683350,
#  1779179971,
#  2769698711,
#  3044624438,
#  2155125253,
#  1981285757,
#  1761093944,
#  1423296956,
#  3664403522,
#  2946631989,
#  888367008,
#  1868366389,
#  1998419863,
#  2372030916,
#  2503501009,
#  3414627364,
#  2388490543,
#  1046229234,
#  3039833795,
#  2453379704,
#  1485242762,
#  1807135014,
#  1997102421,
#  34774333,
#  3663462571,
#  1383457292,
#  1556001063,
#  3149687667,
#  987614322,
#  2061767503,
#  3259194092,
#  2397983094,
#  3550456814,
#  2103658523,
#  2979560471,
#  837515381,
#  2050208345,
#  1877452153,
#  1495478789,
#  883941242,
#  2328212582,
#  1867228303,
#  3267268400,
#  620365173,
#  2990455688,
#  2160676024,
#  877800426,
#  1088621982,
#  1565280130,
#  676812742,
#  1877333944,
#  3658881806,
#  2806506114,
#  2166145434,
#  1963071061,
#  17549586,
#  3111887924,
#  2937610224,
#  2388524666,
#  2081290446,
#  3544962992,
#  3637972283,
#  1496179316,
#  1023305837,
#  760234230,
#  1783333891,
#  1999494954,
#  1999444597,
#  2818082087,
#  244137387,
#  1934492891,
#  1862408180,
#  837302042,
#  3010204630,
#  837487497,
#  1880473354,
#  3231859897,
#  837373196,
#  860143327,
#  1364643548,
#  990839749,
#  1730918798,
#  3075630658,
#  2552270874,
#  1363468354,
#  2727247141,
#  717258943,
#  1736976472,
#  1947746333,
#  3057488816,
#  2177692934,
#  1711231323,
#  2499087637,
#  2891786413,
#  1781945341,
#  3556606433,
#  2259671791,
#  1733253704,
#  1974271367,
#  1998412582,
#  1717721198,
#  2703463499,
#  3237080418,
#  1999451086,
#  2342195530,
#  837340401,
#  882437650,
#  2700809546,
#  837512122,
#  3237080534,
#  238102063,
#  1022798643,
#  760383779,
#  3730447459,
#  2335940352,
#  2806448390,
#  3722983841,
#  3425705117,
#  2769712086,
#  3696017503,
#  2019315589,
#  843777874,
#  1743668649,
#  2358218892,
#  48822875,
#  1363471879,
#  2022186441,
#  3165053487,
#  1363579386,
#  3698691368,
#  1999490401,
#  1877328105,
#  1999492421,
#  1580858501,
#  633042363,
#  837430055,
#  1191617992,
#  1589585611,
#  1905146523,
#  3280486917,
#  2526938342,
#  1919388158,
#  2968212133,
#  2513058020,
#  1866006618,
#  2388494921,
#  2859113224,
#  2328209365,
#  2453380533,
#  837361248,
#  2487390092,
#  1760325596,
#  2974351929,
#  2026610706,
#  2247288738,
#  3391891649,
#  1868217908,
#  2335924319,
#  3063364557,
#  1090575432,
#  860557450,
#  2809305858,
#  2338531372,
#  2019333500,
#  837443131,
#  3070651204,
#  2418196819,
#  3237080517,
#  3197143884,
#  720915972,
#  2703455758,
#  3191276942,
#  1939823288,
#  2727247160,
#  1348638217,
#  1952242594,
#  2406414945,
#  3165043635,
#  1998336867,
#  99141105,
#  1033960290,
#  1985607904,
#  1874713777,
#  2984033647,
#  1613606353,
#  778415591,
#  1731148197,
#  1884160807,
#  1833797593,
#  3191920027,
#  1966315210,
#  3731938316,
#  1708040912,
#  3016958141,
#  1415584319,
#  3237079787,
#  2649152691,
#  1732209689,
#  2703433424,
#  1877406733,
#  1290358877,
#  3147972024,
#  2372502619,
#  466062361,
#  2050202196,
#  609881919,
#  2335902394,
#  2713558279,
#  3242590436,
#  1877460979,
#  764893397,
#  1709675044,
#  1733169658,
#  1734594049,
#  1494505853,
#  2102989913,
#  1779261059,
#  778410738,
#  3357266966,
#  2668321149,
#  1900810591,
#  1999485110,
#  2064797663,
#  3743353890,
#  1116727129,
#  1779205344,
#  2461643833,
#  2358182009,
#  1753479481,
#  3206506513,
#  2335965094,
#  838325522,
#  2526991530,
#  2721979002,
#  984965811,
#  1363464259,
#  3468525783,
#  3058470458,
#  3360045260,
#  3575672628,
#  3115111931,
#  2808308560,
#  3418226090,
#  3120884484,
#  235329443,
#  3302769410,
#  2089405755,
#  2650122431,
#  1585534942,
#  2022017099,
#  2937633623,
#  1360034432,
#  712438461,
#  3368352170,
#  1884208322,
#  1476098738,
#  1078937213,
#  3187673222,
#  1864905332,
#  2385302329,
#  2769643456,
#  3201134476,
#  1037999077,
#  837541292,
#  2655378499,
#  237233556,
#  1088619813,
#  2990413454,
#  998126533,
#  2448379918,
#  1981487591,
#  2336791579,
#  2839434247,
#  2418198981,
#  1363538734,
#  2574820993,
#  96749163,
#  3512836201,
#  2769707992,
#  1534679890,
#  908435212,
#  1939855095,
#  1055547082,
#  868440993,
#  642286778,
#  3219867573,
#  2994788666,
#  3237080784,
#  314330388,
#  1999476530,
#  1985607537,
#  3569848766,
#  623834810,
#  3664153294,
#  860586987,
#  1604655643,
#  1598538814,
#  3197851688,
#  1949395948,
#  1981399162,
#  2067400179,
#  36549381,
#  1928721170,
#  3400024211,
#  237230050,
#  1382033099,
#  3010966137,
#  784867158,
#  1152334605,
#  3196907594,
#  2502039381,
#  2649126876,
#  1743203906,
#  2769714006,
#  1999495153,
#  1934362454,
#  1952970544,
#  1998305777,
#  767017217,
#  1743497890,
#  1761144425,
#  1534700898,
#  3134712585,
#  3719674130,
#  2978726462,
#  2174690397,
#  2549972360,
#  2554539915,
#  1862450369,
#  2813103741,
#  642286794,
#  3070636356,
#  3204802122,
#  3223562544,
#  3719674310,
#  3716392273,
#  2937645390,
#  717258214,
#  1779195693,
#  2671862448,
#  2229818412,
#  1734951826,
#  1998364864,
#  2319736493,
#  2971244938,
#  2525551674,
#  825467781,
#  892835273,
#  837424677,
#  3084776212,
#  3399136307,
#  2783129081,
#  265239254,
#  867324133,
#  3164996786,
#  2261899548,
#  778420045,
#  2328202833,
#  1760328749,
#  1753438437,
#  3105939116,
#  1336462516,
#  2671874150,
#  2655373281,
#  3535220456,
#  2703440249,
#  602314310,
#  1737604633,
#  2345075903,
#  1696902444,
#  1897886051,
#  2671872931,
#  1023929299,
#  2033898604,
#  1985602900,
#  1743323810,
#  872310291,
#  2006288430,
#  1872841321,
#  3085568811,
#  861110756,
#  1033071455,
#  393467484,
#  223483995,
#  1028698998,
#  3641459226,
#  2177693988,
#  3203733039,
#  837520695,
#  1806308599,
#  1877279694,
#  1877287343,
#  1939840410,
#  717411046,
#  3390405500,
#  3530117685,
#  1509469699,
#  837493583,
#  1998300465,
#  1806639600,
#  2321745739,
#  2574822008,
#  2640055707,
#  783911587,
#  837480283,
#  2160558480,
#  1286149103,
#  2808311475,
#  1985579637,
#  1296307415,
#  1137662345,
#  2229819834,
#  3237080940,
#  988409950,
#  717410001,
#  3291431860,
#  882226404,
#  3662122302,
#  3547337253,
#  1781919343,
#  2004607440,
#  2342202045,
#  3638401172,
#  2865934590,
#  3551834054,
#  3039316310,
#  786040803,
#  1779292275,
#  2673439614,
#  3108931024,
#  920372336,
#  3663421364,
#  3483038830,
#  2050172989,
#  2974149942,
#  3039950356,
#  1779248763,
#  1729792173,
#  2430182323,
#  3083130432,
#  3194151990,
#  837442382,
#  921781749,
#  1781746124,
#  2249419285,
#  2296684867,
#  3355871723,
#  1333278382,
#  2671898357,
#  2733863977,
#  3237080887,
#  1466087005,
#  57688913,
#  3120680422,
#  3030836452,
#  675389184,
#  642286786,
#  1981485920,
#  1934474468,
#  1534678550,
#  3419596936,
#  1934341525,
#  3255153139,
#  2621693274,
#  1779193549,
#  3237080474,
#  3237064698,
#  2649106096,
#  3386562410,
#  2261868675,
#  2673443506,
#  860142917,
#  2917230649,
#  1441428887,
#  1918162162,
#  860118734,
#  3264794129,
#  2673439562,
#  2673437431,
#  42513229,
#  3560966022,
#  1779177260,
#  3237080581,
#  1611994028,
#  2972180021,
#  2252970669,
#  3194525122,
#  2160588392,
#  837408272,
#  338370871,
#  2525498396,
#  1291539718,
#  1877428125,
#  3328324997,
#  1140654863,
#  2016770482,
#  576686587,
#  3390957658,
#  2733867169,
#  2769735872,
#  1077171640,
#  3237076922,
#  2928228470,
#  2044919825,
#  860618746,
#  2960535259,
#  3524044879,
#  1887044870,
#  3286537226,
#  920593770,
#  1780866870,
#  2671884583,
#  1999492651,
#  1779203055,
#  2694445911,
#  1152898857,
#  840502663,
#  2948664579,
#  3237079267,
#  3721171312,
#  1781917853,
#  3291554106,
#  2671857150,
#  2102008860,
#  1844716336,
#  837425497,
#  3205330387,
#  599341929,
#  1055563236,
#  2342252495,
#  3375395819,
#  987499172,
#  2649112114,
#  2606663320,
#  2050214957,
#  3663462648,
#  3194023193,
#  3379023067,
#  3534990961,
#  1782027800,
#  3560984215,
#  3659381899,
#  3223562272,
#  3747850882,
#  2178108716,
#  3468537471,
#  2994770727,
#  2160557272,
#  1999442637,
#  1877328514,
#  2783133605,
#  837443272,
#  1877279156,
#  1946404598,
#  861095125,
#  3245364515,
#  1138282780,
#  2016769676,
#  2769697199,
#  1779178648,
#  2019325786,
#  1345603608,
#  2160578138,
#  24615278,
#  1843609347,
#  1975529000,
#  1999448817,
#  2673422367,
#  1401902654,
#  1986074394,
#  2769737571,
#  3315351946,
#  1877313092,
#  2685716714,
#  222768866,
#  1757414929,
#  3043996978,
#  2099469442,
#  2242338769,
#  1337337744,
#  774225035,
#  869425321,
#  2160533343,
#  2708814079,
#  1608772110,
#  2994765630,
#  3652619773,
#  837476440,
#  1230582909,
#  1754067528,
#  238597223,
#  2783119291,
#  2680899598,
#  1018302052,
#  1082870186,
#  869449320,
#  1998415512,
#  2671875051,
#  1998434782,
#  2673470777,
#  1731734497,
#  908476727,
#  3237074613,
#  623810062,
#  1019157970,
#  3361747276,
#  762586021,
#  2160549692,
#  837316517,
#  837465404,
#  3149742577,
#  3058990143,
#  3384486399,
#  3057495496,
#  1730676921,
#  1912009537,
#  2916564884,
#  1534762945,
#  222838833,
#  460534386,
#  2960578787,
#  1206272096,
#  1534673815,
#  3237080853,
#  1126845462,
#  2453195042,
#  3732213076,
#  1035590716,
#  1761099550,
#  1696607764,
#  3722143518,
#  1877306650,
#  2960931616,
#  1781984482,
#  2649150467,
#  2566531894,
#  781381817,
#  241333564,
#  2913452913,
#  1962924066,
#  2448365566,
#  2671857155,
#  3014537802,
#  860741393,
#  1088638461,
#  2345040191,
#  867310542,
#  2487645809,
#  3138465878,
#  866041088,
#  1868316124,
#  770725923,
#  2179106467,
#  1783360061,
#  1117144864,
#  3663322640,
#  837518424,
#  1734967944,
#  1786544966,
#  2508241628,
#  1706785637,
#  1363614369,
#  736467276,
#  1186160158,
#  3560983981,
#  1981400052,
#  3697051935,
#  2808311338,
#  3323679387,
#  1779210707,
#  2891051245,
#  3468516826,
#  1783361622,
#  3398680818,
#  1737536530,
#  94385282,
#  2050200918,
#  908507061,
#  3290842648,
#  2101432225,
#  612723970,
#  1868533026,
#  2365181333,
#  575068595,
#  2806460043,
#  978810844,
#  1903076998,
#  634712784,
#  3254566181,
#  915653137,
#  2173813186,
#  1779224556,
#  783684401,
#  3164944598,
#  2650106915,
#  3369606852,
#  2673460299,
#  1779227307,
#  1939825180,
#  2296963786,
#  2703428470,
#  1731029909,
#  2000491351,
#  1843487675,
#  870194471,
#  837318653,
#  837302360,
#  758601744,
#  1786017370,
#  1781999022,
#  1781826746,
#  577094061,
#  3560984745,
#  84413130,
#  3363093566,
#  3237055468,
#  3305476379,
#  3005955073,
#  3732934250,
#  2673461855,
#  1210794462,
#  3113785098,
#  3265050652,
#  2680903108,
#  2080135527,
#  38973303,
#  3107146951,
#  2090656159,
#  2177659769,
#  2671873728,
#  1998346724,
#  1781910102,
#  998084952,
#  2388486029,
#  1999473723,
#  1730860562,
#  3663462584,
#  3361730326,
#  3016927636,
#  2808286957,
#  1032186104,
#  1032186109,
#  2160568865,
#  1906489366,
#  2783154225,
#  2475906254,
#  2177641846,
#  3184216202,
#  1138286365,
#  2673454809,
#  3155894681,
#  392272837,
#  3105939117,
#  999305250,
#  3736858199,
#  662770204,
#  1388580515,
#  1354135671,
#  867309629,
#  1998339117,
#  1781980141,
#  1540302893,
#  3346261194,
#  2884930540,
#  1758863873,
#  1999500861,
#  2707505332,
#  3191087659,
#  2523755066,
#  702684243,
#  1981320874,
#  2901791546,
#  3305476454,
#  3696755152,
#  2345098852,
#  1696607498,
#  316480844,
#  1877014719,
#  3530059983,
#  2166136263,
#  1210753615,
#  837446424,
#  991656986,
#  1919150082,
#  3673770294,
#  837357366,
#  250140298,
#  3360260277,
#  3741064733,
#  869402027,
#  3414359810,
#  2591617606,
#  3000274949,
#  3111887926,
#  1877285401,
#  3040304948,
#  3111656467,
#  860738952,
#  1779192054,
#  1137550125,
#  2319759430,
#  2769699924,
#  3412217004,
#  3729457605,
#  1877430927,
#  1730860672,
#  3287674707,
#  575825739,
#  1927762462,
#  1733098502,
#  1567993495,
#  3078725587,
#  3193258923,
#  597801692,
#  1856290101,
#  3707226477,
#  1304937177,
#  1981356116,
#  2303378962,
#  1781990513,
#  3737031042,
#  2671887425,
#  1806669395,
#  778428600,
#  222762363,
#  2388496174,
#  978804299,
#  1363456101,
#  250139232,
#  1103003881,
#  3559909102,
#  3057488892,
#  1779290061,
#  2808311294,
#  1363461663,
#  2673420004,
#  1985560554,
#  1605793968,
#  2968240261,
#  392812542,
#  2166099479,
#  1999451198,
#  3245397435,
#  838323278,
#  3217164650,
#  1754390438,
#  221319174,
#  2984591798,
#  635287306,
#  1088504023,
#  2976376122,
#  3107925712,
#  2047792080,
#  3730973270,
#  3468524010,
#  2152101702,
#  244871349,
#  1152865951,
#  3121157757,
#  1696602783,
#  1287276835,
#  2002803935,
#  1917014745,
#  1197234278,
#  2657421156,
#  3286147894,
#  1998418841,
#  1984358773,
#  1614958409,
#  2319718488,
#  837478686,
#  1383653521,
#  3334947642,
#  872309816,
#  3288424920,
#  1346540116,
#  2559093190,
#  1238352030,
#  3165057619,
#  1152008800,
#  2760151366,
#  1903429003,
#  2449311026,
#  1781946855,
#  860722806,
#  3365030714,
#  1728371082,
#  1998300865,
#  2623566409,
#  1781980214,
#  2585925844,
#  1741136537,
#  3237079689,
#  2160558998,
#  1054001654,
#  1981321914,
#  2453379652,
#  1484330731,
#  3237059240,
#  3388205397,
#  317239336,
#  760234214,
#  765380508,
#  3065282694,
#  1864947220,
#  908412095,
#  2640055657,
#  623703180,
#  3366520526,
#  1412090917,
#  2990420361,
#  2649155224,
#  2783169920,
#  1877329590,
#  908531391,
#  3049031301,
#  1779195995,
#  3165023575,
#  2757410528,
#  1396344597,
#  862940708,
#  1741435970,
#  609406410,
#  3652626871,
#  612710011,
#  3664524346,
#  1022440764,
#  837444796,
#  1363428676,
#  3050446579,
#  664524638,
#  794586992,
#  3242613583,
#  1843701840,
#  3168977011,
#  1884629589,
#  989484588,
#  1218962210,
#  1999499313,
#  2703427260,
#  2671877804,
#  2671868763,
#  2703438158,
#  3230721579,
#  2177633289,
#  1530221939,
#  3358339739,
#  2021942117,
#  771368328,
#  1759129698,
#  1363428882,
#  2028759486,
#  3323675173,
#  ...]

# %% [markdown]
# # All the Countries non root users ip addresses are from

# %%
nonRootResultCountries = nonRootDecimalIP.map(lambda line: find_country(line))
nonRootCountries = nonRootResultCountries.map(lambda name: (name, 1)) \
          .reduceByKey(lambda a, b: a + b)
nonRootCountries.collect()
# Out:
# [('India', 256),
#  ('Poland', 43),
#  ('Germany', 225),
#  ('Canada', 105),
#  ('Ukraine', 32),
#  ('Romania', 15),
#  ('Viet Nam', 115),
#  ('Malaysia', 27),
#  ('Taiwan (Province of China)', 35),
#  ('Japan', 69),
#  ('Cambodia', 2),
#  ('United Arab Emirates', 8),
#  ('Thailand', 45),
#  ('Uruguay', 3),
#  ('Mongolia', 5),
#  ('Namibia', 1),
#  ('Bangladesh', 9),
#  ('Tunisia', 10),
#  ('Denmark', 1),
#  ('Zimbabwe', 3),
#  ('Belgium', 11),
#  ('Syrian Arab Republic', 2),
#  ('Serbia', 4),
#  ('Bhutan', 1),
#  ('Finland', 6),
#  ('Kyrgyzstan', 1),
#  ('Saudi Arabia', 2),
#  ('Luxembourg', 2),
#  ("Cote D'ivoire", 3),
#  ('Uganda', 2),
#  ('New Zealand', 2),
#  ('Guatemala', 1),
#  ('Puerto Rico', 1),
#  ('Cameroon', 1),
#  ('Albania', 1),
#  ('Norway', 5),
#  ('Australia', 15),
#  ('Netherlands', 146),
#  ('Mexico', 50),
#  ('Korea (Republic of)', 197),
#  ('Macao', 3),
#  ('Chile', 13),
#  ('Panama', 6),
#  ('Lebanon', 2),
#  ('Senegal', 2),
#  ('-', 16),
#  ('Algeria', 2),
#  ('Mozambique', 1),
#  ('Sudan', 1),
#  ('Angola', 1),
#  ('Azerbaijan', 2),
#  ('Argentina', 54),
#  ('Bulgaria', 3),
#  ('Spain', 27),
#  ('United Kingdom of Great Britain and Northern Ireland', 107),
#  ('Morocco', 4),
#  ('Ecuador', 8),
#  ('Portugal', 9),
#  ('Ethiopia', 3),
#  ('Montenegro', 2),
#  ('Uzbekistan', 8),
#  ('Peru', 5),
#  ('Moldova (Republic of)', 3),
#  ('Reunion', 1),
#  ('Madagascar', 1),
#  ('Austria', 4),
#  ('Slovenia', 3),
#  ('Nepal', 3),
#  ('Costa Rica', 1),
#  ('Georgia', 2),
#  ('Ghana', 1),
#  ('Somalia', 1),
#  ('Trinidad and Tobago', 1),
#  ('China', 2320),
#  ('Indonesia', 86),
#  ('Paraguay', 9),
#  ('Pakistan', 18),
#  ('Colombia', 59),
#  ('Sweden', 23),
#  ('Hungary', 15),
#  ('Ireland', 6),
#  ('Kuwait', 1),
#  ('Venezuela (Bolivarian Republic of)', 15),
#  ('Myanmar', 2),
#  ('Haiti', 1),
#  ('Croatia', 10),
#  ('Belarus', 4),
#  ('Sri Lanka', 2),
#  ('Czechia', 7),
#  ('Tanzania, United Republic of', 2),
#  ('Greece', 6),
#  ('Latvia', 2),
#  ('North Macedonia', 2),
#  ('Kenya', 8),
#  ('Armenia', 3),
#  ('Malta', 1),
#  ('Brunei Darussalam', 1),
#  ('Kazakhstan', 7),
#  ('Libya', 1),
#  ('Seychelles', 2),
#  ('Zambia', 2),
#  ('Virgin Islands (U.S.)', 1),
#  ('Iraq', 1),
#  ('Iran (Islamic Republic of)', 22),
#  ('United States of America', 980),
#  ('Brazil', 250),
#  ('Singapore', 240),
#  ('France', 353),
#  ('Hong Kong', 170),
#  ('Russian Federation', 149),
#  ('Italy', 49),
#  ('Turkey', 13),
#  ('Nigeria', 5),
#  ('Israel', 2),
#  ('Switzerland', 11),
#  ('Philippines', 15),
#  ('Jordan', 4),
#  ('Mauritius', 1),
#  ('Egypt', 8),
#  ('South Africa', 13),
#  ('Bolivia (Plurinational State of)', 9),
#  ('Honduras', 1),
#  ('Bahrain', 1),
#  ('Dominican Republic', 5),
#  ('Lithuania', 2),
#  ('Slovakia', 1),
#  ('Fiji', 1),
#  ('Palestine, State of', 1),
#  ('Guadeloupe', 1)]

# %% [markdown]
# ### Filter out the attempts without usernames

# %%
knownRootFails = nonRootFails.filter(lambda line: line.find("unknown") < 0)
knownRootFails.take(50)
# Out:
# ['Dec 13 00:08:29 submitty sshd[19552]: Invalid user shalini from 27.128.173.81 port 49454',
#  'Dec 13 00:08:29 submitty sshd[19552]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=27.128.173.81',
#  'Dec 13 00:08:32 submitty sshd[19552]: Failed password for invalid user shalini from 27.128.173.81 port 49454 ssh2',
#  'Dec 13 00:08:40 submitty sshd[19560]: Invalid user user5 from 134.175.17.32 port 44532',
#  'Dec 13 00:08:40 submitty sshd[19560]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=134.175.17.32',
#  'Dec 13 00:08:41 submitty sshd[19562]: Invalid user lms from 201.90.101.165 port 44854',
#  'Dec 13 00:08:41 submitty sshd[19562]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=201.90.101.165',
#  'Dec 13 00:08:43 submitty sshd[19560]: Failed password for invalid user user5 from 134.175.17.32 port 44532 ssh2',
#  'Dec 13 00:08:43 submitty sshd[19560]: Received disconnect from 134.175.17.32 port 44532:11: Bye Bye [preauth]',
#  'Dec 13 00:08:43 submitty sshd[19560]: Disconnected from invalid user user5 134.175.17.32 port 44532 [preauth]',
#  'Dec 13 00:08:43 submitty sshd[19562]: Failed password for invalid user lms from 201.90.101.165 port 44854 ssh2',
#  'Dec 13 00:08:44 submitty sshd[19562]: Received disconnect from 201.90.101.165 port 44854:11: Bye Bye [preauth]',
#  'Dec 13 00:08:44 submitty sshd[19562]: Disconnected from invalid user lms 201.90.101.165 port 44854 [preauth]',
#  'Dec 13 00:11:06 submitty sshd[19744]: Invalid user ttf from 119.45.22.71 port 60804',
#  'Dec 13 00:11:06 submitty sshd[19744]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=119.45.22.71',
#  'Dec 13 00:11:07 submitty sshd[19744]: Failed password for invalid user ttf from 119.45.22.71 port 60804 ssh2',
#  'Dec 13 00:11:08 submitty sshd[19744]: Received disconnect from 119.45.22.71 port 60804:11: Bye Bye [preauth]',
#  'Dec 13 00:11:08 submitty sshd[19744]: Disconnected from invalid user ttf 119.45.22.71 port 60804 [preauth]',
#  'Dec 13 00:11:21 submitty sshd[19752]: Invalid user finn from 58.17.200.197 port 49650',
#  'Dec 13 00:11:21 submitty sshd[19752]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=58.17.200.197',
#  'Dec 13 00:11:23 submitty sshd[19752]: Failed password for invalid user finn from 58.17.200.197 port 49650 ssh2',
#  'Dec 13 00:11:23 submitty sshd[19752]: Received disconnect from 58.17.200.197 port 49650:11: Bye Bye [preauth]',
#  'Dec 13 00:11:23 submitty sshd[19752]: Disconnected from invalid user finn 58.17.200.197 port 49650 [preauth]',
#  'Dec 13 00:11:43 submitty sshd[19777]: warning: /etc/hosts.allow, line 13: host name/name mismatch: static.vnpt.vn != dnsfirewall.wcupa.edu',
#  'Dec 13 00:11:44 submitty sshd[19777]: Invalid user merle from 14.161.45.187 port 56273',
#  'Dec 13 00:11:44 submitty sshd[19777]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=14.161.45.187',
#  'Dec 13 00:11:46 submitty sshd[19777]: Failed password for invalid user merle from 14.161.45.187 port 56273 ssh2',
#  'Dec 13 00:11:46 submitty sshd[19777]: Received disconnect from 14.161.45.187 port 56273:11: Bye Bye [preauth]',
#  'Dec 13 00:11:46 submitty sshd[19777]: Disconnected from invalid user merle 14.161.45.187 port 56273 [preauth]',
#  'Dec 13 00:11:53 submitty sshd[19789]: Invalid user domain from 49.70.64.41 port 34474',
#  'Dec 13 00:11:53 submitty sshd[19789]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=49.70.64.41',
#  'Dec 13 00:11:54 submitty sshd[19796]: Invalid user ame from 129.211.138.177 port 53742',
#  'Dec 13 00:11:54 submitty sshd[19796]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=129.211.138.177',
#  'Dec 13 00:11:55 submitty sshd[19789]: Failed password for invalid user domain from 49.70.64.41 port 34474 ssh2',
#  'Dec 13 00:11:55 submitty sshd[19789]: Received disconnect from 49.70.64.41 port 34474:11: Bye Bye [preauth]',
#  'Dec 13 00:11:55 submitty sshd[19789]: Disconnected from invalid user domain 49.70.64.41 port 34474 [preauth]',
#  'Dec 13 00:11:56 submitty sshd[19796]: Failed password for invalid user ame from 129.211.138.177 port 53742 ssh2',
#  'Dec 13 00:11:56 submitty sshd[19796]: Received disconnect from 129.211.138.177 port 53742:11: Bye Bye [preauth]',
#  'Dec 13 00:11:56 submitty sshd[19796]: Disconnected from invalid user ame 129.211.138.177 port 53742 [preauth]',
#  "Dec 13 00:11:58 submitty sshd[19809]: warning: /etc/hosts.allow, line 13: can't verify hostname: getaddrinfo(185-156-74-65.pro-telecom.net, AF_INET) failed",
#  'Dec 13 00:12:00 submitty sshd[19809]: Invalid user mysql from 185.156.74.65 port 2243',
#  'Dec 13 00:12:00 submitty sshd[19809]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=185.156.74.65',
#  'Dec 13 00:12:02 submitty sshd[19809]: Failed password for invalid user mysql from 185.156.74.65 port 2243 ssh2',
#  'Dec 13 00:12:02 submitty sshd[19809]: Connection closed by invalid user mysql 185.156.74.65 port 2243 [preauth]',
#  'Dec 13 00:12:54 submitty sshd[19848]: Invalid user klx from 103.152.101.19 port 60110',
#  'Dec 13 00:12:54 submitty sshd[19848]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=103.152.101.19',
#  'Dec 13 00:12:56 submitty sshd[19848]: Failed password for invalid user klx from 103.152.101.19 port 60110 ssh2',
#  'Dec 13 00:12:56 submitty sshd[19850]: Invalid user lionya from 61.181.80.253 port 60023',
#  'Dec 13 00:12:56 submitty sshd[19850]: pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=61.181.80.253',
#  'Dec 13 00:12:56 submitty sshd[19848]: Received disconnect from 103.152.101.19 port 60110:11: Bye Bye [preauth]']

# %%
s = 'Dec 13 00:12:56 submitty sshd[19848]: Received disconnect from 103.152.101.19 port 60110:11: Bye Bye [preauth]'
breakdown_failed(s)[2]
# Out:
# '19848'

# %% [markdown]
# ### Gets the error messages for the the fails with known user names

# %%
knownRootFailsGroups = knownRootFails.map(lambda line: breakdown_failed(line)[3])
knownRootFailsGroups.take(5)
# Out:
# ['Invalid user shalini from 27.128.173.81 port 49454',
#  'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=27.128.173.81',
#  'Failed password for invalid user shalini from 27.128.173.81 port 49454 ssh2',
#  'Invalid user user5 from 134.175.17.32 port 44532',
#  'pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=134.175.17.32']

# %% [markdown]
# ### Makes sure we just have the error messages with user names as not all error message include the user name

# %%
withUsers = knownRootFailsGroups.filter(lambda line: line.find("user") > 0)
withUsersTake  = withUsers.filter(lambda line: line.find("failure") < 0)
withUsersTake.take(20)
# Out:
# ['Invalid user shalini from 27.128.173.81 port 49454',
#  'Failed password for invalid user shalini from 27.128.173.81 port 49454 ssh2',
#  'Invalid user user5 from 134.175.17.32 port 44532',
#  'Invalid user lms from 201.90.101.165 port 44854',
#  'Failed password for invalid user user5 from 134.175.17.32 port 44532 ssh2',
#  'Disconnected from invalid user user5 134.175.17.32 port 44532 [preauth]',
#  'Failed password for invalid user lms from 201.90.101.165 port 44854 ssh2',
#  'Disconnected from invalid user lms 201.90.101.165 port 44854 [preauth]',
#  'Invalid user ttf from 119.45.22.71 port 60804',
#  'Failed password for invalid user ttf from 119.45.22.71 port 60804 ssh2',
#  'Disconnected from invalid user ttf 119.45.22.71 port 60804 [preauth]',
#  'Invalid user finn from 58.17.200.197 port 49650',
#  'Failed password for invalid user finn from 58.17.200.197 port 49650 ssh2',
#  'Disconnected from invalid user finn 58.17.200.197 port 49650 [preauth]',
#  'Invalid user merle from 14.161.45.187 port 56273',
#  'Failed password for invalid user merle from 14.161.45.187 port 56273 ssh2',
#  'Disconnected from invalid user merle 14.161.45.187 port 56273 [preauth]',
#  'Invalid user domain from 49.70.64.41 port 34474',
#  'Invalid user ame from 129.211.138.177 port 53742',
#  'Failed password for invalid user domain from 49.70.64.41 port 34474 ssh2']

# %% [markdown]
# ### Method for finding the user names

# %%
import re
def find_user_names(s):
    extracts = re.search("([\S ]+) user (\S+) ([\S ]+)", s)
    return extracts.groups() if extracts else s

# %% [markdown]
# ### Testing the find user name method

# %%
s = 'Invalid user shalini from 27.128.173.81 port 49454'
find_user_names(s)[1]
# Out:
# 'shalini'

# %% [markdown]
# ### Finding all the user names of each error message with user names

# %%
names = withUsersTake.map(lambda line: find_user_names(line)[1])
names.take(10)
# Out:
# ['shalini',
#  'shalini',
#  'user5',
#  'lms',
#  'user5',
#  'user5',
#  'lms',
#  'lms',
#  'ttf',
#  'ttf']

# %% [markdown]
# # Groups all like user names Answer to list all of the non root users user names

# %%
namesGrouped = names.map(lambda name: (name, 1)) \
            .reduceByKey(lambda a, b: a + b)
namesGrouped.take(10000)
# Out:
# [('shalini', 10),
#  ('named', 14),
#  ('i3', 3),
#  ('anthony', 20),
#  ('csgo', 23),
#  ('q', 9),
#  ('lara', 6),
#  ('webster', 6),
#  ('nobody', 12),
#  ('was', 8),
#  ('pi', 370),
#  ('ernesto', 3),
#  ('test', 752),
#  ('viper', 3),
#  ('admin10', 3),
#  ('newuser', 8),
#  ('cmuir', 3),
#  ('ultra', 12),
#  ('dyndns', 11),
#  ('luca', 8),
#  ('liz', 3),
#  ('photos', 6),
#  ('edward', 6),
#  ('jang', 3),
#  ('max', 20),
#  ('gelson', 5),
#  ('sahara', 3),
#  ('temp', 66),
#  ('alexandra', 5),
#  ('chelsea', 3),
#  ('kjayroe', 2),
#  ('azureuser', 14),
#  ('boon', 5),
#  ('support', 134),
#  ('pasquel', 3),
#  ('saml', 6),
#  ('sienna', 3),
#  ('aeegj', 2),
#  ('clinton', 9),
#  ('petera', 3),
#  ('giulia', 5),
#  ('svenserver', 3),
#  ('vision', 3),
#  ('heinz', 3),
#  ('frank', 5),
#  ('glpi', 6),
#  ('zabbix', 61),
#  ('Dakota', 5),
#  ('miusuario', 3),
#  ('e8telnet', 3),
#  ('default', 17),
#  ('telnet', 6),
#  ('mamta', 6),
#  ('openadmin', 6),
#  ('libuuid', 41),
#  ('flw', 3),
#  ('hamish', 3),
#  ('vboxuser', 8),
#  ('eli', 3),
#  ('sys', 7),
#  ('smbguest', 11),
#  ('redis', 12),
#  ('help', 14),
#  ('185.156.74.65', 4),
#  ('alex', 45),
#  ('b2', 6),
#  ('kinder', 3),
#  ('gnats', 7),
#  ('sabina', 6),
#  ('minecraft1', 3),
#  ('culture', 3),
#  ('marconi', 3),
#  ('olga', 6),
#  ('whoopsie', 6),
#  ('devops', 17),
#  ('telus', 3),
#  ('festival', 2),
#  ('lzhang', 6),
#  ('apidoc', 3),
#  ('kkyin', 3),
#  ('phoebe', 3),
#  ('compnf', 3),
#  ('ftpuser1', 38),
#  ('seaport', 3),
#  ('benjamin', 4),
#  ('me', 6),
#  ('maroon', 3),
#  ('archivo', 6),
#  ('pfs', 3),
#  ('cs', 17),
#  ('dino', 7),
#  ('egomez', 6),
#  ('perl', 3),
#  ('forestserver', 3),
#  ('gustavo', 3),
#  ('upload', 35),
#  ('nobody4', 9),
#  ('rainman', 6),
#  ('chenyu', 3),
#  ('xlychee', 3),
#  ('ts', 37),
#  ('stat', 3),
#  ('walle', 6),
#  ('ts3crack', 2),
#  ('165.22.63.151', 1),
#  ('odoo', 37),
#  ('superman', 3),
#  ('daemon', 4),
#  ('apitest', 3),
#  ('wenzhi', 3),
#  ('web-data', 2),
#  ('delta', 3),
#  ('dbbackup', 3),
#  ('ford', 3),
#  ('ramiro', 6),
#  ('kegel', 3),
#  ('marco', 12),
#  ('rustserverx2', 3),
#  ('mycat', 6),
#  ('builder', 3),
#  ('preche', 3),
#  ('puya', 6),
#  ('utente', 9),
#  ('server', 54),
#  ('vpup', 3),
#  ('couchdb', 14),
#  ('rpcuser', 17),
#  ('mendy', 3),
#  ('telmas', 3),
#  ('cyp', 3),
#  ('osama', 3),
#  ('dutch', 3),
#  ('gwen', 3),
#  ('morris', 3),
#  ('password', 6),
#  ('kmuser', 3),
#  ('demos', 3),
#  ('vhugo', 3),
#  ('moffice', 3),
#  ('vbns', 3),
#  ('lines', 3),
#  ('dujoey', 3),
#  ('ossi', 3),
#  ('fetchmail', 6),
#  ('henk', 6),
#  ('mihail', 3),
#  ('"uid=yang,ou=Faculty,ou=People,dc=cs"', 3),
#  ('vyatta', 12),
#  ('ts2', 9),
#  ('warmachine', 5),
#  ('aneta', 3),
#  ('justin', 6),
#  ('sftpdepot', 3),
#  ('aster', 3),
#  ('db2inst3', 3),
#  ('washington', 3),
#  ('hydra', 12),
#  ('misa', 3),
#  ('share', 21),
#  ('invoices', 9),
#  ('bananapi', 22),
#  ('trial', 3),
#  ('igor', 6),
#  ('nathavel', 3),
#  ('pos', 3),
#  ('hadoop', 121),
#  ('usbmux', 3),
#  ('vmail', 17),
#  ('steamcmd', 3),
#  ('chipset', 6),
#  ('avg', 6),
#  ('william', 8),
#  ('jana', 3),
#  ('karry', 3),
#  ('justin123', 3),
#  ('year', 9),
#  ('python', 9),
#  ('cychen', 3),
#  ('audio', 6),
#  ('hduser', 18),
#  ('user05', 8),
#  ('clamscan', 3),
#  ('nvidia', 12),
#  ('conghao', 3),
#  ('nginx', 37),
#  ('bamboo', 3),
#  ('coupon', 3),
#  ('administ', 3),
#  ('gloriela', 6),
#  ('kitamura', 3),
#  ('mountsys', 3),
#  ('admin2', 18),
#  ('xmlrpc', 11),
#  ('pietro', 3),
#  ('Administrator', 53),
#  ('wildfly', 15),
#  ('myvi', 3),
#  ('kamailio', 3),
#  ('bunny', 6),
#  ('mysql1', 6),
#  ('artemio', 3),
#  ('struts2', 3),
#  ('files', 11),
#  ('f3', 2),
#  ('dsl', 3),
#  ('rebecca', 6),
#  ('nur', 3),
#  ('joerg', 6),
#  ('sergiy', 3),
#  ('team3', 9),
#  ('test_01', 3),
#  ('arma3server', 9),
#  ('119.45.26.117', 1),
#  ('es', 24),
#  ('padmin', 15),
#  ('kate', 3),
#  ('sarah', 3),
#  ('edi', 2),
#  ('ftptestusr', 3),
#  ('younko', 3),
#  ('kek', 3),
#  ('rashid', 3),
#  ('wipro', 6),
#  ('netsis', 3),
#  ('dpham', 3),
#  ('vagner', 2),
#  ('testar', 3),
#  ('shak', 3),
#  ('stereo', 3),
#  ('at', 5),
#  ('office', 31),
#  ('dee', 18),
#  ('scott', 2),
#  ('nslcd', 11),
#  ('beam', 3),
#  ('minecraft', 79),
#  ('mtheile', 3),
#  ('ejabberd', 18),
#  ('bbu', 2),
#  ('marqo', 3),
#  ('gerard', 3),
#  ('sergey', 9),
#  ('deborah', 14),
#  ('o2', 6),
#  ('asoto', 3),
#  ('belese', 9),
#  ('webdown', 2),
#  ('pgadmin', 6),
#  ('anita', 3),
#  ('ajay', 9),
#  ('hatton', 6),
#  ('faic', 3),
#  ('oneadmin', 3),
#  ('huyen', 6),
#  ('server1', 15),
#  ('pierre', 3),
#  ('ciprian', 5),
#  ('nuucp', 12),
#  ('spamd', 3),
#  ('janine', 3),
#  ('logger', 8),
#  ('checksys', 3),
#  ('apt-dater', 3),
#  ('apenaloza', 3),
#  ('aparada', 9),
#  ('ftpadmin', 47),
#  ('jetman', 6),
#  ('fiscal', 3),
#  ('padrao', 3),
#  ('bernice', 3),
#  ('clarissa', 3),
#  ('mongod', 3),
#  ('alejarbu', 3),
#  ('zub', 3),
#  ('giga', 3),
#  ('sabine', 3),
#  ('mcladm', 3),
#  ('php-manager', 12),
#  ('gta', 6),
#  ('mckey', 3),
#  ('payment', 3),
#  ('jane', 3),
#  ('helpdesk', 25),
#  ('tkm', 6),
#  ('username', 20),
#  ('sssd', 12),
#  ('kasa', 3),
#  ('away', 3),
#  ('uucp', 11),
#  ('gitblit', 3),
#  ('csmi', 3),
#  ('magician', 3),
#  ('ctrls', 12),
#  ('virgil', 6),
#  ('jens', 3),
#  ('word', 6),
#  ('firebird', 3),
#  ('sarolta', 3),
#  ('dorotea', 5),
#  ('play', 12),
#  ('cde', 3),
#  ('mirjam', 3),
#  ('cstrike', 6),
#  ('pcp', 9),
#  ('193.169.252.59', 1),
#  ('manager', 40),
#  ('php-ashish', 3),
#  ('btkps', 3),
#  ('db_shv', 10),
#  ('testbox', 3),
#  ('mitchell', 3),
#  ('drill', 2),
#  ('kristy', 3),
#  ('robin', 6),
#  ('administrador', 6),
#  ('agent', 3),
#  ('lab', 12),
#  ('demicro', 5),
#  ('kenny', 6),
#  ('rtest', 3),
#  ('blyad', 3),
#  ('mari', 3),
#  ('saned', 1),
#  ('tom', 37),
#  ('op', 3),
#  ('sagaadministrator1', 3),
#  ('filip', 3),
#  ('smh', 3),
#  ('webbackup', 6),
#  ('pibak', 3),
#  ('oiio', 3),
#  ('ogsc', 3),
#  ('webteam', 3),
#  ('pazabbix', 3),
#  ('ftp1', 13),
#  ('slavisa', 3),
#  ('internet', 13),
#  ('gabriel', 9),
#  ('mia', 3),
#  ('gzuser', 3),
#  ('dircreate', 11),
#  ('back', 3),
#  ('antique', 3),
#  ('sftpjp', 3),
#  ('banet', 2),
#  ('cpanel', 49),
#  ('wifi', 6),
#  ('tamas', 3),
#  ('bayram', 3),
#  ('shalture', 3),
#  ('sopa', 3),
#  ('ashton', 9),
#  ('geeta', 6),
#  ('sshuser', 11),
#  ('nrlourenco', 6),
#  ('chaser', 6),
#  ('sanford', 3),
#  ('manfred', 3),
#  ('mickael', 3),
#  ('vtdc', 3),
#  ('mozak', 3),
#  ('qwer1234', 3),
#  ('lost+found', 3),
#  ('newwebsite', 3),
#  ('lanman', 6),
#  ('cricket', 3),
#  ('muraoka', 6),
#  ('setroubleshoot', 3),
#  ('ronald', 18),
#  ('bro', 6),
#  ('tanya', 6),
#  ('mysql-test', 3),
#  ('mich', 3),
#  ('cash', 3),
#  ('christina', 7),
#  ('cj894884', 9),
#  ('sampserver', 3),
#  ('anon', 6),
#  ('challbot', 6),
#  ('blaa', 3),
#  ('artifactory', 3),
#  ('janett', 3),
#  ('indra', 3),
#  ('family', 10),
#  ('xmr-node', 3),
#  ('daisy', 3),
#  ('george', 15),
#  ('kaczmarek', 3),
#  ('rdbackup', 2),
#  ('msin', 3),
#  ('tinydesk', 3),
#  ('martinez', 3),
#  ('pharmacy', 3),
#  ('mayeh', 3),
#  ('54.37.159.12', 1),
#  ('hassan', 2),
#  ('lorenz', 3),
#  ('icinga', 9),
#  ('terrariaserver2', 6),
#  ('king', 8),
#  ('t7inst', 3),
#  ('cyrus', 14),
#  ('clyde', 3),
#  ('icecast2', 3),
#  ('checkago', 3),
#  ('thierry', 3),
#  ('pjc', 3),
#  ('krodriguez', 3),
#  ('rick', 5),
#  ('graffiti', 3),
#  ('tip', 3),
#  ('adserver', 5),
#  ('nfp', 3),
#  ('lclin', 3),
#  ('xpmuser', 3),
#  ('austin', 13),
#  ('majordomo', 27),
#  ('official', 3),
#  ('oc_admin', 6),
#  ('meng', 3),
#  ('maks', 3),
#  ('status', 6),
#  ('glenrose', 3),
#  ('cablecom', 11),
#  ('netman', 8),
#  ('kamal', 3),
#  ('otsftp', 3),
#  ('nilson', 3),
#  ('mailuser', 3),
#  ('jimmy', 9),
#  ('self', 3),
#  ('clark', 8),
#  ('thomash', 6),
#  ('prasad', 3),
#  ('virinchi', 2),
#  ('hello', 2),
#  ('pacy', 3),
#  ('libb', 3),
#  ('ssh-user', 2),
#  ('beate', 3),
#  ('umountfs', 3),
#  ('factur', 6),
#  ('mapr', 9),
#  ('rodica', 3),
#  ('dobus', 3),
#  ('alumni', 17),
#  ('odoo1', 3),
#  ('wisa', 3),
#  ('gpadmin', 48),
#  ('personal', 6),
#  ('minera', 3),
#  ('mossc', 2),
#  ('asa', 6),
#  ('peewee', 3),
#  ('fluffy', 6),
#  ('test5', 17),
#  ('master4', 3),
#  ('arpwatch', 6),
#  ('madalina', 3),
#  ('samboi', 6),
#  ('cooper', 6),
#  ('filter', 6),
#  ('user3', 6),
#  ('black', 8),
#  ('danioss', 3),
#  ('rust', 9),
#  ('madison', 6),
#  ('terrariaserver', 8),
#  ('admin5', 3),
#  ('gmodserv3', 3),
#  ('peraire', 3),
#  ('shivam', 3),
#  ('livy', 3),
#  ('lpadm', 6),
#  ('phuket', 3),
#  ('132.232.84.44', 1),
#  ('andee', 3),
#  ('process', 6),
#  ('sonja', 3),
#  ('dominic', 6),
#  ('symop', 6),
#  ('backuppc', 6),
#  ('somuano', 3),
#  ('ashtond', 3),
#  ('f4', 6),
#  ('maiti', 3),
#  ('kpkp', 3),
#  ('testing', 45),
#  ('nugget', 3),
#  ('wywu', 5),
#  ('gymnast', 5),
#  ('tig3r', 3),
#  ('j\\342\\226\\222rgen', 2),
#  ('vodemia', 3),
#  ('pfisterer', 3),
#  ('devkostklip', 3),
#  ('lovemba', 3),
#  ('ssl_user', 9),
#  ('kasia', 6),
#  ('mes', 3),
#  ('vdapp', 3),
#  ('roland', 6),
#  ('pentaho', 3),
#  ('adin', 3),
#  ('Ionut', 3),
#  ('michaela', 6),
#  ('razz', 3),
#  ('master3', 3),
#  ('systuser', 3),
#  ('ovpn', 3),
#  ('jonnes', 3),
#  ('vfat', 3),
#  ('ipe', 3),
#  ('houx', 3),
#  ('leonard', 5),
#  ('momi', 3),
#  ('alupigus', 3),
#  ('mybackups', 3),
#  ('annamarie', 3),
#  ('master1', 9),
#  ('corentin', 2),
#  ('liu', 3),
#  ('xmuser', 2),
#  ('is', 3),
#  ('lexander', 3),
#  ('pty', 2),
#  ('almacen', 3),
#  ('elan', 3),
#  ('azhang', 3),
#  ('sebastien', 3),
#  ('wiew', 3),
#  ('tartaglia', 3),
#  ('die', 3),
#  ('niklas', 3),
#  ('mondal', 3),
#  ('andrei', 2),
#  ('invscout', 3),
#  ('wei', 5),
#  ('duplicata', 3),
#  ('dexter', 6),
#  ('georg', 3),
#  ('halina', 3),
#  ('jetty', 9),
#  ('chsm', 3),
#  ('joelson', 3),
#  ('desiree', 3),
#  ('chin', 3),
#  ('minetell', 3),
#  ('itinfra', 2),
#  ('if', 3),
#  ('ts3s', 3),
#  ('fdn', 3),
#  ('pernilla', 3),
#  ('maurice', 6),
#  ('jungu', 3),
#  ('ukhan', 3),
#  ('linda', 11),
#  ('123avahi-autoipd', 3),
#  ('ensp', 3),
#  ('lambrosi', 3),
#  ('podcast', 3),
#  ('aura', 3),
#  ('temporary', 2),
#  ('zena', 3),
#  ('ldapuser', 7),
#  ('gpd', 3),
#  ('lsx', 3),
#  ('cmbi', 3),
#  ('secure', 3),
#  ('derrell', 3),
#  ('look', 2),
#  ('kannel', 3),
#  ('sherry', 3),
#  ('foo', 3),
#  ('mcserv', 3),
#  ('pieter', 2),
#  ('erika', 2),
#  ('t3', 3),
#  ('fabior', 3),
#  ('one', 2),
#  ('kayten', 3),
#  ('tftpd', 3),
#  ('bjoern', 3),
#  ('cosinus', 3),
#  ('tyrel', 3),
#  ('tmuh', 3),
#  ('mateo', 3),
#  ('elline', 2),
#  ('xxl', 3),
#  ('inkass', 3),
#  ('yuli', 3),
#  ('jesse', 9),
#  ('notification', 3),
#  ('bash', 3),
#  ('chuj', 2),
#  ('syq', 3),
#  ('erwei', 3),
#  ('sll', 3),
#  ('drop', 3),
#  ('207.154.244.110', 1),
#  ('custom', 3),
#  ('head', 3),
#  ('vladislav', 3),
#  ('redy', 3),
#  ('superservicio', 3),
#  ('mellis', 3),
#  ('wang', 6),
#  ('sand', 3),
#  ('audit', 3),
#  ('tableau', 3),
#  ('hamza', 3),
#  ('barni', 3),
#  ('ludovic', 3),
#  ('shutdown', 11),
#  ('info1', 22),
#  ('testovh', 5),
#  ('testman', 10),
#  ('rpcbind', 5),
#  ('stq', 3),
#  ('fjn', 3),
#  ('qaz', 3),
#  ('smz', 3),
#  ('wcjn', 3),
#  ('oywc', 3),
#  ('lsh', 6),
#  ('okt', 3),
#  ('cbh', 3),
#  ('skm', 3),
#  ('xgd', 3),
#  ('jgl', 3),
#  ('nsn', 3),
#  ('abf', 3),
#  ('gyyy', 3),
#  ('jat', 3),
#  ('rwq', 3),
#  ('wczh', 3),
#  ('hem', 3),
#  ('dyr', 3),
#  ('azy', 3),
#  ('jtm', 3),
#  ('crj', 3),
#  ('qmb', 3),
#  ('lhsx', 3),
#  ('fpd', 3),
#  ('qnt', 3),
#  ('stmx', 3),
#  ('lsk', 3),
#  ('gmh', 3),
#  ('jxx', 2),
#  ('nhx', 3),
#  ('zwl', 3),
#  ('xml', 3),
#  ('ewd', 3),
#  ('hfmk', 3),
#  ('xmb', 3),
#  ('blt', 3),
#  ('oyzh', 3),
#  ('sgrh', 3),
#  ('wag', 3),
#  ('mml', 3),
#  ('bsj', 3),
#  ('"uid=pp920492,ou=Student,ou=People,dc=cs"', 3),
#  ('pp920492', 1),
#  ('lts', 3),
#  ('mrhz', 3),
#  ('ska', 3),
#  ('yrw', 3),
#  ('sgyy', 3),
#  ('qgx', 3),
#  ('hfrh', 3),
#  ('ryt', 6),
#  ('bet', 3),
#  ('ogz', 2),
#  ('sgdq', 3),
#  ('sxz', 3),
#  ('kqw', 3),
#  ('rnf', 3),
#  ('zgp', 3),
#  ('gqg', 3),
#  ('twt', 3),
#  ('ywze', 3),
#  ('ohg', 3),
#  ('zymz', 3),
#  ('mrzq', 3),
#  ('bmg', 3),
#  ('axm', 3),
#  ('ywyd', 3),
#  ('ztal', 3),
#  ('dmr', 3),
#  ('stwz', 3),
#  ('twa', 3),
#  ('klr', 2),
#  ('yo', 3),
#  ('pac', 3),
#  ('stxs', 3),
#  ('ckm', 3),
#  ('ckt', 3),
#  ('xzd', 3),
#  ('xox', 3),
#  ('sjh', 3),
#  ('wrrz', 3),
#  ('oyqq', 3),
#  ('dpm', 3),
#  ('zpn', 2),
#  ('mrxl', 3),
#  ('smj', 3),
#  ('txw', 3),
#  ('zph', 3),
#  ('ywcp', 2),
#  ('oaq', 3),
#  ('mnk', 3),
#  ('gkq', 3),
#  ('zsqr', 3),
#  ('nrs', 3),
#  ('ywtj', 3),
#  ('qbm', 3),
#  ('dck', 3),
#  ('kmn', 3),
#  ('jnd', 3),
#  ('ohh', 3),
#  ('dfbe', 3),
#  ('nfe', 3),
#  ('clp', 3),
#  ('jdb', 3),
#  ('lmk', 3),
#  ('odf', 3),
#  ('prs', 3),
#  ('spe', 3),
#  ('zyxz', 3),
#  ('wcqk', 3),
#  ('stmz', 3),
#  ('efb', 3),
#  ('slk', 3),
#  ('pef', 3),
#  ('gsc', 3),
#  ('bsg', 3),
#  ('wcl', 3),
#  ('wclf', 2),
#  ('fhx', 3),
#  ('hmg', 3),
#  ('nll', 3),
#  ('ahd', 3),
#  ('gr', 3),
#  ('fsw', 3),
#  ('hfm', 3),
#  ('ztm', 3),
#  ('meo', 3),
#  ('lfr', 3),
#  ('ztjh', 2),
#  ('lhlq', 3),
#  ('lec', 3),
#  ('rps', 3),
#  ('csle', 3),
#  ('fjl', 2),
#  ('cbj', 3),
#  ('orj', 6),
#  ('tbt', 6),
#  ('fdm', 3),
#  ('cjj', 3),
#  ('hfyk', 3),
#  ('lhyq', 3),
#  ('atx', 3),
#  ('qah', 3),
#  ('nkn', 3),
#  ('gyzr', 3),
#  ('xyln', 3),
#  ('ywcx', 3),
#  ('ztgy', 3),
#  ('hdn', 3),
#  ('nfh', 3),
#  ('lrq', 3),
#  ('nzg', 3),
#  ('smkz', 3),
#  ('wpp', 3),
#  ('oyyz', 3),
#  ('wwz', 3),
#  ('xpd', 3),
#  ('off', 3),
#  ('olq', 3),
#  ('fo', 3),
#  ('akz', 3),
#  ('rzs', 3),
#  ('ftf', 3),
#  ('styd', 3),
#  ('wdc', 3),
#  ('hej', 3),
#  ('dao', 3),
#  ('qke', 3),
#  ('men', 3),
#  ('lah', 2),
#  ('xzg', 3),
#  ('fkn', 3),
#  ('ttj', 3),
#  ('bqa', 3),
#  ('pmn', 3),
#  ('bkb', 3),
#  ('loh', 3),
#  ('xdo', 3),
#  ('stdp', 3),
#  ('xgw', 2),
#  ('ges', 3),
#  ('zggj', 3),
#  ('ztyh', 3),
#  ('mpy', 3),
#  ('gywz', 3),
#  ('whz', 3),
#  ('yqh', 3),
#  ('ees', 3),
#  ('zhd', 2),
#  ('oyrj', 3),
#  ('fwx', 3),
#  ('lzw', 3),
#  ('xyml', 2),
#  ('meg', 3),
#  ('bsb', 3),
#  ('ebx', 3),
#  ('smgc', 3),
#  ('jhw', 3),
#  ('tfl', 3),
#  ('lqx', 3),
#  ('tzs', 3),
#  ('xaz', 3),
#  ('mae', 3),
#  ('smes', 3),
#  ('xam', 3),
#  ('yrf', 3),
#  ('mkj', 2),
#  ('of', 3),
#  ('tqy', 3),
#  ('tlt', 6),
#  ('zyc', 3),
#  ('bho', 3),
#  ('ah', 3),
#  ('stsl', 3),
#  ('cqy', 3),
#  ('tme', 3),
#  ('lhc', 3),
#  ('wkh', 3),
#  ('yyd', 3),
#  ('bwm', 3),
#  ('lgb', 3),
#  ('mzy', 3),
#  ('zlt', 3),
#  ('stserver', 3),
#  ('gogogo', 3),
#  ('rebel', 6),
#  ('Abbott', 6),
#  ('daddy', 6),
#  ('amavis', 25),
#  ('design2', 9),
#  ('testman1', 3),
#  ('rafelc43', 4),
#  ('stpi', 3),
#  ('oscar', 2),
#  ('mm', 4),
#  ('device', 5),
#  ('toto', 11),
#  ('atan', 6),
#  ('nuevos', 7),
#  ('sanjivarishi', 3),
#  ('diane', 7),
#  ('jeremiah', 3),
#  ('wwwdata1', 5),
#  ('db2', 24),
#  ('birmingham', 6),
#  ('tsserver', 5),
#  ('49.233.15.54', 1),
#  ('lhftp2', 2),
#  ('mdpi', 6),
#  ('cacti', 3),
#  ('sage', 3),
#  ('piper', 14),
#  ('x', 5),
#  ('anton', 6),
#  ('liferay', 8),
#  ('tuxedo', 17),
#  ('nagios5', 5),
#  ('oo', 11),
#  ('mi', 5),
#  ('postgresqlpostgresql', 3),
#  ('landspace', 5),
#  ('185.63.46.208', 1),
#  ('tal', 8),
#  ('diana', 12),
#  ('hadoop2', 2),
#  ('samba1', 5),
#  ('db2test', 3),
#  ('00', 3),
#  ('newsletter', 12),
#  ('5', 6),
#  ('ff', 2),
#  ('techsupport', 9),
#  ('cvs1', 8),
#  ('scarab', 5),
#  ('tt', 3),
#  ('amanda', 18),
#  ('web6p1', 2),
#  ('farrell', 3),
#  ('www-run', 3),
#  ('changeme', 2),
#  ('zz12345', 5),
#  ('billy', 15),
#  ('164.132.145.70', 1),
#  ('mary', 3),
#  ('admin2003', 7),
#  ('abella', 2),
#  ('web13', 4),
#  ('backspace', 3),
#  ('nagios3', 3),
#  ('russ', 6),
#  ('catherine', 3),
#  ('ghost2', 4),
#  ('next', 9),
#  ('vodafone', 3),
#  ('user2004', 3),
#  ('200.216.30.196', 2),
#  ('frederic', 3),
#  ('tina', 3),
#  ('solaris', 8),
#  ('mathserv', 5),
#  ('ITMUser', 5),
#  ('tet', 3),
#  ('220.92.137.31', 1),
#  ('tuerk', 3),
#  ('nelson', 3),
#  ('almir', 2),
#  ('157.245.194.231', 1),
#  ('php', 6),
#  ('walker', 3),
#  ('lynda', 8),
#  ('freebsd', 6),
#  ('acplugs', 3),
#  ('test12', 3),
#  ('anna', 6),
#  ('wt', 2),
#  ('storm', 3),
#  ('jessica', 3),
#  ('test3', 11),
#  ('aaron', 6),
#  ('mexal', 3),
#  ('tibero6', 2),
#  ('webapp', 9),
#  ('chrome', 2),
#  ('fernando', 3),
#  ('test001', 3),
#  ('!Z1qaz1qaz', 3),
#  ('1q@@w3e$$r', 3),
#  ('power2008', 6),
#  ('@dMIN123', 2),
#  ('qwerty!.', 3),
#  ('Owner123!@#', 3),
#  ('012345', 3),
#  ('qwert@123', 3),
#  ('PaSswoRD', 3),
#  ('Qwerty@1234rfv', 3),
#  ('1q@w3@e$r5', 3),
#  ('123qweQWE.', 2),
#  ('!@34qwera', 3),
#  ('Pass_hash', 3),
#  ('Welcome12', 3),
#  ('ADM1N1', 3),
#  ('Qwert123@', 3),
#  ('passw0rd1', 3),
#  ('password00', 3),
#  ('$c@nner1.', 3),
#  ('1qazASDzxc', 3),
#  ('IRANwebfa', 5),
#  ('QWERT_12345', 3),
#  ('P&lt;OMINUB', 3),
#  ('Pa%%w0rd123', 6),
#  ('045478', 3),
#  ('%TGB%5tgb', 12),
#  ('Passw0rd01!', 9),
#  ('Administrator123*.', 3),
#  ('qaz123!@#', 3),
#  ('Pa$$wOrd12', 9),
#  ('Romania', 3),
#  ('123qwe$', 3),
#  ('1qwertzu', 2),
#  ('1q2w3e4r@12', 3),
#  ('Pa$$word43213', 3),
#  ('1qaz@QWEzxc', 3),
#  ('!qwe2wsx#zxc', 3),
#  ('1a2g3t', 3),
#  ('windows2008', 2),
#  ('zk', 3),
#  ('1nt3rn3t1', 3),
#  ('frankie', 8),
#  ('riana', 3),
#  ('rianna', 3),
#  ('format', 6),
#  ('riona', 3),
#  ('sada', 3),
#  ('trent', 3),
#  ('desire', 3),
#  ('silence', 6),
#  ('ronna', 3),
#  ('mindy', 3),
#  ('american', 2),
#  ('winona', 3),
#  ...]

# %% [markdown]
# ### Finds all the dates of every fail

# %%
dates = fails.map(lambda line: breakdown_failed(line)[0])
dates.take(50)
# Out:
# ['Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13',
#  'Dec 13']

# %% [markdown]
# # Groups every fail by date and counts how many fails happened on each day. It appear the the day with the most fails is Dec 8 with 7952 fails there doesn't seem to be anything special about this day asside from being a few national holidays and some minor religious holidays with the most popular on being Feast of the Immaculate Conception which is a public holiday in multiple countries

# %%
dateCount = dates.map(lambda date: (date, 1)) \
            .reduceByKey(lambda a, b: a + b)
dateCount.take(100)
# Out:
# [('Dec  8', 7952),
#  ('Nov 29', 5588),
#  ('Nov 17', 4796),
#  ('Dec 16', 4489),
#  ('Dec  7', 6261),
#  ('Dec 11', 5894),
#  ('Dec  1', 4375),
#  ('Dec  2', 4983),
#  ('Dec  5', 5031),
#  ('Nov 23', 4963),
#  ('Nov 27', 6167),
#  ('Dec 15', 5629),
#  ('Nov 19', 4245),
#  ('Nov 21', 4382),
#  ('Dec 13', 6498),
#  ('Dec  9', 5388),
#  ('Dec 10', 4359),
#  ('Dec 12', 5237),
#  ('Nov 30', 3848),
#  ('Dec  4', 5232),
#  ('Nov 24', 6478),
#  ('Nov 25', 4603),
#  ('Nov 26', 4420),
#  ('Nov 20', 4596),
#  ('Dec 14', 4094),
#  ('Dec  3', 5438),
#  ('Dec  6', 6844),
#  ('Nov 28', 5356),
#  ('Nov 15', 3436),
#  ('Nov 16', 4310),
#  ('Nov 18', 3771),
#  ('Nov 22', 5590)]
